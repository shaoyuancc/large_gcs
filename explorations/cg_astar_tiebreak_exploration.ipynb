# %%
import logging
from large_gcs.graph_generators.contact_graph_generator import (
    ContactGraphGeneratorParams,
    ContactGraphGenerator,
)
from large_gcs.graph.contact_graph import ContactGraph
from large_gcs.algorithms.search_algorithm import TieBreak
from large_gcs.algorithms.gcs_astar import GcsAstar
from large_gcs.algorithms.gcs_astar_convex_restriction import GcsAstarConvexRestriction
from large_gcs.graph.contact_cost_constraint_factory import (
    contact_shortcut_edge_cost_factory_under,
    contact_shortcut_edge_cost_factory_over_obj_weighted,
)

import numpy as np

np.set_printoptions(formatter={"float": lambda x: "{0:0.3f}".format(x)})
logging.basicConfig(level=logging.INFO)
logging.getLogger("drake").setLevel(logging.WARNING)

# %%
cg = ContactGraph.load_from_file(ContactGraphGeneratorParams.graph_file_path_from_name("cg_trichal2"))
# Out:
# INFO:large_gcs.graph.contact_graph:Loading 20 contact pair modes for 3 bodies...
# INFO:large_gcs.graph.contact_graph:Generating contact sets for 179 sets...
# 100%|██████████| 179/179 [00:05<00:00, 31.84it/s]
# INFO:large_gcs.graph.contact_graph:Creating vertex costs...
# 100%|██████████| 181/181 [00:00<00:00, 3268.21it/s]
# INFO:large_gcs.graph.graph:Adding 181 vertices to graph...
# 100%|██████████| 181/181 [00:00<00:00, 2928.89it/s]
# INFO:large_gcs.graph.contact_graph:Creating edge costs...
# 100%|██████████| 6408/6408 [00:01<00:00, 3513.23it/s]
# INFO:large_gcs.graph.contact_graph:Creating edge constraints...
# 100%|██████████| 6408/6408 [00:03<00:00, 1786.66it/s]
# INFO:large_gcs.graph.graph:Adding 6408 edges to graph...
# 100%|██████████| 6408/6408 [00:04<00:00, 1559.44it/s]
# INFO:large_gcs.graph.contact_graph:Created contact graph: GraphParams(dim_bounds=(4, 18), n_vertices=181, n_edges=6408, source=[array([3.250, 0.000]), array([1.500, 0.500])], target=[array([-1.500, 0.000]), array([-3,  0])], workspace=array([[-4,  4],
#        [-3,  3]]), default_costs_constraints=None)

# %% [markdown]
# With the following cell I did FIFO tie breaking by setting the tie breaking counter to count up

# %%
gcs_astar = GcsAstarConvexRestriction(
    cg,
    should_reexplore=True,
    shortcut_edge_cost_factory=contact_shortcut_edge_cost_factory_over_obj_weighted,
    tiebreak=TieBreak.FIFO
)
sol = gcs_astar.run()
# Out:
# INFO:large_gcs.algorithms.gcs_astar_convex_restriction:Running GcsAstarConvexRestriction, should_rexplore: True, use_convex_relaxation: False, shortcut_edge_cost_factory: contact_shortcut_edge_cost_factory_over_obj_weighted
# INFO:large_gcs.algorithms.gcs_astar_convex_restriction:Top 10 pq costs: [0]
# INFO:large_gcs.algorithms.gcs_astar_convex_restriction:
# n_vertices_visited: 2, n_edges_visited: 0, n_vertices_explored: 0, vertex_coverage: 0.011, edge_coverage: 0, time_wall_clock: 0, n_gcs_solves: 0, gcs_solve_time_total: 0, gcs_solve_time_iter_mean: 0, gcs_solve_time_last_10_mean: 0, gcs_solve_time_iter_std: 0, gcs_solve_time_iter_min: inf, gcs_solve_time_iter_max: 0, n_vertices_revisited: 0, n_vertices_reexplored: 0
# now exploring node source's 1 neighbors (0)
# INFO:large_gcs.algorithms.gcs_astar_convex_restriction:Top 10 pq costs: [241.04873818714518]
# INFO:large_gcs.algorithms.gcs_astar_convex_restriction:
# n_vertices_visited: 3, n_edges_visited: 1, n_vertices_explored: 1, vertex_coverage: 0.0166, edge_coverage: 0.0002, time_wall_clock: 0.0415, n_gcs_solves: 1, gcs_solve_time_total: 0.032, gcs_solve_time_iter_mean: 0.032, gcs_solve_time_last_10_mean: 0, gcs_solve_time_iter_std: 0, gcs_solve_time_iter_min: 0.032, gcs_solve_time_iter_max: 0.032, n_vertices_revisited: 0, n_vertices_reexplored: 0
# now exploring node ('NC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'NC|obj0_f3-rob0_v0')'s 56 neighbors (241.04873818714518)
# INFO:large_gcs.algorithms.gcs_astar_convex_restriction:Top 10 pq costs: [240.87381507616544, 241.03951911905648, 242.0487383257758, 251.84254974633157, 259.92793879324444, 260.25991447508846, 260.61046403663573]
# INFO:large_gcs.algorithms.gcs_astar_convex_restriction:
# n_vertices_visited: 4, n_edges_visited: 2, n_vertices_explored: 56, vertex_coverage: 0.0221, edge_coverage: 0.0003, time_wall_clock: 1.4, n_gcs_solves: 56, gcs_solve_time_total: 1.22, gcs_solve_time_iter_mean: 0.0218, gcs_solve_time_last_10_mean: 0.0214, gcs_solve_time_iter_std: 0.00328, gcs_solve_time_iter_min: 0.0174, gcs_solve_time_iter_max: 0.032, n_vertices_revisited: 0, n_vertices_reexplored: 0
# now exploring node ('NC|obs0_f0-obj0_v3', 'NC|obs0_f2-rob0_v0', 'NC|obj0_f3-rob0_v0')'s 63 neighbors (240.87381507616544)
# INFO:large_gcs.algorithms.gcs_astar_convex_restriction:Top 10 pq costs: [241.03951911905648, 242.03952684324568, 242.0487383257758, 244.77398981607567, 244.87894534934293, 251.84254974633157, 252.34703794605855, 252.3470396676862, 259.92793879324444, 260.25991447508846]
# INFO:large_gcs.algorithms.gcs_astar_convex_restriction:
# n_vertices_visited: 5, n_edges_visited: 2, n_vertices_explored: 118, vertex_coverage: 0.0276, edge_coverage: 0.0003, time_wall_clock: 2.96, n_gcs_solves: 118, gcs_solve_time_total: 2.58, gcs_solve_time_iter_mean: 0.0219, gcs_solve_time_last_10_mean: 0.0236, gcs_solve_time_iter_std: 0.00341, gcs_solve_time_iter_min: 0.0174, gcs_solve_time_iter_max: 0.0337, n_vertices_revisited: 0, n_vertices_reexplored: 0
# now exploring node ('NC|obs0_f0-obj0_v3', 'NC|obs0_f2-rob0_v0', 'NC|obj0_f0-rob0_v1')'s 43 neighbors (241.03951911905648)
# INFO:large_gcs.algorithms.gcs_astar_convex_restriction:Top 10 pq costs: [241.87381135426023, 242.03952684324568, 242.0487383257758, 244.77398981607567, 244.8789439865949, 244.87894534934293, 251.84254974633157, 252.34703794605855, 252.3470396676862, 259.92793879324444]
# INFO:large_gcs.algorithms.gcs_astar_convex_restriction:
# n_vertices_visited: 5, n_edges_visited: 3, n_vertices_explored: 159, vertex_coverage: 0.0276, edge_coverage: 0.0005, time_wall_clock: 3.99, n_gcs_solves: 160, gcs_solve_time_total: 3.49, gcs_solve_time_iter_mean: 0.0218, gcs_solve_time_last_10_mean: 0.0212, gcs_solve_time_iter_std: 0.00327, gcs_solve_time_iter_min: 0.0174, gcs_solve_time_iter_max: 0.0337, n_vertices_revisited: 1, n_vertices_reexplored: 1
# now exploring node ('NC|obs0_f0-obj0_v3', 'NC|obs0_f2-rob0_v0', 'NC|obj0_f3-rob0_v0')'s 63 neighbors (241.87381135426023)
# INFO:large_gcs.algorithms.gcs_astar_convex_restriction:Top 10 pq costs: [242.03952684324568, 242.0487383257758, 244.77398981607567, 244.8789439865949, 244.87894534934293, 245.7739997683196, 245.8789443691765, 251.84254974633157, 252.34703794605855, 252.3470396676862]
# INFO:large_gcs.algorithms.gcs_astar_convex_restriction:
# n_vertices_visited: 5, n_edges_visited: 3, n_vertices_explored: 220, vertex_coverage: 0.0276, edge_coverage: 0.0005, time_wall_clock: 5.53, n_gcs_solves: 221, gcs_solve_time_total: 4.84, gcs_solve_time_iter_mean: 0.0219, gcs_solve_time_last_10_mean: 0.02, gcs_solve_time_iter_std: 0.00331, gcs_solve_time_iter_min: 0.0174, gcs_solve_time_iter_max: 0.0337, n_vertices_revisited: 2, n_vertices_reexplored: 1
# now exploring node ('NC|obs0_f0-obj0_v3', 'NC|obs0_f2-rob0_v0', 'NC|obj0_f0-rob0_v1')'s 43 neighbors (242.03952684324568)
# INFO:large_gcs.algorithms.gcs_astar_convex_restriction:Top 10 pq costs: [242.0487383257758, 244.77398981607567, 244.8789439865949, 244.87894534934293, 245.7739997683196, 245.8789443691765, 245.87894539497904, 251.84254974633157, 252.34703794605855, 252.3470396676862]
# INFO:large_gcs.algorithms.gcs_astar_convex_restriction:
# n_vertices_visited: 6, n_edges_visited: 2, n_vertices_explored: 261, vertex_coverage: 0.0331, edge_coverage: 0.0003, time_wall_clock: 6.59, n_gcs_solves: 262, gcs_solve_time_total: 5.77, gcs_solve_time_iter_mean: 0.022, gcs_solve_time_last_10_mean: 0.0216, gcs_solve_time_iter_std: 0.00326, gcs_solve_time_iter_min: 0.0174, gcs_solve_time_iter_max: 0.0337, n_vertices_revisited: 2, n_vertices_reexplored: 1
# now exploring node ('NC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'NC|obj0_f0-rob0_v1')'s 67 neighbors (242.0487383257758)
# INFO:large_gcs.algorithms.gcs_astar_convex_restriction:Top 10 pq costs: [100.880913144764, 241.87381081721614, 242.03952025196955, 244.77398981607567, 244.8789439865949, 244.87894534934293, 245.7739997683196, 245.8789443691765, 245.87894539497904, 251.84254974633157]
# INFO:large_gcs.algorithms.gcs_astar_convex_restriction:
# n_vertices_visited: 7, n_edges_visited: 3, n_vertices_explored: 325, vertex_coverage: 0.0387, edge_coverage: 0.0005, time_wall_clock: 8.36, n_gcs_solves: 328, gcs_solve_time_total: 7.33, gcs_solve_time_iter_mean: 0.0223, gcs_solve_time_last_10_mean: 0.023, gcs_solve_time_iter_std: 0.00359, gcs_solve_time_iter_min: 0.0174, gcs_solve_time_iter_max: 0.0477, n_vertices_revisited: 2, n_vertices_reexplored: 3
# now exploring node ('NC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'IC|obj0_f1-rob0_f1')'s 67 neighbors (100.880913144764)
# INFO:large_gcs.algorithms.gcs_astar_convex_restriction:Top 10 pq costs: [63.73091044150253, 92.10647160605136, 96.54173188574, 96.54173472554182, 101.88091290870672, 101.88091617495418, 102.26012477815702, 103.5451423018186, 103.54514342192242, 103.5451475545022]
# INFO:large_gcs.algorithms.gcs_astar_convex_restriction:
# n_vertices_visited: 8, n_edges_visited: 4, n_vertices_explored: 390, vertex_coverage: 0.0442, edge_coverage: 0.0006, time_wall_clock: 10.1, n_gcs_solves: 394, gcs_solve_time_total: 8.87, gcs_solve_time_iter_mean: 0.0225, gcs_solve_time_last_10_mean: 0.0233, gcs_solve_time_iter_std: 0.00351, gcs_solve_time_iter_min: 0.0174, gcs_solve_time_iter_max: 0.0477, n_vertices_revisited: 2, n_vertices_reexplored: 4
# now exploring node ('IC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'IC|obj0_f1-rob0_f1')'s 35 neighbors (63.73091044150253)
# INFO:large_gcs.algorithms.gcs_astar_convex_restriction:Top 10 pq costs: [54.74194031993999, 64.73090752723701, 64.7309077773652, 64.73091066316351, 64.73091164088778, 64.73091190077265, 64.73091381298153, 65.26806771455041, 65.36138067368688, 65.36138080807254]
# INFO:large_gcs.algorithms.gcs_astar_convex_restriction:
# n_vertices_visited: 9, n_edges_visited: 5, n_vertices_explored: 423, vertex_coverage: 0.0497, edge_coverage: 0.0008, time_wall_clock: 11.2, n_gcs_solves: 427, gcs_solve_time_total: 9.83, gcs_solve_time_iter_mean: 0.023, gcs_solve_time_last_10_mean: 0.0269, gcs_solve_time_iter_std: 0.00423, gcs_solve_time_iter_min: 0.0174, gcs_solve_time_iter_max: 0.0567, n_vertices_revisited: 2, n_vertices_reexplored: 4
# now exploring node ('IC|obs0_v0-obj0_f2', 'NC|obs0_f0-rob0_v1', 'IC|obj0_f1-rob0_f1')'s 25 neighbors (54.74194031993999)
# INFO:large_gcs.algorithms.gcs_astar_convex_restriction:Top 10 pq costs: [38.822837017371064, 38.82283711426717, 55.74193974153909, 55.80142046772013, 55.80142240294822, 55.80142426143542, 55.80142426153576, 59.407802312099726, 59.40862738012315, 59.40862825626829]
# INFO:large_gcs.algorithms.gcs_astar_convex_restriction:
# n_vertices_visited: 10, n_edges_visited: 6, n_vertices_explored: 445, vertex_coverage: 0.0552, edge_coverage: 0.0009, time_wall_clock: 12, n_gcs_solves: 449, gcs_solve_time_total: 10.5, gcs_solve_time_iter_mean: 0.0234, gcs_solve_time_last_10_mean: 0.031, gcs_solve_time_iter_std: 0.0047, gcs_solve_time_iter_min: 0.0174, gcs_solve_time_iter_max: 0.0567, n_vertices_revisited: 2, n_vertices_reexplored: 4
# now exploring node ('NC|obs0_f2-obj0_f1', 'NC|obs0_f0-rob0_v1', 'IC|obj0_f0-rob0_v1')'s 35 neighbors (38.822837017371064)
# INFO:large_gcs.algorithms.gcs_astar_convex_restriction:Top 10 pq costs: [34.34955030938746, 34.34955144476057, 35.18674900974683, 38.82283711426717, 39.822836449827065, 39.822838149473306, 39.822838827861325, 39.82283980072, 39.822839800895544, 39.822840016976805]
# INFO:large_gcs.algorithms.gcs_astar_convex_restriction:
# n_vertices_visited: 11, n_edges_visited: 7, n_vertices_explored: 476, vertex_coverage: 0.0608, edge_coverage: 0.0011, time_wall_clock: 13.1, n_gcs_solves: 481, gcs_solve_time_total: 11.5, gcs_solve_time_iter_mean: 0.0239, gcs_solve_time_last_10_mean: 0.0287, gcs_solve_time_iter_std: 0.00522, gcs_solve_time_iter_min: 0.0174, gcs_solve_time_iter_max: 0.0567, n_vertices_revisited: 2, n_vertices_reexplored: 5
# now exploring node ('NC|obs0_f2-obj0_f1', 'NC|obs0_f2-rob0_v0', 'IC|obj0_f0-rob0_v1')'s 49 neighbors (34.34955030938746)
# INFO:large_gcs.algorithms.gcs_astar_convex_restriction:Top 10 pq costs: [34.34955144476057, 34.96898131461636, 35.01053103174262, 35.18674900974683, 35.321776169575294, 35.321777450372835, 35.34955043042763, 38.82283711426717, 39.822836449827065, 39.822838149473306]
# INFO:large_gcs.algorithms.gcs_astar_convex_restriction:
# n_vertices_visited: 12, n_edges_visited: 7, n_vertices_explored: 521, vertex_coverage: 0.0663, edge_coverage: 0.0011, time_wall_clock: 14.6, n_gcs_solves: 527, gcs_solve_time_total: 12.7, gcs_solve_time_iter_mean: 0.0242, gcs_solve_time_last_10_mean: 0.0269, gcs_solve_time_iter_std: 0.00522, gcs_solve_time_iter_min: 0.0174, gcs_solve_time_iter_max: 0.0567, n_vertices_revisited: 2, n_vertices_reexplored: 6
# now exploring node ('IC|obs0_f2-obj0_f1', 'NC|obs0_f2-rob0_v0', 'IC|obj0_f0-rob0_v1')'s 23 neighbors (34.34955144476057)
# INFO:large_gcs.algorithms.gcs_astar_convex_restriction:Top 10 pq costs: [34.968980804395486, 34.96898131461636, 35.01053103174262, 35.01053215498521, 35.18674900974683, 35.32177386820385, 35.32177386842399, 35.321776169575294, 35.321777450372835, 35.34955043042763]
# INFO:large_gcs.algorithms.gcs_astar_convex_restriction:
# n_vertices_visited: 13, n_edges_visited: 8, n_vertices_explored: 542, vertex_coverage: 0.0718, edge_coverage: 0.0012, time_wall_clock: 15.4, n_gcs_solves: 549, gcs_solve_time_total: 13.4, gcs_solve_time_iter_mean: 0.0245, gcs_solve_time_last_10_mean: 0.0318, gcs_solve_time_iter_std: 0.00552, gcs_solve_time_iter_min: 0.0174, gcs_solve_time_iter_max: 0.0601, n_vertices_revisited: 2, n_vertices_reexplored: 7
# now exploring node ('IC|obs0_f2-obj0_f1', 'NC|obs0_f2-rob0_v0', 'IC|obj0_v0-rob0_f0')'s 45 neighbors (34.968980804395486)
# INFO:large_gcs.algorithms.gcs_astar_convex_restriction:Convex Restriction Gcs A* complete!
# cost: 37.17068292599849, time: 0.031368255615234375
# vertex path: ['source'
#  "('NC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'NC|obj0_f3-rob0_v0')"
#  "('NC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'NC|obj0_f0-rob0_v1')"
#  "('NC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'IC|obj0_f1-rob0_f1')"
#  "('IC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'IC|obj0_f1-rob0_f1')"
#  "('IC|obs0_v0-obj0_f2', 'NC|obs0_f0-rob0_v1', 'IC|obj0_f1-rob0_f1')"
#  "('NC|obs0_f2-obj0_f1', 'NC|obs0_f0-rob0_v1', 'IC|obj0_f0-rob0_v1')"
#  "('IC|obs0_f2-obj0_f1', 'NC|obs0_f2-rob0_v0', 'IC|obj0_f0-rob0_v1')"
#  "('IC|obs0_f2-obj0_f1', 'NC|obs0_f2-rob0_v0', 'IC|obj0_v0-rob0_f0')"
#  "('NC|obs0_f2-obj0_f1', 'NC|obs0_f2-rob0_v0', 'NC|obj0_f3-rob0_v0')"
#  'target']
# n_vertices_visited: 13, n_edges_visited: 8, n_vertices_explored: 584, vertex_coverage: 0.0718, edge_coverage: 0.0012, time_wall_clock: 16.8, n_gcs_solves: 592, gcs_solve_time_total: 14.7, gcs_solve_time_iter_mean: 0.0248, gcs_solve_time_last_10_mean: 0.0301, gcs_solve_time_iter_std: 0.00555, gcs_solve_time_iter_min: 0.0174, gcs_solve_time_iter_max: 0.0601, n_vertices_revisited: 2, n_vertices_reexplored: 8

# %% [markdown]
# With the following cell I did FIFO tie breaking by setting the tie breaking counter to count down `self._counter = itertools.count(start=0, step=-1)` but as you can see there was no difference, so at least in this problem it doesn't seem like tie breaking is a big issue.

# %%
gcs_astar = GcsAstarConvexRestriction(
    cg,
    should_reexplore=True,
    shortcut_edge_cost_factory=contact_shortcut_edge_cost_factory_over_obj_weighted,
    tiebreak=TieBreak.LIFO
)
sol = gcs_astar.run()
# Out:
# INFO:large_gcs.algorithms.gcs_astar_convex_restriction:Running GcsAstarConvexRestriction, should_rexplore: True, use_convex_relaxation: False, shortcut_edge_cost_factory: contact_shortcut_edge_cost_factory_over_obj_weighted
# INFO:large_gcs.algorithms.gcs_astar_convex_restriction:Top 10 pq costs: [0]
# INFO:large_gcs.algorithms.gcs_astar_convex_restriction:
# n_vertices_visited: 2, n_edges_visited: 0, n_vertices_explored: 0, vertex_coverage: 0.011, edge_coverage: 0, time_wall_clock: 0, n_gcs_solves: 0, gcs_solve_time_total: 0, gcs_solve_time_iter_mean: 0, gcs_solve_time_last_10_mean: 0, gcs_solve_time_iter_std: 0, gcs_solve_time_iter_min: inf, gcs_solve_time_iter_max: 0, n_vertices_revisited: 0, n_vertices_reexplored: 0
# now exploring node source's 1 neighbors (0)
# INFO:large_gcs.algorithms.gcs_astar_convex_restriction:Top 10 pq costs: [241.04873818714518]
# INFO:large_gcs.algorithms.gcs_astar_convex_restriction:
# n_vertices_visited: 3, n_edges_visited: 1, n_vertices_explored: 1, vertex_coverage: 0.0166, edge_coverage: 0.0002, time_wall_clock: 0.0311, n_gcs_solves: 1, gcs_solve_time_total: 0.0223, gcs_solve_time_iter_mean: 0.0223, gcs_solve_time_last_10_mean: 0, gcs_solve_time_iter_std: 0, gcs_solve_time_iter_min: 0.0223, gcs_solve_time_iter_max: 0.0223, n_vertices_revisited: 0, n_vertices_reexplored: 0
# now exploring node ('NC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'NC|obj0_f3-rob0_v0')'s 56 neighbors (241.04873818714518)
# INFO:large_gcs.algorithms.gcs_astar_convex_restriction:Top 10 pq costs: [240.87381507616544, 241.03951911905648, 242.0487383257758, 251.84254974633157, 259.92793879324444, 260.25991447508846, 260.61046403663573]
# INFO:large_gcs.algorithms.gcs_astar_convex_restriction:
# n_vertices_visited: 4, n_edges_visited: 2, n_vertices_explored: 56, vertex_coverage: 0.0221, edge_coverage: 0.0003, time_wall_clock: 1.36, n_gcs_solves: 56, gcs_solve_time_total: 1.19, gcs_solve_time_iter_mean: 0.0212, gcs_solve_time_last_10_mean: 0.0222, gcs_solve_time_iter_std: 0.00269, gcs_solve_time_iter_min: 0.017, gcs_solve_time_iter_max: 0.0271, n_vertices_revisited: 0, n_vertices_reexplored: 0
# now exploring node ('NC|obs0_f0-obj0_v3', 'NC|obs0_f2-rob0_v0', 'NC|obj0_f3-rob0_v0')'s 63 neighbors (240.87381507616544)
# INFO:large_gcs.algorithms.gcs_astar_convex_restriction:Top 10 pq costs: [241.03951911905648, 242.03952684324568, 242.0487383257758, 244.77398981607567, 244.87894534934293, 251.84254974633157, 252.34703794605855, 252.3470396676862, 259.92793879324444, 260.25991447508846]
# INFO:large_gcs.algorithms.gcs_astar_convex_restriction:
# n_vertices_visited: 5, n_edges_visited: 2, n_vertices_explored: 118, vertex_coverage: 0.0276, edge_coverage: 0.0003, time_wall_clock: 3, n_gcs_solves: 118, gcs_solve_time_total: 2.61, gcs_solve_time_iter_mean: 0.0221, gcs_solve_time_last_10_mean: 0.0206, gcs_solve_time_iter_std: 0.00367, gcs_solve_time_iter_min: 0.017, gcs_solve_time_iter_max: 0.0374, n_vertices_revisited: 0, n_vertices_reexplored: 0
# now exploring node ('NC|obs0_f0-obj0_v3', 'NC|obs0_f2-rob0_v0', 'NC|obj0_f0-rob0_v1')'s 43 neighbors (241.03951911905648)
# INFO:large_gcs.algorithms.gcs_astar_convex_restriction:Top 10 pq costs: [241.87381135426023, 242.03952684324568, 242.0487383257758, 244.77398981607567, 244.8789439865949, 244.87894534934293, 251.84254974633157, 252.34703794605855, 252.3470396676862, 259.92793879324444]
# INFO:large_gcs.algorithms.gcs_astar_convex_restriction:
# n_vertices_visited: 5, n_edges_visited: 3, n_vertices_explored: 159, vertex_coverage: 0.0276, edge_coverage: 0.0005, time_wall_clock: 3.99, n_gcs_solves: 160, gcs_solve_time_total: 3.48, gcs_solve_time_iter_mean: 0.0217, gcs_solve_time_last_10_mean: 0.0194, gcs_solve_time_iter_std: 0.00347, gcs_solve_time_iter_min: 0.017, gcs_solve_time_iter_max: 0.0374, n_vertices_revisited: 1, n_vertices_reexplored: 1
# now exploring node ('NC|obs0_f0-obj0_v3', 'NC|obs0_f2-rob0_v0', 'NC|obj0_f3-rob0_v0')'s 63 neighbors (241.87381135426023)
# INFO:large_gcs.algorithms.gcs_astar_convex_restriction:Top 10 pq costs: [242.03952684324568, 242.0487383257758, 244.77398981607567, 244.8789439865949, 244.87894534934293, 245.7739997683196, 245.8789443691765, 251.84254974633157, 252.34703794605855, 252.3470396676862]
# INFO:large_gcs.algorithms.gcs_astar_convex_restriction:
# n_vertices_visited: 5, n_edges_visited: 3, n_vertices_explored: 220, vertex_coverage: 0.0276, edge_coverage: 0.0005, time_wall_clock: 5.57, n_gcs_solves: 221, gcs_solve_time_total: 4.88, gcs_solve_time_iter_mean: 0.0221, gcs_solve_time_last_10_mean: 0.0193, gcs_solve_time_iter_std: 0.00362, gcs_solve_time_iter_min: 0.017, gcs_solve_time_iter_max: 0.0374, n_vertices_revisited: 2, n_vertices_reexplored: 1
# now exploring node ('NC|obs0_f0-obj0_v3', 'NC|obs0_f2-rob0_v0', 'NC|obj0_f0-rob0_v1')'s 43 neighbors (242.03952684324568)
# INFO:large_gcs.algorithms.gcs_astar_convex_restriction:Top 10 pq costs: [242.0487383257758, 244.77398981607567, 244.8789439865949, 244.87894534934293, 245.7739997683196, 245.8789443691765, 245.87894539497904, 251.84254974633157, 252.34703794605855, 252.3470396676862]
# INFO:large_gcs.algorithms.gcs_astar_convex_restriction:
# n_vertices_visited: 6, n_edges_visited: 2, n_vertices_explored: 261, vertex_coverage: 0.0331, edge_coverage: 0.0003, time_wall_clock: 6.64, n_gcs_solves: 262, gcs_solve_time_total: 5.81, gcs_solve_time_iter_mean: 0.0222, gcs_solve_time_last_10_mean: 0.022, gcs_solve_time_iter_std: 0.00363, gcs_solve_time_iter_min: 0.017, gcs_solve_time_iter_max: 0.0374, n_vertices_revisited: 2, n_vertices_reexplored: 1
# now exploring node ('NC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'NC|obj0_f0-rob0_v1')'s 67 neighbors (242.0487383257758)
# INFO:large_gcs.algorithms.gcs_astar_convex_restriction:Top 10 pq costs: [100.880913144764, 241.87381081721614, 242.03952025196955, 244.77398981607567, 244.8789439865949, 244.87894534934293, 245.7739997683196, 245.8789443691765, 245.87894539497904, 251.84254974633157]
# INFO:large_gcs.algorithms.gcs_astar_convex_restriction:
# n_vertices_visited: 7, n_edges_visited: 3, n_vertices_explored: 325, vertex_coverage: 0.0387, edge_coverage: 0.0005, time_wall_clock: 8.31, n_gcs_solves: 328, gcs_solve_time_total: 7.27, gcs_solve_time_iter_mean: 0.0222, gcs_solve_time_last_10_mean: 0.0246, gcs_solve_time_iter_std: 0.00359, gcs_solve_time_iter_min: 0.017, gcs_solve_time_iter_max: 0.0374, n_vertices_revisited: 2, n_vertices_reexplored: 3
# now exploring node ('NC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'IC|obj0_f1-rob0_f1')'s 67 neighbors (100.880913144764)
# INFO:large_gcs.algorithms.gcs_astar_convex_restriction:Top 10 pq costs: [63.73091044150253, 92.10647160605136, 96.54173188574, 96.54173472554182, 101.88091290870672, 101.88091617495418, 102.26012477815702, 103.5451423018186, 103.54514342192242, 103.5451475545022]
# INFO:large_gcs.algorithms.gcs_astar_convex_restriction:
# n_vertices_visited: 8, n_edges_visited: 4, n_vertices_explored: 390, vertex_coverage: 0.0442, edge_coverage: 0.0006, time_wall_clock: 10, n_gcs_solves: 394, gcs_solve_time_total: 8.76, gcs_solve_time_iter_mean: 0.0222, gcs_solve_time_last_10_mean: 0.0235, gcs_solve_time_iter_std: 0.00371, gcs_solve_time_iter_min: 0.017, gcs_solve_time_iter_max: 0.0409, n_vertices_revisited: 2, n_vertices_reexplored: 4
# now exploring node ('IC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'IC|obj0_f1-rob0_f1')'s 35 neighbors (63.73091044150253)
# INFO:large_gcs.algorithms.gcs_astar_convex_restriction:Top 10 pq costs: [54.74194031993999, 64.73090752723701, 64.7309077773652, 64.73091066316351, 64.73091164088778, 64.73091190077265, 64.73091381298153, 65.26806771455041, 65.36138067368688, 65.36138080807254]
# INFO:large_gcs.algorithms.gcs_astar_convex_restriction:
# n_vertices_visited: 9, n_edges_visited: 5, n_vertices_explored: 423, vertex_coverage: 0.0497, edge_coverage: 0.0008, time_wall_clock: 11, n_gcs_solves: 427, gcs_solve_time_total: 9.61, gcs_solve_time_iter_mean: 0.0225, gcs_solve_time_last_10_mean: 0.0282, gcs_solve_time_iter_std: 0.00405, gcs_solve_time_iter_min: 0.017, gcs_solve_time_iter_max: 0.0438, n_vertices_revisited: 2, n_vertices_reexplored: 4
# now exploring node ('IC|obs0_v0-obj0_f2', 'NC|obs0_f0-rob0_v1', 'IC|obj0_f1-rob0_f1')'s 25 neighbors (54.74194031993999)
# INFO:large_gcs.algorithms.gcs_astar_convex_restriction:Top 10 pq costs: [38.822837017371064, 38.82283711426717, 55.74193974153909, 55.80142046772013, 55.80142240294822, 55.80142426143542, 55.80142426153576, 59.407802312099726, 59.40862738012315, 59.40862825626829]
# INFO:large_gcs.algorithms.gcs_astar_convex_restriction:
# n_vertices_visited: 10, n_edges_visited: 6, n_vertices_explored: 445, vertex_coverage: 0.0552, edge_coverage: 0.0009, time_wall_clock: 11.6, n_gcs_solves: 449, gcs_solve_time_total: 10.2, gcs_solve_time_iter_mean: 0.0227, gcs_solve_time_last_10_mean: 0.0261, gcs_solve_time_iter_std: 0.00412, gcs_solve_time_iter_min: 0.017, gcs_solve_time_iter_max: 0.0438, n_vertices_revisited: 2, n_vertices_reexplored: 4
# now exploring node ('NC|obs0_f2-obj0_f1', 'NC|obs0_f0-rob0_v1', 'IC|obj0_f0-rob0_v1')'s 35 neighbors (38.822837017371064)
# INFO:large_gcs.algorithms.gcs_astar_convex_restriction:Top 10 pq costs: [34.34955030938746, 34.34955144476057, 35.18674900974683, 38.82283711426717, 39.822836449827065, 39.822838149473306, 39.822838827861325, 39.82283980072, 39.822839800895544, 39.822840016976805]
# INFO:large_gcs.algorithms.gcs_astar_convex_restriction:
# n_vertices_visited: 11, n_edges_visited: 7, n_vertices_explored: 476, vertex_coverage: 0.0608, edge_coverage: 0.0011, time_wall_clock: 12.6, n_gcs_solves: 481, gcs_solve_time_total: 11, gcs_solve_time_iter_mean: 0.0229, gcs_solve_time_last_10_mean: 0.0241, gcs_solve_time_iter_std: 0.00414, gcs_solve_time_iter_min: 0.017, gcs_solve_time_iter_max: 0.0438, n_vertices_revisited: 2, n_vertices_reexplored: 5
# now exploring node ('NC|obs0_f2-obj0_f1', 'NC|obs0_f2-rob0_v0', 'IC|obj0_f0-rob0_v1')'s 49 neighbors (34.34955030938746)
# INFO:large_gcs.algorithms.gcs_astar_convex_restriction:Top 10 pq costs: [34.34955144476057, 34.96898131461636, 35.01053103174262, 35.18674900974683, 35.321776169575294, 35.321777450372835, 35.34955043042763, 38.82283711426717, 39.822836449827065, 39.822838149473306]
# INFO:large_gcs.algorithms.gcs_astar_convex_restriction:
# n_vertices_visited: 12, n_edges_visited: 7, n_vertices_explored: 521, vertex_coverage: 0.0663, edge_coverage: 0.0011, time_wall_clock: 14, n_gcs_solves: 527, gcs_solve_time_total: 12.3, gcs_solve_time_iter_mean: 0.0234, gcs_solve_time_last_10_mean: 0.0253, gcs_solve_time_iter_std: 0.00436, gcs_solve_time_iter_min: 0.017, gcs_solve_time_iter_max: 0.0438, n_vertices_revisited: 2, n_vertices_reexplored: 6
# now exploring node ('IC|obs0_f2-obj0_f1', 'NC|obs0_f2-rob0_v0', 'IC|obj0_f0-rob0_v1')'s 23 neighbors (34.34955144476057)
# INFO:large_gcs.algorithms.gcs_astar_convex_restriction:Top 10 pq costs: [34.968980804395486, 34.96898131461636, 35.01053103174262, 35.01053215498521, 35.18674900974683, 35.32177386820385, 35.32177386842399, 35.321776169575294, 35.321777450372835, 35.34955043042763]
# INFO:large_gcs.algorithms.gcs_astar_convex_restriction:
# n_vertices_visited: 13, n_edges_visited: 8, n_vertices_explored: 542, vertex_coverage: 0.0718, edge_coverage: 0.0012, time_wall_clock: 14.8, n_gcs_solves: 549, gcs_solve_time_total: 12.9, gcs_solve_time_iter_mean: 0.0236, gcs_solve_time_last_10_mean: 0.0292, gcs_solve_time_iter_std: 0.00446, gcs_solve_time_iter_min: 0.017, gcs_solve_time_iter_max: 0.0438, n_vertices_revisited: 2, n_vertices_reexplored: 7
# now exploring node ('IC|obs0_f2-obj0_f1', 'NC|obs0_f2-rob0_v0', 'IC|obj0_v0-rob0_f0')'s 45 neighbors (34.968980804395486)
# INFO:large_gcs.algorithms.gcs_astar_convex_restriction:Convex Restriction Gcs A* complete!
# cost: 37.17068292599849, time: 0.03001093864440918
# vertex path: ['source'
#  "('NC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'NC|obj0_f3-rob0_v0')"
#  "('NC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'NC|obj0_f0-rob0_v1')"
#  "('NC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'IC|obj0_f1-rob0_f1')"
#  "('IC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'IC|obj0_f1-rob0_f1')"
#  "('IC|obs0_v0-obj0_f2', 'NC|obs0_f0-rob0_v1', 'IC|obj0_f1-rob0_f1')"
#  "('NC|obs0_f2-obj0_f1', 'NC|obs0_f0-rob0_v1', 'IC|obj0_f0-rob0_v1')"
#  "('IC|obs0_f2-obj0_f1', 'NC|obs0_f2-rob0_v0', 'IC|obj0_f0-rob0_v1')"
#  "('IC|obs0_f2-obj0_f1', 'NC|obs0_f2-rob0_v0', 'IC|obj0_v0-rob0_f0')"
#  "('NC|obs0_f2-obj0_f1', 'NC|obs0_f2-rob0_v0', 'NC|obj0_f3-rob0_v0')"
#  'target']
# n_vertices_visited: 13, n_edges_visited: 8, n_vertices_explored: 584, vertex_coverage: 0.0718, edge_coverage: 0.0012, time_wall_clock: 16.3, n_gcs_solves: 592, gcs_solve_time_total: 14.3, gcs_solve_time_iter_mean: 0.0241, gcs_solve_time_last_10_mean: 0.0305, gcs_solve_time_iter_std: 0.00489, gcs_solve_time_iter_min: 0.017, gcs_solve_time_iter_max: 0.0463, n_vertices_revisited: 2, n_vertices_reexplored: 8
