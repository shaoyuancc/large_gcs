# %%
from large_gcs.graph_generators.contact_graph_generator import (
    ContactGraphGeneratorParams,
    ContactGraphGenerator,
)
from large_gcs.graph.contact_graph import ContactGraph
from large_gcs.algorithms.gcs_astar_convex_restriction import GcsAstarConvexRestriction
from large_gcs.graph.contact_cost_constraint_factory import (
    contact_shortcut_edge_cost_factory_over_obj_weighted,
)

import numpy as np

np.set_printoptions(formatter={"float": lambda x: "{0:0.3f}".format(x)})
import logging

logging.basicConfig(level=logging.INFO)

# %%
cg = ContactGraph.load_from_file(
    ContactGraphGeneratorParams.graph_file_path_from_name("cg_trichal2")
)
# Out:
# INFO:large_gcs.graph.contact_graph:Loading 20 contact pair modes for 3 bodies...
# INFO:large_gcs.graph.contact_graph:Generating contact sets for 179 sets...
# 100%|██████████| 179/179 [00:02<00:00, 81.08it/s]
# INFO:large_gcs.graph.contact_graph:Creating vertex costs...
# 100%|██████████| 181/181 [00:00<00:00, 7612.09it/s]
# INFO:large_gcs.graph.graph:Adding 181 vertices to graph...
# 100%|██████████| 181/181 [00:00<00:00, 6373.73it/s]
# INFO:large_gcs.graph.contact_graph:Creating edge costs...
# 100%|██████████| 6408/6408 [00:00<00:00, 8854.33it/s]
# INFO:large_gcs.graph.contact_graph:Creating edge constraints...
# 100%|██████████| 6408/6408 [00:01<00:00, 4016.50it/s]
# INFO:large_gcs.graph.graph:Adding 6408 edges to graph...
# 100%|██████████| 6408/6408 [00:01<00:00, 3913.19it/s]
# INFO:large_gcs.graph.contact_graph:Created contact graph: GraphParams(dim_bounds=(4, 18), n_vertices=181, n_edges=6408, source=[array([3.250, 0.000]), array([1.500, 0.500])], target=[array([-1.500, 0.000]), array([-3,  0])], workspace=array([[-4,  4],
#        [-3,  3]]), default_costs_constraints=None)

# %%
cg.plot()

# %%
gviz = cg.graphviz()
gviz.format = "pdf"
gviz.render("cg_trichal2", view=False)
# Out:
# 'cg_trichal2.pdf'

# %%
alg = GcsAstarConvexRestriction(cg, shortcut_edge_cost_factory=contact_shortcut_edge_cost_factory_over_obj_weighted)
sol = alg.run()
sol.vertex_path
# Out:
# INFO:large_gcs.algorithms.gcs_astar_convex_restriction:Running GcsAstarConvexRestriction, should_rexplore: False, use_convex_relaxation: False, shortcut_edge_cost_factory: contact_shortcut_edge_cost_factory_over_obj_weighted
# INFO:large_gcs.algorithms.gcs_astar_convex_restriction:
# n_vertices_visited: 2, n_edges_visited: 0, n_vertices_explored: 0, vertex_coverage: 0.011, edge_coverage: 0, time_wall_clock: 0, n_gcs_solves: 0, gcs_solve_time_total: 0, gcs_solve_time_iter_mean: 0, gcs_solve_time_last_10_mean: 0, gcs_solve_time_iter_std: 0, gcs_solve_time_iter_min: inf, gcs_solve_time_iter_max: 0, n_vertices_revisited: 0, n_vertices_reexplored: 0
# now exploring node source's 1 neighbors (0)
# INFO:large_gcs.algorithms.gcs_astar_convex_restriction:
# n_vertices_visited: 3, n_edges_visited: 1, n_vertices_explored: 1, vertex_coverage: 0.0166, edge_coverage: 0.0002, time_wall_clock: 0.0215, n_gcs_solves: 1, gcs_solve_time_total: 0.0176, gcs_solve_time_iter_mean: 0.0176, gcs_solve_time_last_10_mean: 0, gcs_solve_time_iter_std: 0, gcs_solve_time_iter_min: 0.0176, gcs_solve_time_iter_max: 0.0176, n_vertices_revisited: 0, n_vertices_reexplored: 0
# now exploring node ('NC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'NC|obj0_f3-rob0_v0')'s 56 neighbors (241.04873818714518)
# INFO:large_gcs.algorithms.gcs_astar_convex_restriction:
# n_vertices_visited: 4, n_edges_visited: 2, n_vertices_explored: 56, vertex_coverage: 0.0221, edge_coverage: 0.0003, time_wall_clock: 0.6, n_gcs_solves: 56, gcs_solve_time_total: 0.525, gcs_solve_time_iter_mean: 0.00937, gcs_solve_time_last_10_mean: 0.00824, gcs_solve_time_iter_std: 0.00161, gcs_solve_time_iter_min: 0.00771, gcs_solve_time_iter_max: 0.0176, n_vertices_revisited: 0, n_vertices_reexplored: 0
# now exploring node ('NC|obs0_f0-obj0_v3', 'NC|obs0_f2-rob0_v0', 'NC|obj0_f3-rob0_v0')'s 63 neighbors (240.87381507616544)
# INFO:large_gcs.algorithms.gcs_astar_convex_restriction:
# n_vertices_visited: 5, n_edges_visited: 2, n_vertices_explored: 118, vertex_coverage: 0.0276, edge_coverage: 0.0003, time_wall_clock: 1.24, n_gcs_solves: 118, gcs_solve_time_total: 1.09, gcs_solve_time_iter_mean: 0.00925, gcs_solve_time_last_10_mean: 0.00994, gcs_solve_time_iter_std: 0.00127, gcs_solve_time_iter_min: 0.00771, gcs_solve_time_iter_max: 0.0176, n_vertices_revisited: 0, n_vertices_reexplored: 0
# now exploring node ('NC|obs0_f0-obj0_v3', 'NC|obs0_f2-rob0_v0', 'NC|obj0_f0-rob0_v1')'s 43 neighbors (241.03951911905648)
# INFO:large_gcs.algorithms.gcs_astar_convex_restriction:
# n_vertices_visited: 6, n_edges_visited: 2, n_vertices_explored: 159, vertex_coverage: 0.0331, edge_coverage: 0.0003, time_wall_clock: 1.72, n_gcs_solves: 159, gcs_solve_time_total: 1.51, gcs_solve_time_iter_mean: 0.00949, gcs_solve_time_last_10_mean: 0.0109, gcs_solve_time_iter_std: 0.00126, gcs_solve_time_iter_min: 0.00771, gcs_solve_time_iter_max: 0.0176, n_vertices_revisited: 0, n_vertices_reexplored: 0
# now exploring node ('NC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'NC|obj0_f0-rob0_v1')'s 67 neighbors (242.0487383257758)
# INFO:large_gcs.algorithms.gcs_astar_convex_restriction:
# n_vertices_visited: 7, n_edges_visited: 3, n_vertices_explored: 223, vertex_coverage: 0.0387, edge_coverage: 0.0005, time_wall_clock: 2.44, n_gcs_solves: 223, gcs_solve_time_total: 2.14, gcs_solve_time_iter_mean: 0.00958, gcs_solve_time_last_10_mean: 0.00974, gcs_solve_time_iter_std: 0.00116, gcs_solve_time_iter_min: 0.00771, gcs_solve_time_iter_max: 0.0176, n_vertices_revisited: 0, n_vertices_reexplored: 0
# now exploring node ('NC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'IC|obj0_f1-rob0_f1')'s 67 neighbors (100.880913144764)
# INFO:large_gcs.algorithms.gcs_astar_convex_restriction:
# n_vertices_visited: 8, n_edges_visited: 4, n_vertices_explored: 288, vertex_coverage: 0.0442, edge_coverage: 0.0006, time_wall_clock: 3.13, n_gcs_solves: 288, gcs_solve_time_total: 2.75, gcs_solve_time_iter_mean: 0.00955, gcs_solve_time_last_10_mean: 0.00936, gcs_solve_time_iter_std: 0.00109, gcs_solve_time_iter_min: 0.00771, gcs_solve_time_iter_max: 0.0176, n_vertices_revisited: 0, n_vertices_reexplored: 0
# now exploring node ('IC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'IC|obj0_f1-rob0_f1')'s 35 neighbors (63.73091044150253)
# INFO:large_gcs.algorithms.gcs_astar_convex_restriction:
# n_vertices_visited: 9, n_edges_visited: 5, n_vertices_explored: 321, vertex_coverage: 0.0497, edge_coverage: 0.0008, time_wall_clock: 3.58, n_gcs_solves: 321, gcs_solve_time_total: 3.14, gcs_solve_time_iter_mean: 0.00979, gcs_solve_time_last_10_mean: 0.0101, gcs_solve_time_iter_std: 0.00206, gcs_solve_time_iter_min: 0.00771, gcs_solve_time_iter_max: 0.0394, n_vertices_revisited: 0, n_vertices_reexplored: 0
# now exploring node ('IC|obs0_v0-obj0_f2', 'NC|obs0_f0-rob0_v1', 'IC|obj0_f1-rob0_f1')'s 25 neighbors (54.74194031993999)
# INFO:large_gcs.algorithms.gcs_astar_convex_restriction:
# n_vertices_visited: 10, n_edges_visited: 6, n_vertices_explored: 343, vertex_coverage: 0.0552, edge_coverage: 0.0009, time_wall_clock: 3.85, n_gcs_solves: 343, gcs_solve_time_total: 3.39, gcs_solve_time_iter_mean: 0.00988, gcs_solve_time_last_10_mean: 0.0109, gcs_solve_time_iter_std: 0.00202, gcs_solve_time_iter_min: 0.00771, gcs_solve_time_iter_max: 0.0394, n_vertices_revisited: 0, n_vertices_reexplored: 0
# now exploring node ('NC|obs0_f2-obj0_f1', 'NC|obs0_f0-rob0_v1', 'IC|obj0_f0-rob0_v1')'s 35 neighbors (38.822837017371064)
# INFO:large_gcs.algorithms.gcs_astar_convex_restriction:
# n_vertices_visited: 11, n_edges_visited: 7, n_vertices_explored: 374, vertex_coverage: 0.0608, edge_coverage: 0.0011, time_wall_clock: 4.3, n_gcs_solves: 374, gcs_solve_time_total: 3.78, gcs_solve_time_iter_mean: 0.0101, gcs_solve_time_last_10_mean: 0.012, gcs_solve_time_iter_std: 0.00254, gcs_solve_time_iter_min: 0.00771, gcs_solve_time_iter_max: 0.0394, n_vertices_revisited: 0, n_vertices_reexplored: 0
# now exploring node ('NC|obs0_f2-obj0_f1', 'NC|obs0_f2-rob0_v0', 'IC|obj0_f0-rob0_v1')'s 49 neighbors (34.34955030938746)
# INFO:large_gcs.algorithms.gcs_astar_convex_restriction:
# n_vertices_visited: 12, n_edges_visited: 7, n_vertices_explored: 419, vertex_coverage: 0.0663, edge_coverage: 0.0011, time_wall_clock: 4.92, n_gcs_solves: 419, gcs_solve_time_total: 4.33, gcs_solve_time_iter_mean: 0.0103, gcs_solve_time_last_10_mean: 0.012, gcs_solve_time_iter_std: 0.00251, gcs_solve_time_iter_min: 0.00771, gcs_solve_time_iter_max: 0.0394, n_vertices_revisited: 0, n_vertices_reexplored: 0
# now exploring node ('IC|obs0_f2-obj0_f1', 'NC|obs0_f2-rob0_v0', 'IC|obj0_f0-rob0_v1')'s 23 neighbors (34.34955144476057)
# INFO:large_gcs.algorithms.gcs_astar_convex_restriction:
# n_vertices_visited: 13, n_edges_visited: 8, n_vertices_explored: 440, vertex_coverage: 0.0718, edge_coverage: 0.0012, time_wall_clock: 5.23, n_gcs_solves: 440, gcs_solve_time_total: 4.59, gcs_solve_time_iter_mean: 0.0104, gcs_solve_time_last_10_mean: 0.0121, gcs_solve_time_iter_std: 0.00251, gcs_solve_time_iter_min: 0.00771, gcs_solve_time_iter_max: 0.0394, n_vertices_revisited: 0, n_vertices_reexplored: 0
# now exploring node ('IC|obs0_f2-obj0_f1', 'NC|obs0_f2-rob0_v0', 'IC|obj0_v0-rob0_f0')'s 45 neighbors (34.968980804395486)
# INFO:large_gcs.algorithms.gcs_astar_convex_restriction:Convex Restriction Gcs A* complete!
# cost: 37.17068292599849, time: 0.01179814338684082
# vertex path: ['source'
#  "('NC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'NC|obj0_f3-rob0_v0')"
#  "('NC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'NC|obj0_f0-rob0_v1')"
#  "('NC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'IC|obj0_f1-rob0_f1')"
#  "('IC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'IC|obj0_f1-rob0_f1')"
#  "('IC|obs0_v0-obj0_f2', 'NC|obs0_f0-rob0_v1', 'IC|obj0_f1-rob0_f1')"
#  "('NC|obs0_f2-obj0_f1', 'NC|obs0_f0-rob0_v1', 'IC|obj0_f0-rob0_v1')"
#  "('IC|obs0_f2-obj0_f1', 'NC|obs0_f2-rob0_v0', 'IC|obj0_f0-rob0_v1')"
#  "('IC|obs0_f2-obj0_f1', 'NC|obs0_f2-rob0_v0', 'IC|obj0_v0-rob0_f0')"
#  "('NC|obs0_f2-obj0_f1', 'NC|obs0_f2-rob0_v0', 'NC|obj0_f3-rob0_v0')"
#  'target']
# n_vertices_visited: 13, n_edges_visited: 8, n_vertices_explored: 482, vertex_coverage: 0.0718, edge_coverage: 0.0012, time_wall_clock: 5.86, n_gcs_solves: 482, gcs_solve_time_total: 5.15, gcs_solve_time_iter_mean: 0.0107, gcs_solve_time_last_10_mean: 0.0129, gcs_solve_time_iter_std: 0.00253, gcs_solve_time_iter_min: 0.00771, gcs_solve_time_iter_max: 0.0394, n_vertices_revisited: 0, n_vertices_reexplored: 0
# ['source',
#  "('NC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'NC|obj0_f3-rob0_v0')",
#  "('NC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'NC|obj0_f0-rob0_v1')",
#  "('NC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'IC|obj0_f1-rob0_f1')",
#  "('IC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'IC|obj0_f1-rob0_f1')",
#  "('IC|obs0_v0-obj0_f2', 'NC|obs0_f0-rob0_v1', 'IC|obj0_f1-rob0_f1')",
#  "('NC|obs0_f2-obj0_f1', 'NC|obs0_f0-rob0_v1', 'IC|obj0_f0-rob0_v1')",
#  "('IC|obs0_f2-obj0_f1', 'NC|obs0_f2-rob0_v0', 'IC|obj0_f0-rob0_v1')",
#  "('IC|obs0_f2-obj0_f1', 'NC|obs0_f2-rob0_v0', 'IC|obj0_v0-rob0_f0')",
#  "('NC|obs0_f2-obj0_f1', 'NC|obs0_f2-rob0_v0', 'NC|obj0_f3-rob0_v0')",
#  'target']

# %%
cg = ContactGraph.load_from_file(
    ContactGraphGeneratorParams.graph_file_path_from_name("cg_trichal3")
)
cg.plot()
# Out:
# INFO:large_gcs.graph.contact_graph:Loading 20 contact pair modes for 3 bodies...
# INFO:large_gcs.graph.contact_graph:Generating contact sets for 179 sets...
# 100%|██████████| 179/179 [00:02<00:00, 82.06it/s]
# INFO:large_gcs.graph.contact_graph:Creating vertex costs...
# 100%|██████████| 181/181 [00:00<00:00, 7284.85it/s]
# INFO:large_gcs.graph.graph:Adding 181 vertices to graph...
# 100%|██████████| 181/181 [00:00<00:00, 6386.98it/s]
# INFO:large_gcs.graph.contact_graph:Creating edge costs...
# 100%|██████████| 6408/6408 [00:00<00:00, 8385.22it/s]
# INFO:large_gcs.graph.contact_graph:Creating edge constraints...
# 100%|██████████| 6408/6408 [00:01<00:00, 4323.35it/s]
# INFO:large_gcs.graph.graph:Adding 6408 edges to graph...
# 100%|██████████| 6408/6408 [00:01<00:00, 3641.87it/s]
# INFO:large_gcs.graph.contact_graph:Created contact graph: GraphParams(dim_bounds=(4, 18), n_vertices=181, n_edges=6408, source=[array([3.250, 0.000]), array([-3,  0])], target=[array([-1.500, 0.000]), array([1.500, 0.500])], workspace=array([[-4,  4],
#        [-3,  3]]), default_costs_constraints=None)

# %%
alg = GcsAstarConvexRestriction(cg, shortcut_edge_cost_factory=contact_shortcut_edge_cost_factory_over_obj_weighted)
sol = alg.run()
sol.vertex_path
# Out:
# INFO:large_gcs.algorithms.gcs_astar_convex_restriction:Running GcsAstarConvexRestriction, should_rexplore: False, use_convex_relaxation: False, shortcut_edge_cost_factory: contact_shortcut_edge_cost_factory_over_obj_weighted
# INFO:large_gcs.algorithms.gcs_astar_convex_restriction:
# n_vertices_visited: 2, n_edges_visited: 0, n_vertices_explored: 0, vertex_coverage: 0.011, edge_coverage: 0, time_wall_clock: 0, n_gcs_solves: 0, gcs_solve_time_total: 0, gcs_solve_time_iter_mean: 0, gcs_solve_time_last_10_mean: 0, gcs_solve_time_iter_std: 0, gcs_solve_time_iter_min: inf, gcs_solve_time_iter_max: 0, n_vertices_revisited: 0, n_vertices_reexplored: 0
# now exploring node source's 1 neighbors (0)
# INFO:large_gcs.algorithms.gcs_astar_convex_restriction:
# n_vertices_visited: 3, n_edges_visited: 1, n_vertices_explored: 1, vertex_coverage: 0.0166, edge_coverage: 0.0002, time_wall_clock: 0.0163, n_gcs_solves: 1, gcs_solve_time_total: 0.0125, gcs_solve_time_iter_mean: 0.0125, gcs_solve_time_last_10_mean: 0, gcs_solve_time_iter_std: 0, gcs_solve_time_iter_min: 0.0125, gcs_solve_time_iter_max: 0.0125, n_vertices_revisited: 0, n_vertices_reexplored: 0
# now exploring node ('NC|obs0_f0-obj0_v3', 'NC|obs0_f2-rob0_v0', 'NC|obj0_f3-rob0_v0')'s 64 neighbors (239.07936309279924)
# INFO:large_gcs.algorithms.gcs_astar_convex_restriction:
# n_vertices_visited: 4, n_edges_visited: 2, n_vertices_explored: 64, vertex_coverage: 0.0221, edge_coverage: 0.0003, time_wall_clock: 0.744, n_gcs_solves: 64, gcs_solve_time_total: 0.644, gcs_solve_time_iter_mean: 0.0101, gcs_solve_time_last_10_mean: 0.01, gcs_solve_time_iter_std: 0.00167, gcs_solve_time_iter_min: 0.00811, gcs_solve_time_iter_max: 0.0188, n_vertices_revisited: 0, n_vertices_reexplored: 0
# now exploring node ('NC|obs0_f0-obj0_v3', 'NC|obs0_f2-rob0_v0', 'NC|obj0_f2-rob0_f2')'s 49 neighbors (240.49069207067998)
# INFO:large_gcs.algorithms.gcs_astar_convex_restriction:
# n_vertices_visited: 5, n_edges_visited: 2, n_vertices_explored: 112, vertex_coverage: 0.0276, edge_coverage: 0.0003, time_wall_clock: 1.28, n_gcs_solves: 112, gcs_solve_time_total: 1.11, gcs_solve_time_iter_mean: 0.00995, gcs_solve_time_last_10_mean: 0.00925, gcs_solve_time_iter_std: 0.00139, gcs_solve_time_iter_min: 0.00811, gcs_solve_time_iter_max: 0.0188, n_vertices_revisited: 0, n_vertices_reexplored: 0
# now exploring node ('NC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'NC|obj0_f3-rob0_v0')'s 55 neighbors (240.8738114246021)
# INFO:large_gcs.algorithms.gcs_astar_convex_restriction:
# n_vertices_visited: 6, n_edges_visited: 2, n_vertices_explored: 165, vertex_coverage: 0.0331, edge_coverage: 0.0003, time_wall_clock: 1.94, n_gcs_solves: 165, gcs_solve_time_total: 1.7, gcs_solve_time_iter_mean: 0.0103, gcs_solve_time_last_10_mean: 0.0101, gcs_solve_time_iter_std: 0.00208, gcs_solve_time_iter_min: 0.00811, gcs_solve_time_iter_max: 0.0269, n_vertices_revisited: 0, n_vertices_reexplored: 0
# now exploring node ('NC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'NC|obj0_f0-rob0_v1')'s 67 neighbors (242.0330001989068)
# INFO:large_gcs.algorithms.gcs_astar_convex_restriction:
# n_vertices_visited: 7, n_edges_visited: 3, n_vertices_explored: 230, vertex_coverage: 0.0387, edge_coverage: 0.0005, time_wall_clock: 2.68, n_gcs_solves: 230, gcs_solve_time_total: 2.34, gcs_solve_time_iter_mean: 0.0102, gcs_solve_time_last_10_mean: 0.0101, gcs_solve_time_iter_std: 0.00181, gcs_solve_time_iter_min: 0.00811, gcs_solve_time_iter_max: 0.0269, n_vertices_revisited: 0, n_vertices_reexplored: 0
# now exploring node ('NC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'IC|obj0_f1-rob0_f1')'s 67 neighbors (88.84977179641656)
# INFO:large_gcs.algorithms.gcs_astar_convex_restriction:
# n_vertices_visited: 8, n_edges_visited: 4, n_vertices_explored: 295, vertex_coverage: 0.0442, edge_coverage: 0.0006, time_wall_clock: 3.45, n_gcs_solves: 295, gcs_solve_time_total: 3.01, gcs_solve_time_iter_mean: 0.0102, gcs_solve_time_last_10_mean: 0.00882, gcs_solve_time_iter_std: 0.00166, gcs_solve_time_iter_min: 0.00811, gcs_solve_time_iter_max: 0.0269, n_vertices_revisited: 0, n_vertices_reexplored: 0
# now exploring node ('IC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'IC|obj0_f1-rob0_f1')'s 35 neighbors (62.948706023663874)
# INFO:large_gcs.algorithms.gcs_astar_convex_restriction:
# n_vertices_visited: 9, n_edges_visited: 5, n_vertices_explored: 328, vertex_coverage: 0.0497, edge_coverage: 0.0008, time_wall_clock: 3.87, n_gcs_solves: 328, gcs_solve_time_total: 3.38, gcs_solve_time_iter_mean: 0.0103, gcs_solve_time_last_10_mean: 0.0115, gcs_solve_time_iter_std: 0.00162, gcs_solve_time_iter_min: 0.00811, gcs_solve_time_iter_max: 0.0269, n_vertices_revisited: 0, n_vertices_reexplored: 0
# now exploring node ('NC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'NC|obj0_f1-rob0_f1')'s 71 neighbors (63.89595014034576)
# INFO:large_gcs.algorithms.gcs_astar_convex_restriction:
# n_vertices_visited: 10, n_edges_visited: 5, n_vertices_explored: 395, vertex_coverage: 0.0552, edge_coverage: 0.0008, time_wall_clock: 4.69, n_gcs_solves: 395, gcs_solve_time_total: 4.1, gcs_solve_time_iter_mean: 0.0104, gcs_solve_time_last_10_mean: 0.00942, gcs_solve_time_iter_std: 0.00157, gcs_solve_time_iter_min: 0.00811, gcs_solve_time_iter_max: 0.0269, n_vertices_revisited: 0, n_vertices_reexplored: 0
# now exploring node ('IC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'NC|obj0_f1-rob0_f1')'s 37 neighbors (63.8959503382417)
# INFO:large_gcs.algorithms.gcs_astar_convex_restriction:
# n_vertices_visited: 11, n_edges_visited: 5, n_vertices_explored: 428, vertex_coverage: 0.0608, edge_coverage: 0.0008, time_wall_clock: 5.13, n_gcs_solves: 428, gcs_solve_time_total: 4.49, gcs_solve_time_iter_mean: 0.0105, gcs_solve_time_last_10_mean: 0.0106, gcs_solve_time_iter_std: 0.00159, gcs_solve_time_iter_min: 0.00811, gcs_solve_time_iter_max: 0.0269, n_vertices_revisited: 0, n_vertices_reexplored: 0
# now exploring node ('NC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'NC|obj0_f2-rob0_f2')'s 65 neighbors (63.89595101499849)
# INFO:large_gcs.algorithms.gcs_astar_convex_restriction:
# n_vertices_visited: 12, n_edges_visited: 5, n_vertices_explored: 486, vertex_coverage: 0.0663, edge_coverage: 0.0008, time_wall_clock: 5.82, n_gcs_solves: 486, gcs_solve_time_total: 5.09, gcs_solve_time_iter_mean: 0.0105, gcs_solve_time_last_10_mean: 0.00941, gcs_solve_time_iter_std: 0.00154, gcs_solve_time_iter_min: 0.00811, gcs_solve_time_iter_max: 0.0269, n_vertices_revisited: 0, n_vertices_reexplored: 0
# now exploring node ('IC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'NC|obj0_f2-rob0_f2')'s 29 neighbors (63.895955308222355)
# INFO:large_gcs.algorithms.gcs_astar_convex_restriction:
# n_vertices_visited: 13, n_edges_visited: 5, n_vertices_explored: 510, vertex_coverage: 0.0718, edge_coverage: 0.0008, time_wall_clock: 6.11, n_gcs_solves: 510, gcs_solve_time_total: 5.35, gcs_solve_time_iter_mean: 0.0105, gcs_solve_time_last_10_mean: 0.01, gcs_solve_time_iter_std: 0.00153, gcs_solve_time_iter_min: 0.00811, gcs_solve_time_iter_max: 0.0269, n_vertices_revisited: 0, n_vertices_reexplored: 0
# now exploring node ('IC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'IC|obj0_f2-rob0_f2')'s 27 neighbors (63.948702127669506)
# INFO:large_gcs.algorithms.gcs_astar_convex_restriction:
# n_vertices_visited: 14, n_edges_visited: 5, n_vertices_explored: 531, vertex_coverage: 0.0773, edge_coverage: 0.0008, time_wall_clock: 6.37, n_gcs_solves: 531, gcs_solve_time_total: 5.58, gcs_solve_time_iter_mean: 0.0105, gcs_solve_time_last_10_mean: 0.0105, gcs_solve_time_iter_std: 0.00152, gcs_solve_time_iter_min: 0.00811, gcs_solve_time_iter_max: 0.0269, n_vertices_revisited: 0, n_vertices_reexplored: 0
# now exploring node ('NC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'IC|obj0_f2-rob0_f2')'s 61 neighbors (63.948706005025436)
# INFO:large_gcs.algorithms.gcs_astar_convex_restriction:
# n_vertices_visited: 15, n_edges_visited: 5, n_vertices_explored: 582, vertex_coverage: 0.0829, edge_coverage: 0.0008, time_wall_clock: 6.96, n_gcs_solves: 582, gcs_solve_time_total: 6.1, gcs_solve_time_iter_mean: 0.0105, gcs_solve_time_last_10_mean: 0.00947, gcs_solve_time_iter_std: 0.00148, gcs_solve_time_iter_min: 0.00811, gcs_solve_time_iter_max: 0.0269, n_vertices_revisited: 0, n_vertices_reexplored: 0
# now exploring node ('IC|obs0_v0-obj0_f2', 'NC|obs0_f0-rob0_v1', 'IC|obj0_f1-rob0_f1')'s 25 neighbors (64.02498153512084)
# INFO:large_gcs.algorithms.gcs_astar_convex_restriction:
# n_vertices_visited: 16, n_edges_visited: 6, n_vertices_explored: 598, vertex_coverage: 0.0884, edge_coverage: 0.0009, time_wall_clock: 7.17, n_gcs_solves: 598, gcs_solve_time_total: 6.28, gcs_solve_time_iter_mean: 0.0105, gcs_solve_time_last_10_mean: 0.0111, gcs_solve_time_iter_std: 0.00147, gcs_solve_time_iter_min: 0.00811, gcs_solve_time_iter_max: 0.0269, n_vertices_revisited: 0, n_vertices_reexplored: 0
# now exploring node ('IC|obs0_f2-obj0_f1', 'NC|obs0_f0-rob0_v1', 'IC|obj0_f0-rob0_v1')'s 23 neighbors (50.841149845821434)
# INFO:large_gcs.algorithms.gcs_astar_convex_restriction:
# n_vertices_visited: 17, n_edges_visited: 7, n_vertices_explored: 620, vertex_coverage: 0.0939, edge_coverage: 0.0011, time_wall_clock: 7.47, n_gcs_solves: 620, gcs_solve_time_total: 6.54, gcs_solve_time_iter_mean: 0.0106, gcs_solve_time_last_10_mean: 0.0121, gcs_solve_time_iter_std: 0.00149, gcs_solve_time_iter_min: 0.00811, gcs_solve_time_iter_max: 0.0269, n_vertices_revisited: 0, n_vertices_reexplored: 0
# now exploring node ('NC|obs0_f2-obj0_f1', 'NC|obs0_f0-rob0_v1', 'NC|obj0_f0-rob0_v1')'s 58 neighbors (50.06336480373646)
# INFO:large_gcs.algorithms.gcs_astar_convex_restriction:
# n_vertices_visited: 18, n_edges_visited: 7, n_vertices_explored: 671, vertex_coverage: 0.0994, edge_coverage: 0.0011, time_wall_clock: 8.13, n_gcs_solves: 671, gcs_solve_time_total: 7.13, gcs_solve_time_iter_mean: 0.0106, gcs_solve_time_last_10_mean: 0.0108, gcs_solve_time_iter_std: 0.00149, gcs_solve_time_iter_min: 0.00811, gcs_solve_time_iter_max: 0.0269, n_vertices_revisited: 0, n_vertices_reexplored: 0
# now exploring node ('IC|obs0_f2-obj0_f1', 'NC|obs0_f0-rob0_v1', 'NC|obj0_f0-rob0_v1')'s 39 neighbors (50.06336480392952)
# INFO:large_gcs.algorithms.gcs_astar_convex_restriction:
# n_vertices_visited: 19, n_edges_visited: 6, n_vertices_explored: 707, vertex_coverage: 0.105, edge_coverage: 0.0009, time_wall_clock: 8.58, n_gcs_solves: 707, gcs_solve_time_total: 7.52, gcs_solve_time_iter_mean: 0.0106, gcs_solve_time_last_10_mean: 0.0116, gcs_solve_time_iter_std: 0.00148, gcs_solve_time_iter_min: 0.00811, gcs_solve_time_iter_max: 0.0269, n_vertices_revisited: 0, n_vertices_reexplored: 0
# now exploring node ('NC|obs0_f2-obj0_f1', 'NC|obs0_f0-rob0_v1', 'IC|obj0_f0-rob0_v1')'s 35 neighbors (50.8411515914913)
# INFO:large_gcs.algorithms.gcs_astar_convex_restriction:
# n_vertices_visited: 20, n_edges_visited: 7, n_vertices_explored: 735, vertex_coverage: 0.111, edge_coverage: 0.0011, time_wall_clock: 8.94, n_gcs_solves: 735, gcs_solve_time_total: 7.84, gcs_solve_time_iter_mean: 0.0107, gcs_solve_time_last_10_mean: 0.0108, gcs_solve_time_iter_std: 0.00147, gcs_solve_time_iter_min: 0.00811, gcs_solve_time_iter_max: 0.0269, n_vertices_revisited: 0, n_vertices_reexplored: 0
# now exploring node ('IC|obs0_f2-obj0_f1', 'NC|obs0_f2-rob0_v0', 'IC|obj0_f0-rob0_v1')'s 23 neighbors (51.56175670736194)
# INFO:large_gcs.algorithms.gcs_astar_convex_restriction:
# n_vertices_visited: 21, n_edges_visited: 7, n_vertices_explored: 754, vertex_coverage: 0.116, edge_coverage: 0.0011, time_wall_clock: 9.21, n_gcs_solves: 754, gcs_solve_time_total: 8.07, gcs_solve_time_iter_mean: 0.0107, gcs_solve_time_last_10_mean: 0.0116, gcs_solve_time_iter_std: 0.00148, gcs_solve_time_iter_min: 0.00811, gcs_solve_time_iter_max: 0.0269, n_vertices_revisited: 0, n_vertices_reexplored: 0
# now exploring node ('NC|obs0_f2-obj0_f1', 'NC|obs0_f2-rob0_v0', 'IC|obj0_f0-rob0_v1')'s 49 neighbors (51.56176264957443)
# INFO:large_gcs.algorithms.gcs_astar_convex_restriction:
# n_vertices_visited: 22, n_edges_visited: 7, n_vertices_explored: 795, vertex_coverage: 0.121, edge_coverage: 0.0011, time_wall_clock: 9.78, n_gcs_solves: 795, gcs_solve_time_total: 8.58, gcs_solve_time_iter_mean: 0.0108, gcs_solve_time_last_10_mean: 0.011, gcs_solve_time_iter_std: 0.00152, gcs_solve_time_iter_min: 0.00811, gcs_solve_time_iter_max: 0.0269, n_vertices_revisited: 0, n_vertices_reexplored: 0
# now exploring node ('NC|obs0_f2-obj0_f1', 'NC|obs0_f0-rob0_v1', 'IC|obj0_f1-rob0_f1')'s 31 neighbors (51.84115205007096)
# INFO:large_gcs.algorithms.gcs_astar_convex_restriction:
# n_vertices_visited: 23, n_edges_visited: 7, n_vertices_explored: 814, vertex_coverage: 0.127, edge_coverage: 0.0011, time_wall_clock: 10.1, n_gcs_solves: 814, gcs_solve_time_total: 8.82, gcs_solve_time_iter_mean: 0.0108, gcs_solve_time_last_10_mean: 0.0125, gcs_solve_time_iter_std: 0.00153, gcs_solve_time_iter_min: 0.00811, gcs_solve_time_iter_max: 0.0269, n_vertices_revisited: 0, n_vertices_reexplored: 0
# now exploring node ('IC|obs0_f2-obj0_f1', 'NC|obs0_f0-rob0_v1', 'IC|obj0_f1-rob0_f1')'s 11 neighbors (51.84115305151333)
# INFO:large_gcs.algorithms.gcs_astar_convex_restriction:
# n_vertices_visited: 24, n_edges_visited: 8, n_vertices_explored: 819, vertex_coverage: 0.133, edge_coverage: 0.0012, time_wall_clock: 10.1, n_gcs_solves: 819, gcs_solve_time_total: 8.87, gcs_solve_time_iter_mean: 0.0108, gcs_solve_time_last_10_mean: 0.0118, gcs_solve_time_iter_std: 0.00153, gcs_solve_time_iter_min: 0.00811, gcs_solve_time_iter_max: 0.0269, n_vertices_revisited: 0, n_vertices_reexplored: 0
# now exploring node ('NC|obs0_f2-obj0_f1', 'NC|obs0_f2-rob0_v0', 'NC|obj0_f0-rob0_v1')'s 66 neighbors (52.5617566256958)
# INFO:large_gcs.algorithms.gcs_astar_convex_restriction:
# n_vertices_visited: 25, n_edges_visited: 8, n_vertices_explored: 873, vertex_coverage: 0.138, edge_coverage: 0.0012, time_wall_clock: 10.9, n_gcs_solves: 873, gcs_solve_time_total: 9.58, gcs_solve_time_iter_mean: 0.011, gcs_solve_time_last_10_mean: 0.0133, gcs_solve_time_iter_std: 0.00161, gcs_solve_time_iter_min: 0.00811, gcs_solve_time_iter_max: 0.0269, n_vertices_revisited: 0, n_vertices_reexplored: 0
# now exploring node ('IC|obs0_f2-obj0_f1', 'NC|obs0_f2-rob0_v0', 'NC|obj0_f0-rob0_v1')'s 35 neighbors (52.56176418472749)
# INFO:large_gcs.algorithms.gcs_astar_convex_restriction:
# n_vertices_visited: 26, n_edges_visited: 8, n_vertices_explored: 901, vertex_coverage: 0.144, edge_coverage: 0.0012, time_wall_clock: 11.4, n_gcs_solves: 901, gcs_solve_time_total: 9.97, gcs_solve_time_iter_mean: 0.0111, gcs_solve_time_last_10_mean: 0.0138, gcs_solve_time_iter_std: 0.00166, gcs_solve_time_iter_min: 0.00811, gcs_solve_time_iter_max: 0.0269, n_vertices_revisited: 0, n_vertices_reexplored: 0
# now exploring node ('NC|obs0_f2-obj0_f1', 'NC|obs0_f2-rob0_v0', 'IC|obj0_v0-rob0_f0')'s 61 neighbors (55.84072765303095)
# INFO:large_gcs.algorithms.gcs_astar_convex_restriction:
# n_vertices_visited: 27, n_edges_visited: 8, n_vertices_explored: 951, vertex_coverage: 0.149, edge_coverage: 0.0012, time_wall_clock: 12.1, n_gcs_solves: 951, gcs_solve_time_total: 10.6, gcs_solve_time_iter_mean: 0.0112, gcs_solve_time_last_10_mean: 0.0129, gcs_solve_time_iter_std: 0.00169, gcs_solve_time_iter_min: 0.00811, gcs_solve_time_iter_max: 0.0269, n_vertices_revisited: 0, n_vertices_reexplored: 0
# now exploring node ('IC|obs0_f2-obj0_f1', 'NC|obs0_f2-rob0_v0', 'IC|obj0_v0-rob0_f0')'s 45 neighbors (55.840733367178636)
# INFO:large_gcs.algorithms.gcs_astar_convex_restriction:
# n_vertices_visited: 28, n_edges_visited: 9, n_vertices_explored: 987, vertex_coverage: 0.155, edge_coverage: 0.0014, time_wall_clock: 12.6, n_gcs_solves: 987, gcs_solve_time_total: 11.1, gcs_solve_time_iter_mean: 0.0112, gcs_solve_time_last_10_mean: 0.0121, gcs_solve_time_iter_std: 0.00168, gcs_solve_time_iter_min: 0.00811, gcs_solve_time_iter_max: 0.0269, n_vertices_revisited: 0, n_vertices_reexplored: 0
# now exploring node ('NC|obs0_f2-obj0_f1', 'NC|obs0_f2-rob0_v0', 'NC|obj0_f3-rob0_v0')'s 81 neighbors (60.274874990657395)
# INFO:large_gcs.algorithms.gcs_astar_convex_restriction:
# n_vertices_visited: 29, n_edges_visited: 10, n_vertices_explored: 1056, vertex_coverage: 0.16, edge_coverage: 0.0016, time_wall_clock: 13.6, n_gcs_solves: 1056, gcs_solve_time_total: 11.9, gcs_solve_time_iter_mean: 0.0113, gcs_solve_time_last_10_mean: 0.0125, gcs_solve_time_iter_std: 0.00167, gcs_solve_time_iter_min: 0.00811, gcs_solve_time_iter_max: 0.0269, n_vertices_revisited: 0, n_vertices_reexplored: 0
# now exploring node ('IC|obs0_f2-obj0_f1', 'NC|obs0_f2-rob0_v0', 'IC|obj0_f2-rob0_f2')'s 35 neighbors (58.11998698252877)
# INFO:large_gcs.algorithms.gcs_astar_convex_restriction:
# n_vertices_visited: 30, n_edges_visited: 10, n_vertices_explored: 1090, vertex_coverage: 0.166, edge_coverage: 0.0016, time_wall_clock: 14.1, n_gcs_solves: 1090, gcs_solve_time_total: 12.4, gcs_solve_time_iter_mean: 0.0113, gcs_solve_time_last_10_mean: 0.0132, gcs_solve_time_iter_std: 0.00168, gcs_solve_time_iter_min: 0.00811, gcs_solve_time_iter_max: 0.0269, n_vertices_revisited: 0, n_vertices_reexplored: 0
# now exploring node ('IC|obs0_f2-obj0_f1', 'NC|obs0_f2-rob0_v0', 'NC|obj0_f2-rob0_f2')'s 37 neighbors (58.11998758181016)
# INFO:large_gcs.algorithms.gcs_astar_convex_restriction:
# n_vertices_visited: 31, n_edges_visited: 10, n_vertices_explored: 1125, vertex_coverage: 0.171, edge_coverage: 0.0016, time_wall_clock: 14.6, n_gcs_solves: 1125, gcs_solve_time_total: 12.8, gcs_solve_time_iter_mean: 0.0114, gcs_solve_time_last_10_mean: 0.0132, gcs_solve_time_iter_std: 0.00169, gcs_solve_time_iter_min: 0.00811, gcs_solve_time_iter_max: 0.0269, n_vertices_revisited: 0, n_vertices_reexplored: 0
# now exploring node ('NC|obs0_f2-obj0_f1', 'NC|obs0_f2-rob0_v0', 'NC|obj0_f2-rob0_f2')'s 66 neighbors (58.11998758185594)
# INFO:large_gcs.algorithms.gcs_astar_convex_restriction:
# n_vertices_visited: 32, n_edges_visited: 10, n_vertices_explored: 1180, vertex_coverage: 0.177, edge_coverage: 0.0016, time_wall_clock: 15.4, n_gcs_solves: 1180, gcs_solve_time_total: 13.5, gcs_solve_time_iter_mean: 0.0114, gcs_solve_time_last_10_mean: 0.0122, gcs_solve_time_iter_std: 0.00168, gcs_solve_time_iter_min: 0.00811, gcs_solve_time_iter_max: 0.0269, n_vertices_revisited: 0, n_vertices_reexplored: 0
# now exploring node ('NC|obs0_f2-obj0_f1', 'NC|obs0_f2-rob0_v0', 'IC|obj0_f2-rob0_f2')'s 61 neighbors (58.11999114760587)
# INFO:large_gcs.algorithms.gcs_astar_convex_restriction:
# n_vertices_visited: 33, n_edges_visited: 9, n_vertices_explored: 1229, vertex_coverage: 0.182, edge_coverage: 0.0014, time_wall_clock: 16.1, n_gcs_solves: 1229, gcs_solve_time_total: 14.1, gcs_solve_time_iter_mean: 0.0115, gcs_solve_time_last_10_mean: 0.0124, gcs_solve_time_iter_std: 0.00168, gcs_solve_time_iter_min: 0.00811, gcs_solve_time_iter_max: 0.0269, n_vertices_revisited: 0, n_vertices_reexplored: 0
# now exploring node ('IC|obs0_f2-obj0_f1', 'NC|obs0_f2-rob0_v0', 'NC|obj0_f3-rob0_v0')'s 61 neighbors (60.27487499081138)
# INFO:large_gcs.algorithms.gcs_astar_convex_restriction:
# n_vertices_visited: 34, n_edges_visited: 9, n_vertices_explored: 1279, vertex_coverage: 0.188, edge_coverage: 0.0014, time_wall_clock: 16.8, n_gcs_solves: 1279, gcs_solve_time_total: 14.8, gcs_solve_time_iter_mean: 0.0116, gcs_solve_time_last_10_mean: 0.0143, gcs_solve_time_iter_std: 0.00168, gcs_solve_time_iter_min: 0.00811, gcs_solve_time_iter_max: 0.0269, n_vertices_revisited: 0, n_vertices_reexplored: 0
# now exploring node ('NC|obs0_f2-obj0_f1', 'NC|obs0_f2-rob0_v0', 'IC|obj0_f3-rob0_v0')'s 59 neighbors (60.274877926960706)
# INFO:large_gcs.algorithms.gcs_astar_convex_restriction:
# n_vertices_visited: 35, n_edges_visited: 9, n_vertices_explored: 1325, vertex_coverage: 0.193, edge_coverage: 0.0014, time_wall_clock: 17.5, n_gcs_solves: 1325, gcs_solve_time_total: 15.4, gcs_solve_time_iter_mean: 0.0116, gcs_solve_time_last_10_mean: 0.0122, gcs_solve_time_iter_std: 0.00168, gcs_solve_time_iter_min: 0.00811, gcs_solve_time_iter_max: 0.0269, n_vertices_revisited: 0, n_vertices_reexplored: 0
# now exploring node ('IC|obs0_f2-obj0_f1', 'NC|obs0_f2-rob0_v0', 'IC|obj0_f3-rob0_v0')'s 44 neighbors (60.27487792707343)
# INFO:large_gcs.algorithms.gcs_astar_convex_restriction:
# n_vertices_visited: 36, n_edges_visited: 11, n_vertices_explored: 1360, vertex_coverage: 0.199, edge_coverage: 0.0017, time_wall_clock: 18, n_gcs_solves: 1360, gcs_solve_time_total: 15.8, gcs_solve_time_iter_mean: 0.0116, gcs_solve_time_last_10_mean: 0.0131, gcs_solve_time_iter_std: 0.00168, gcs_solve_time_iter_min: 0.00811, gcs_solve_time_iter_max: 0.0269, n_vertices_revisited: 0, n_vertices_reexplored: 0
# now exploring node ('NC|obs0_f2-obj0_f1', 'NC|obs0_f1-rob0_f2', 'NC|obj0_f2-rob0_f2')'s 66 neighbors (60.77740122146425)
# INFO:large_gcs.algorithms.gcs_astar_convex_restriction:Convex Restriction Gcs A* complete!
# cost: 67.7088597142803, time: 0.014829158782958984
# vertex path: ['source'
#  "('NC|obs0_f0-obj0_v3', 'NC|obs0_f2-rob0_v0', 'NC|obj0_f3-rob0_v0')"
#  "('NC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'NC|obj0_f0-rob0_v1')"
#  "('NC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'IC|obj0_f1-rob0_f1')"
#  "('IC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'IC|obj0_f1-rob0_f1')"
#  "('IC|obs0_v0-obj0_f2', 'NC|obs0_f0-rob0_v1', 'IC|obj0_f1-rob0_f1')"
#  "('IC|obs0_f2-obj0_f1', 'NC|obs0_f0-rob0_v1', 'IC|obj0_f0-rob0_v1')"
#  "('NC|obs0_f2-obj0_f1', 'NC|obs0_f2-rob0_v0', 'IC|obj0_f0-rob0_v1')"
#  "('IC|obs0_f2-obj0_f1', 'NC|obs0_f2-rob0_v0', 'IC|obj0_v0-rob0_f0')"
#  "('NC|obs0_f2-obj0_f1', 'NC|obs0_f2-rob0_v0', 'NC|obj0_f3-rob0_v0')"
#  "('NC|obs0_f2-obj0_f1', 'NC|obs0_f2-rob0_v0', 'NC|obj0_f2-rob0_f2')"
#  "('NC|obs0_f2-obj0_f1', 'NC|obs0_f1-rob0_f2', 'NC|obj0_f2-rob0_f2')"
#  "('NC|obs0_f2-obj0_f1', 'NC|obs0_f0-rob0_v1', 'NC|obj0_f1-rob0_f1')"
#  'target']
# n_vertices_visited: 36, n_edges_visited: 11, n_vertices_explored: 1414, vertex_coverage: 0.199, edge_coverage: 0.0017, time_wall_clock: 18.9, n_gcs_solves: 1414, gcs_solve_time_total: 16.6, gcs_solve_time_iter_mean: 0.0117, gcs_solve_time_last_10_mean: 0.0145, gcs_solve_time_iter_std: 0.00173, gcs_solve_time_iter_min: 0.00811, gcs_solve_time_iter_max: 0.0269, n_vertices_revisited: 0, n_vertices_reexplored: 0
# ['source',
#  "('NC|obs0_f0-obj0_v3', 'NC|obs0_f2-rob0_v0', 'NC|obj0_f3-rob0_v0')",
#  "('NC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'NC|obj0_f0-rob0_v1')",
#  "('NC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'IC|obj0_f1-rob0_f1')",
#  "('IC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'IC|obj0_f1-rob0_f1')",
#  "('IC|obs0_v0-obj0_f2', 'NC|obs0_f0-rob0_v1', 'IC|obj0_f1-rob0_f1')",
#  "('IC|obs0_f2-obj0_f1', 'NC|obs0_f0-rob0_v1', 'IC|obj0_f0-rob0_v1')",
#  "('NC|obs0_f2-obj0_f1', 'NC|obs0_f2-rob0_v0', 'IC|obj0_f0-rob0_v1')",
#  "('IC|obs0_f2-obj0_f1', 'NC|obs0_f2-rob0_v0', 'IC|obj0_v0-rob0_f0')",
#  "('NC|obs0_f2-obj0_f1', 'NC|obs0_f2-rob0_v0', 'NC|obj0_f3-rob0_v0')",
#  "('NC|obs0_f2-obj0_f1', 'NC|obs0_f2-rob0_v0', 'NC|obj0_f2-rob0_f2')",
#  "('NC|obs0_f2-obj0_f1', 'NC|obs0_f1-rob0_f2', 'NC|obj0_f2-rob0_f2')",
#  "('NC|obs0_f2-obj0_f1', 'NC|obs0_f0-rob0_v1', 'NC|obj0_f1-rob0_f1')",
#  'target']

# %%
cg = ContactGraph.load_from_file(
    ContactGraphGeneratorParams.graph_file_path_from_name("cg_maze_a2")
)
# Out:
# INFO:large_gcs.graph.contact_graph:Loading 35 contact pair modes for 4 bodies...
# INFO:large_gcs.graph.contact_graph:Generating contact sets for 1234 sets...
# 100%|██████████| 1234/1234 [00:16<00:00, 77.10it/s]
# INFO:large_gcs.graph.contact_graph:Creating vertex costs...
# 100%|██████████| 1236/1236 [00:00<00:00, 6738.37it/s]
# INFO:large_gcs.graph.graph:Adding 1236 vertices to graph...
# 100%|██████████| 1236/1236 [00:00<00:00, 6598.37it/s]
# INFO:large_gcs.graph.contact_graph:Creating edge costs...
# 100%|██████████| 98676/98676 [00:11<00:00, 8583.52it/s]
# INFO:large_gcs.graph.contact_graph:Creating edge constraints...
# 100%|██████████| 98676/98676 [00:22<00:00, 4330.61it/s]
# INFO:large_gcs.graph.graph:Adding 98676 edges to graph...
# 100%|██████████| 98676/98676 [00:26<00:00, 3752.98it/s]
# INFO:large_gcs.graph.contact_graph:Created contact graph: GraphParams(dim_bounds=(4, 18), n_vertices=1236, n_edges=98676, source=[array([1.600, 0.600]), array([3.250, 0.000])], target=[array([-2.300, -0.700]), array([-0.500, 2.000])], workspace=array([[-4,  4],
#        [-3,  3]]), default_costs_constraints=None)

# %%
cg.plot()

# %%
cg.outgoing_edges("source")
# Out:
# [Edge(u='source', v="('NC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f1-rob0_v2', 'NC|obj0_f1-rob0_f1')", costs=[<pydrake.solvers.LinearCost object at 0x194d53170>], constraints=[<pydrake.solvers.LinearEqualityConstraint object at 0x195b28130>], gcs_edge=<pydrake.geometry.optimization.GraphOfConvexSets.Edge object at 0x19737fc70>)]

# %%
cg.incoming_edges("target")
# Out:
# [Edge(u="('NC|obs0_f2-obj0_v1', 'NC|obs0_f1-rob0_v0', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f2-rob0_v0', 'NC|obj0_f1-rob0_f1')", v='target', costs=[<pydrake.solvers.LinearCost object at 0x1954e4df0>], constraints=[<pydrake.solvers.LinearEqualityConstraint object at 0x1962c7130>], gcs_edge=<pydrake.geometry.optimization.GraphOfConvexSets.Edge object at 0x198448d70>),
#  Edge(u="('NC|obs0_f2-obj0_v1', 'NC|obs0_f1-rob0_v0', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f2-rob0_v0', 'NC|obj0_f2-rob0_f2')", v='target', costs=[<pydrake.solvers.LinearCost object at 0x1954fcb30>], constraints=[<pydrake.solvers.LinearEqualityConstraint object at 0x1962b5d70>], gcs_edge=<pydrake.geometry.optimization.GraphOfConvexSets.Edge object at 0x19846f0b0>)]

# %%
for name in cg.vertex_names:
    print(name)
# Out:
# ('IC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'NC|obs1_f1-obj0_v0', 'NC|obs1_f0-rob0_v1', 'NC|obj0_f0-rob0_v1')
# ('IC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'NC|obs1_f1-obj0_v0', 'NC|obs1_f0-rob0_v1', 'NC|obj0_f1-rob0_f1')
# ('IC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'NC|obs1_f1-obj0_v0', 'NC|obs1_f0-rob0_v1', 'NC|obj0_f2-rob0_f2')
# ('IC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'NC|obs1_f1-obj0_v0', 'NC|obs1_f0-rob0_v1', 'NC|obj0_f3-rob0_v0')
# ('IC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'NC|obs1_f1-obj0_v0', 'NC|obs1_f1-rob0_v2', 'IC|obj0_f1-rob0_f1')
# ('IC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'NC|obs1_f1-obj0_v0', 'NC|obs1_f1-rob0_v2', 'IC|obj0_f2-rob0_f2')
# ('IC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'NC|obs1_f1-obj0_v0', 'NC|obs1_f1-rob0_v2', 'IC|obj0_f0-rob0_v1')
# ('IC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'NC|obs1_f1-obj0_v0', 'NC|obs1_f1-rob0_v2', 'NC|obj0_f0-rob0_v1')
# ('IC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'NC|obs1_f1-obj0_v0', 'NC|obs1_f1-rob0_v2', 'NC|obj0_f1-rob0_f1')
# ('IC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'NC|obs1_f1-obj0_v0', 'NC|obs1_f1-rob0_v2', 'NC|obj0_f2-rob0_f2')
# ('IC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'NC|obs1_f1-obj0_v0', 'NC|obs1_f2-rob0_v0', 'IC|obj0_f1-rob0_f1')
# ('IC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'NC|obs1_f1-obj0_v0', 'NC|obs1_f2-rob0_v0', 'IC|obj0_f2-rob0_f2')
# ('IC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'NC|obs1_f1-obj0_v0', 'NC|obs1_f2-rob0_v0', 'IC|obj0_v0-rob0_f0')
# ('IC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'NC|obs1_f1-obj0_v0', 'NC|obs1_f2-rob0_v0', 'NC|obj0_f0-rob0_v1')
# ('IC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'NC|obs1_f1-obj0_v0', 'NC|obs1_f2-rob0_v0', 'NC|obj0_f1-rob0_f1')
# ('IC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'NC|obs1_f1-obj0_v0', 'NC|obs1_f2-rob0_v0', 'NC|obj0_f2-rob0_f2')
# ('IC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'NC|obs1_f1-obj0_v0', 'NC|obs1_f2-rob0_v0', 'NC|obj0_f3-rob0_v0')
# ('IC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f0-rob0_v1', 'IC|obj0_f1-rob0_f1')
# ('IC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f0-rob0_v1', 'IC|obj0_f0-rob0_v1')
# ('IC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f0-rob0_v1', 'IC|obj0_v0-rob0_f0')
# ('IC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f0-rob0_v1', 'NC|obj0_f0-rob0_v1')
# ('IC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f0-rob0_v1', 'NC|obj0_f1-rob0_f1')
# ('IC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f0-rob0_v1', 'NC|obj0_f2-rob0_f2')
# ('IC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f0-rob0_v1', 'NC|obj0_f3-rob0_v0')
# ('IC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f1-rob0_v2', 'IC|obj0_f1-rob0_f1')
# ('IC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f1-rob0_v2', 'IC|obj0_f2-rob0_f2')
# ('IC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f1-rob0_v2', 'IC|obj0_f0-rob0_v1')
# ('IC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f1-rob0_v2', 'NC|obj0_f0-rob0_v1')
# ('IC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f1-rob0_v2', 'NC|obj0_f1-rob0_f1')
# ('IC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f1-rob0_v2', 'NC|obj0_f2-rob0_f2')
# ('IC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f2-rob0_v0', 'IC|obj0_f1-rob0_f1')
# ('IC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f2-rob0_v0', 'IC|obj0_f2-rob0_f2')
# ('IC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f2-rob0_v0', 'IC|obj0_v0-rob0_f0')
# ('IC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f2-rob0_v0', 'NC|obj0_f0-rob0_v1')
# ('IC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f2-rob0_v0', 'NC|obj0_f1-rob0_f1')
# ('IC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f2-rob0_v0', 'NC|obj0_f2-rob0_f2')
# ('IC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f2-rob0_v0', 'NC|obj0_f3-rob0_v0')
# ('IC|obs0_f0-obj0_v3', 'NC|obs0_f1-rob0_v0', 'NC|obs1_f1-obj0_v0', 'NC|obs1_f0-rob0_v1', 'NC|obj0_f0-rob0_v1')
# ('IC|obs0_f0-obj0_v3', 'NC|obs0_f1-rob0_v0', 'NC|obs1_f1-obj0_v0', 'NC|obs1_f0-rob0_v1', 'NC|obj0_f3-rob0_v0')
# ('IC|obs0_f0-obj0_v3', 'NC|obs0_f1-rob0_v0', 'NC|obs1_f1-obj0_v0', 'NC|obs1_f1-rob0_v2', 'NC|obj0_f1-rob0_f1')
# ('IC|obs0_f0-obj0_v3', 'NC|obs0_f1-rob0_v0', 'NC|obs1_f1-obj0_v0', 'NC|obs1_f1-rob0_v2', 'NC|obj0_f2-rob0_f2')
# ('IC|obs0_f0-obj0_v3', 'NC|obs0_f1-rob0_v0', 'NC|obs1_f1-obj0_v0', 'NC|obs1_f1-rob0_v2', 'NC|obj0_f3-rob0_v0')
# ('IC|obs0_f0-obj0_v3', 'NC|obs0_f1-rob0_v0', 'NC|obs1_f1-obj0_v0', 'NC|obs1_f2-rob0_v0', 'IC|obj0_f2-rob0_f2')
# ('IC|obs0_f0-obj0_v3', 'NC|obs0_f1-rob0_v0', 'NC|obs1_f1-obj0_v0', 'NC|obs1_f2-rob0_v0', 'IC|obj0_f3-rob0_v0')
# ('IC|obs0_f0-obj0_v3', 'NC|obs0_f1-rob0_v0', 'NC|obs1_f1-obj0_v0', 'NC|obs1_f2-rob0_v0', 'NC|obj0_f0-rob0_v1')
# ('IC|obs0_f0-obj0_v3', 'NC|obs0_f1-rob0_v0', 'NC|obs1_f1-obj0_v0', 'NC|obs1_f2-rob0_v0', 'NC|obj0_f1-rob0_f1')
# ('IC|obs0_f0-obj0_v3', 'NC|obs0_f1-rob0_v0', 'NC|obs1_f1-obj0_v0', 'NC|obs1_f2-rob0_v0', 'NC|obj0_f2-rob0_f2')
# ('IC|obs0_f0-obj0_v3', 'NC|obs0_f1-rob0_v0', 'NC|obs1_f1-obj0_v0', 'NC|obs1_f2-rob0_v0', 'NC|obj0_f3-rob0_v0')
# ('IC|obs0_f0-obj0_v3', 'NC|obs0_f1-rob0_v0', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f0-rob0_v1', 'NC|obj0_f0-rob0_v1')
# ('IC|obs0_f0-obj0_v3', 'NC|obs0_f1-rob0_v0', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f0-rob0_v1', 'NC|obj0_f3-rob0_v0')
# ('IC|obs0_f0-obj0_v3', 'NC|obs0_f1-rob0_v0', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f1-rob0_v2', 'NC|obj0_f1-rob0_f1')
# ('IC|obs0_f0-obj0_v3', 'NC|obs0_f1-rob0_v0', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f1-rob0_v2', 'NC|obj0_f2-rob0_f2')
# ('IC|obs0_f0-obj0_v3', 'NC|obs0_f1-rob0_v0', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f1-rob0_v2', 'NC|obj0_f3-rob0_v0')
# ('IC|obs0_f0-obj0_v3', 'NC|obs0_f1-rob0_v0', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f2-rob0_v0', 'IC|obj0_f2-rob0_f2')
# ('IC|obs0_f0-obj0_v3', 'NC|obs0_f1-rob0_v0', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f2-rob0_v0', 'IC|obj0_f3-rob0_v0')
# ('IC|obs0_f0-obj0_v3', 'NC|obs0_f1-rob0_v0', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f2-rob0_v0', 'NC|obj0_f0-rob0_v1')
# ('IC|obs0_f0-obj0_v3', 'NC|obs0_f1-rob0_v0', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f2-rob0_v0', 'NC|obj0_f1-rob0_f1')
# ('IC|obs0_f0-obj0_v3', 'NC|obs0_f1-rob0_v0', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f2-rob0_v0', 'NC|obj0_f2-rob0_f2')
# ('IC|obs0_f0-obj0_v3', 'NC|obs0_f1-rob0_v0', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f2-rob0_v0', 'NC|obj0_f3-rob0_v0')
# ('IC|obs0_f0-obj0_v3', 'NC|obs0_f2-rob0_v0', 'NC|obs1_f1-obj0_v0', 'NC|obs1_f0-rob0_v1', 'NC|obj0_f0-rob0_v1')
# ('IC|obs0_f0-obj0_v3', 'NC|obs0_f2-rob0_v0', 'NC|obs1_f1-obj0_v0', 'NC|obs1_f0-rob0_v1', 'NC|obj0_f3-rob0_v0')
# ('IC|obs0_f0-obj0_v3', 'NC|obs0_f2-rob0_v0', 'NC|obs1_f1-obj0_v0', 'NC|obs1_f1-rob0_v2', 'NC|obj0_f1-rob0_f1')
# ('IC|obs0_f0-obj0_v3', 'NC|obs0_f2-rob0_v0', 'NC|obs1_f1-obj0_v0', 'NC|obs1_f1-rob0_v2', 'NC|obj0_f2-rob0_f2')
# ('IC|obs0_f0-obj0_v3', 'NC|obs0_f2-rob0_v0', 'NC|obs1_f1-obj0_v0', 'NC|obs1_f1-rob0_v2', 'NC|obj0_f3-rob0_v0')
# ('IC|obs0_f0-obj0_v3', 'NC|obs0_f2-rob0_v0', 'NC|obs1_f1-obj0_v0', 'NC|obs1_f2-rob0_v0', 'NC|obj0_f0-rob0_v1')
# ('IC|obs0_f0-obj0_v3', 'NC|obs0_f2-rob0_v0', 'NC|obs1_f1-obj0_v0', 'NC|obs1_f2-rob0_v0', 'NC|obj0_f1-rob0_f1')
# ('IC|obs0_f0-obj0_v3', 'NC|obs0_f2-rob0_v0', 'NC|obs1_f1-obj0_v0', 'NC|obs1_f2-rob0_v0', 'NC|obj0_f2-rob0_f2')
# ('IC|obs0_f0-obj0_v3', 'NC|obs0_f2-rob0_v0', 'NC|obs1_f1-obj0_v0', 'NC|obs1_f2-rob0_v0', 'NC|obj0_f3-rob0_v0')
# ('IC|obs0_f0-obj0_v3', 'NC|obs0_f2-rob0_v0', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f0-rob0_v1', 'NC|obj0_f0-rob0_v1')
# ('IC|obs0_f0-obj0_v3', 'NC|obs0_f2-rob0_v0', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f0-rob0_v1', 'NC|obj0_f3-rob0_v0')
# ('IC|obs0_f0-obj0_v3', 'NC|obs0_f2-rob0_v0', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f1-rob0_v2', 'NC|obj0_f1-rob0_f1')
# ('IC|obs0_f0-obj0_v3', 'NC|obs0_f2-rob0_v0', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f1-rob0_v2', 'NC|obj0_f2-rob0_f2')
# ('IC|obs0_f0-obj0_v3', 'NC|obs0_f2-rob0_v0', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f1-rob0_v2', 'NC|obj0_f3-rob0_v0')
# ('IC|obs0_f0-obj0_v3', 'NC|obs0_f2-rob0_v0', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f2-rob0_v0', 'IC|obj0_f2-rob0_f2')
# ('IC|obs0_f0-obj0_v3', 'NC|obs0_f2-rob0_v0', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f2-rob0_v0', 'IC|obj0_f3-rob0_v0')
# ('IC|obs0_f0-obj0_v3', 'NC|obs0_f2-rob0_v0', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f2-rob0_v0', 'NC|obj0_f0-rob0_v1')
# ('IC|obs0_f0-obj0_v3', 'NC|obs0_f2-rob0_v0', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f2-rob0_v0', 'NC|obj0_f1-rob0_f1')
# ('IC|obs0_f0-obj0_v3', 'NC|obs0_f2-rob0_v0', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f2-rob0_v0', 'NC|obj0_f2-rob0_f2')
# ('IC|obs0_f0-obj0_v3', 'NC|obs0_f2-rob0_v0', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f2-rob0_v0', 'NC|obj0_f3-rob0_v0')
# ('IC|obs0_f1-obj0_v1', 'NC|obs0_f0-rob0_v1', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f0-rob0_v1', 'NC|obj0_f0-rob0_v1')
# ('IC|obs0_f1-obj0_v1', 'NC|obs0_f0-rob0_v1', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f0-rob0_v1', 'NC|obj0_f1-rob0_f1')
# ('IC|obs0_f1-obj0_v1', 'NC|obs0_f0-rob0_v1', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f0-rob0_v1', 'NC|obj0_f2-rob0_f2')
# ('IC|obs0_f1-obj0_v1', 'NC|obs0_f0-rob0_v1', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f0-rob0_v1', 'NC|obj0_f3-rob0_v0')
# ('IC|obs0_f1-obj0_v1', 'NC|obs0_f0-rob0_v1', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f1-rob0_v2', 'IC|obj0_f1-rob0_f1')
# ('IC|obs0_f1-obj0_v1', 'NC|obs0_f0-rob0_v1', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f1-rob0_v2', 'IC|obj0_f0-rob0_v1')
# ('IC|obs0_f1-obj0_v1', 'NC|obs0_f0-rob0_v1', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f1-rob0_v2', 'NC|obj0_f0-rob0_v1')
# ('IC|obs0_f1-obj0_v1', 'NC|obs0_f0-rob0_v1', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f1-rob0_v2', 'NC|obj0_f1-rob0_f1')
# ('IC|obs0_f1-obj0_v1', 'NC|obs0_f0-rob0_v1', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f1-rob0_v2', 'NC|obj0_f2-rob0_f2')
# ('IC|obs0_f1-obj0_v1', 'NC|obs0_f0-rob0_v1', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f2-rob0_v0', 'IC|obj0_f1-rob0_f1')
# ('IC|obs0_f1-obj0_v1', 'NC|obs0_f0-rob0_v1', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f2-rob0_v0', 'IC|obj0_f0-rob0_v1')
# ('IC|obs0_f1-obj0_v1', 'NC|obs0_f0-rob0_v1', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f2-rob0_v0', 'NC|obj0_f0-rob0_v1')
# ('IC|obs0_f1-obj0_v1', 'NC|obs0_f0-rob0_v1', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f2-rob0_v0', 'NC|obj0_f1-rob0_f1')
# ('IC|obs0_f1-obj0_v1', 'NC|obs0_f0-rob0_v1', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f2-rob0_v0', 'NC|obj0_f2-rob0_f2')
# ('IC|obs0_f1-obj0_v1', 'NC|obs0_f0-rob0_v1', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f2-rob0_v0', 'NC|obj0_f3-rob0_v0')
# ('IC|obs0_f1-obj0_v1', 'NC|obs0_f1-rob0_v0', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f0-rob0_v1', 'NC|obj0_f0-rob0_v1')
# ('IC|obs0_f1-obj0_v1', 'NC|obs0_f1-rob0_v0', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f0-rob0_v1', 'NC|obj0_f3-rob0_v0')
# ('IC|obs0_f1-obj0_v1', 'NC|obs0_f1-rob0_v0', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f1-rob0_v2', 'IC|obj0_f1-rob0_f1')
# ('IC|obs0_f1-obj0_v1', 'NC|obs0_f1-rob0_v0', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f1-rob0_v2', 'IC|obj0_f2-rob0_f2')
# ('IC|obs0_f1-obj0_v1', 'NC|obs0_f1-rob0_v0', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f1-rob0_v2', 'NC|obj0_f1-rob0_f1')
# ('IC|obs0_f1-obj0_v1', 'NC|obs0_f1-rob0_v0', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f1-rob0_v2', 'NC|obj0_f2-rob0_f2')
# ('IC|obs0_f1-obj0_v1', 'NC|obs0_f1-rob0_v0', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f1-rob0_v2', 'NC|obj0_f3-rob0_v0')
# ('IC|obs0_f1-obj0_v1', 'NC|obs0_f1-rob0_v0', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f2-rob0_v0', 'IC|obj0_f1-rob0_f1')
# ('IC|obs0_f1-obj0_v1', 'NC|obs0_f1-rob0_v0', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f2-rob0_v0', 'IC|obj0_f2-rob0_f2')
# ('IC|obs0_f1-obj0_v1', 'NC|obs0_f1-rob0_v0', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f2-rob0_v0', 'IC|obj0_f3-rob0_v0')
# ('IC|obs0_f1-obj0_v1', 'NC|obs0_f1-rob0_v0', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f2-rob0_v0', 'IC|obj0_v0-rob0_f0')
# ('IC|obs0_f1-obj0_v1', 'NC|obs0_f1-rob0_v0', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f2-rob0_v0', 'NC|obj0_f0-rob0_v1')
# ('IC|obs0_f1-obj0_v1', 'NC|obs0_f1-rob0_v0', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f2-rob0_v0', 'NC|obj0_f1-rob0_f1')
# ('IC|obs0_f1-obj0_v1', 'NC|obs0_f1-rob0_v0', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f2-rob0_v0', 'NC|obj0_f2-rob0_f2')
# ('IC|obs0_f1-obj0_v1', 'NC|obs0_f1-rob0_v0', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f2-rob0_v0', 'NC|obj0_f3-rob0_v0')
# ('IC|obs0_f1-obj0_v1', 'NC|obs0_f2-rob0_v0', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f0-rob0_v1', 'NC|obj0_f0-rob0_v1')
# ('IC|obs0_f1-obj0_v1', 'NC|obs0_f2-rob0_v0', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f0-rob0_v1', 'NC|obj0_f3-rob0_v0')
# ('IC|obs0_f1-obj0_v1', 'NC|obs0_f2-rob0_v0', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f1-rob0_v2', 'NC|obj0_f1-rob0_f1')
# ('IC|obs0_f1-obj0_v1', 'NC|obs0_f2-rob0_v0', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f1-rob0_v2', 'NC|obj0_f2-rob0_f2')
# ('IC|obs0_f1-obj0_v1', 'NC|obs0_f2-rob0_v0', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f1-rob0_v2', 'NC|obj0_f3-rob0_v0')
# ('IC|obs0_f1-obj0_v1', 'NC|obs0_f2-rob0_v0', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f2-rob0_v0', 'IC|obj0_f2-rob0_f2')
# ('IC|obs0_f1-obj0_v1', 'NC|obs0_f2-rob0_v0', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f2-rob0_v0', 'IC|obj0_f0-rob0_v1')
# ('IC|obs0_f1-obj0_v1', 'NC|obs0_f2-rob0_v0', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f2-rob0_v0', 'IC|obj0_f3-rob0_v0')
# ('IC|obs0_f1-obj0_v1', 'NC|obs0_f2-rob0_v0', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f2-rob0_v0', 'IC|obj0_v0-rob0_f0')
# ('IC|obs0_f1-obj0_v1', 'NC|obs0_f2-rob0_v0', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f2-rob0_v0', 'NC|obj0_f0-rob0_v1')
# ('IC|obs0_f1-obj0_v1', 'NC|obs0_f2-rob0_v0', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f2-rob0_v0', 'NC|obj0_f1-rob0_f1')
# ('IC|obs0_f1-obj0_v1', 'NC|obs0_f2-rob0_v0', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f2-rob0_v0', 'NC|obj0_f2-rob0_f2')
# ('IC|obs0_f1-obj0_v1', 'NC|obs0_f2-rob0_v0', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f2-rob0_v0', 'NC|obj0_f3-rob0_v0')
# ('IC|obs0_f2-obj0_v1', 'NC|obs0_f0-rob0_v1', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f0-rob0_v1', 'NC|obj0_f0-rob0_v1')
# ('IC|obs0_f2-obj0_v1', 'NC|obs0_f0-rob0_v1', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f0-rob0_v1', 'NC|obj0_f1-rob0_f1')
# ('IC|obs0_f2-obj0_v1', 'NC|obs0_f0-rob0_v1', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f0-rob0_v1', 'NC|obj0_f2-rob0_f2')
# ('IC|obs0_f2-obj0_v1', 'NC|obs0_f0-rob0_v1', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f0-rob0_v1', 'NC|obj0_f3-rob0_v0')
# ('IC|obs0_f2-obj0_v1', 'NC|obs0_f0-rob0_v1', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f1-rob0_v2', 'NC|obj0_f0-rob0_v1')
# ('IC|obs0_f2-obj0_v1', 'NC|obs0_f0-rob0_v1', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f1-rob0_v2', 'NC|obj0_f1-rob0_f1')
# ('IC|obs0_f2-obj0_v1', 'NC|obs0_f0-rob0_v1', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f1-rob0_v2', 'NC|obj0_f2-rob0_f2')
# ('IC|obs0_f2-obj0_v1', 'NC|obs0_f0-rob0_v1', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f2-rob0_v0', 'IC|obj0_f1-rob0_f1')
# ('IC|obs0_f2-obj0_v1', 'NC|obs0_f0-rob0_v1', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f2-rob0_v0', 'IC|obj0_f0-rob0_v1')
# ('IC|obs0_f2-obj0_v1', 'NC|obs0_f0-rob0_v1', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f2-rob0_v0', 'NC|obj0_f0-rob0_v1')
# ('IC|obs0_f2-obj0_v1', 'NC|obs0_f0-rob0_v1', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f2-rob0_v0', 'NC|obj0_f1-rob0_f1')
# ('IC|obs0_f2-obj0_v1', 'NC|obs0_f0-rob0_v1', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f2-rob0_v0', 'NC|obj0_f2-rob0_f2')
# ('IC|obs0_f2-obj0_v1', 'NC|obs0_f0-rob0_v1', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f2-rob0_v0', 'NC|obj0_f3-rob0_v0')
# ('IC|obs0_f2-obj0_v1', 'NC|obs0_f1-rob0_v0', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f0-rob0_v1', 'NC|obj0_f0-rob0_v1')
# ('IC|obs0_f2-obj0_v1', 'NC|obs0_f1-rob0_v0', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f0-rob0_v1', 'NC|obj0_f3-rob0_v0')
# ('IC|obs0_f2-obj0_v1', 'NC|obs0_f1-rob0_v0', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f1-rob0_v2', 'NC|obj0_f1-rob0_f1')
# ('IC|obs0_f2-obj0_v1', 'NC|obs0_f1-rob0_v0', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f1-rob0_v2', 'NC|obj0_f2-rob0_f2')
# ('IC|obs0_f2-obj0_v1', 'NC|obs0_f1-rob0_v0', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f1-rob0_v2', 'NC|obj0_f3-rob0_v0')
# ('IC|obs0_f2-obj0_v1', 'NC|obs0_f1-rob0_v0', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f2-rob0_v0', 'IC|obj0_f1-rob0_f1')
# ('IC|obs0_f2-obj0_v1', 'NC|obs0_f1-rob0_v0', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f2-rob0_v0', 'IC|obj0_f2-rob0_f2')
# ('IC|obs0_f2-obj0_v1', 'NC|obs0_f1-rob0_v0', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f2-rob0_v0', 'IC|obj0_f3-rob0_v0')
# ('IC|obs0_f2-obj0_v1', 'NC|obs0_f1-rob0_v0', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f2-rob0_v0', 'IC|obj0_v0-rob0_f0')
# ('IC|obs0_f2-obj0_v1', 'NC|obs0_f1-rob0_v0', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f2-rob0_v0', 'NC|obj0_f0-rob0_v1')
# ('IC|obs0_f2-obj0_v1', 'NC|obs0_f1-rob0_v0', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f2-rob0_v0', 'NC|obj0_f1-rob0_f1')
# ('IC|obs0_f2-obj0_v1', 'NC|obs0_f1-rob0_v0', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f2-rob0_v0', 'NC|obj0_f2-rob0_f2')
# ('IC|obs0_f2-obj0_v1', 'NC|obs0_f1-rob0_v0', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f2-rob0_v0', 'NC|obj0_f3-rob0_v0')
# ('IC|obs0_f2-obj0_v1', 'NC|obs0_f2-rob0_v0', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f0-rob0_v1', 'NC|obj0_f0-rob0_v1')
# ('IC|obs0_f2-obj0_v1', 'NC|obs0_f2-rob0_v0', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f0-rob0_v1', 'NC|obj0_f3-rob0_v0')
# ('IC|obs0_f2-obj0_v1', 'NC|obs0_f2-rob0_v0', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f1-rob0_v2', 'NC|obj0_f1-rob0_f1')
# ('IC|obs0_f2-obj0_v1', 'NC|obs0_f2-rob0_v0', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f1-rob0_v2', 'NC|obj0_f2-rob0_f2')
# ('IC|obs0_f2-obj0_v1', 'NC|obs0_f2-rob0_v0', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f1-rob0_v2', 'NC|obj0_f3-rob0_v0')
# ('IC|obs0_f2-obj0_v1', 'NC|obs0_f2-rob0_v0', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f2-rob0_v0', 'IC|obj0_f2-rob0_f2')
# ('IC|obs0_f2-obj0_v1', 'NC|obs0_f2-rob0_v0', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f2-rob0_v0', 'IC|obj0_f0-rob0_v1')
# ('IC|obs0_f2-obj0_v1', 'NC|obs0_f2-rob0_v0', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f2-rob0_v0', 'IC|obj0_f3-rob0_v0')
# ('IC|obs0_f2-obj0_v1', 'NC|obs0_f2-rob0_v0', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f2-rob0_v0', 'IC|obj0_v0-rob0_f0')
# ('IC|obs0_f2-obj0_v1', 'NC|obs0_f2-rob0_v0', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f2-rob0_v0', 'NC|obj0_f0-rob0_v1')
# ('IC|obs0_f2-obj0_v1', 'NC|obs0_f2-rob0_v0', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f2-rob0_v0', 'NC|obj0_f1-rob0_f1')
# ('IC|obs0_f2-obj0_v1', 'NC|obs0_f2-rob0_v0', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f2-rob0_v0', 'NC|obj0_f2-rob0_f2')
# ('IC|obs0_f2-obj0_v1', 'NC|obs0_f2-rob0_v0', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f2-rob0_v0', 'NC|obj0_f3-rob0_v0')
# ('IC|obs0_v0-obj0_f1', 'NC|obs0_f0-rob0_v1', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f0-rob0_v1', 'IC|obj0_f1-rob0_f1')
# ('IC|obs0_v0-obj0_f1', 'NC|obs0_f0-rob0_v1', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f0-rob0_v1', 'IC|obj0_f0-rob0_v1')
# ('IC|obs0_v0-obj0_f1', 'NC|obs0_f0-rob0_v1', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f0-rob0_v1', 'NC|obj0_f0-rob0_v1')
# ('IC|obs0_v0-obj0_f1', 'NC|obs0_f0-rob0_v1', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f0-rob0_v1', 'NC|obj0_f1-rob0_f1')
# ('IC|obs0_v0-obj0_f1', 'NC|obs0_f0-rob0_v1', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f0-rob0_v1', 'NC|obj0_f2-rob0_f2')
# ('IC|obs0_v0-obj0_f1', 'NC|obs0_f0-rob0_v1', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f0-rob0_v1', 'NC|obj0_f3-rob0_v0')
# ('IC|obs0_v0-obj0_f1', 'NC|obs0_f0-rob0_v1', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f1-rob0_v2', 'NC|obj0_f0-rob0_v1')
# ('IC|obs0_v0-obj0_f1', 'NC|obs0_f0-rob0_v1', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f1-rob0_v2', 'NC|obj0_f1-rob0_f1')
# ('IC|obs0_v0-obj0_f1', 'NC|obs0_f0-rob0_v1', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f1-rob0_v2', 'NC|obj0_f2-rob0_f2')
# ('IC|obs0_v0-obj0_f1', 'NC|obs0_f0-rob0_v1', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f2-rob0_v0', 'IC|obj0_f1-rob0_f1')
# ('IC|obs0_v0-obj0_f1', 'NC|obs0_f0-rob0_v1', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f2-rob0_v0', 'IC|obj0_f0-rob0_v1')
# ('IC|obs0_v0-obj0_f1', 'NC|obs0_f0-rob0_v1', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f2-rob0_v0', 'NC|obj0_f0-rob0_v1')
# ('IC|obs0_v0-obj0_f1', 'NC|obs0_f0-rob0_v1', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f2-rob0_v0', 'NC|obj0_f1-rob0_f1')
# ('IC|obs0_v0-obj0_f1', 'NC|obs0_f0-rob0_v1', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f2-rob0_v0', 'NC|obj0_f2-rob0_f2')
# ('IC|obs0_v0-obj0_f1', 'NC|obs0_f0-rob0_v1', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f2-rob0_v0', 'NC|obj0_f3-rob0_v0')
# ('IC|obs0_v0-obj0_f1', 'NC|obs0_f1-rob0_v0', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f0-rob0_v1', 'NC|obj0_f0-rob0_v1')
# ('IC|obs0_v0-obj0_f1', 'NC|obs0_f1-rob0_v0', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f0-rob0_v1', 'NC|obj0_f3-rob0_v0')
# ('IC|obs0_v0-obj0_f1', 'NC|obs0_f1-rob0_v0', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f1-rob0_v2', 'NC|obj0_f1-rob0_f1')
# ('IC|obs0_v0-obj0_f1', 'NC|obs0_f1-rob0_v0', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f1-rob0_v2', 'NC|obj0_f2-rob0_f2')
# ('IC|obs0_v0-obj0_f1', 'NC|obs0_f1-rob0_v0', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f1-rob0_v2', 'NC|obj0_f3-rob0_v0')
# ('IC|obs0_v0-obj0_f1', 'NC|obs0_f1-rob0_v0', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f2-rob0_v0', 'NC|obj0_f0-rob0_v1')
# ('IC|obs0_v0-obj0_f1', 'NC|obs0_f1-rob0_v0', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f2-rob0_v0', 'NC|obj0_f1-rob0_f1')
# ('IC|obs0_v0-obj0_f1', 'NC|obs0_f1-rob0_v0', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f2-rob0_v0', 'NC|obj0_f2-rob0_f2')
# ('IC|obs0_v0-obj0_f1', 'NC|obs0_f1-rob0_v0', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f2-rob0_v0', 'NC|obj0_f3-rob0_v0')
# ('IC|obs0_v0-obj0_f1', 'NC|obs0_f2-rob0_v0', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f0-rob0_v1', 'IC|obj0_f0-rob0_v1')
# ('IC|obs0_v0-obj0_f1', 'NC|obs0_f2-rob0_v0', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f0-rob0_v1', 'IC|obj0_v0-rob0_f0')
# ('IC|obs0_v0-obj0_f1', 'NC|obs0_f2-rob0_v0', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f0-rob0_v1', 'NC|obj0_f0-rob0_v1')
# ('IC|obs0_v0-obj0_f1', 'NC|obs0_f2-rob0_v0', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f0-rob0_v1', 'NC|obj0_f3-rob0_v0')
# ('IC|obs0_v0-obj0_f1', 'NC|obs0_f2-rob0_v0', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f1-rob0_v2', 'NC|obj0_f1-rob0_f1')
# ('IC|obs0_v0-obj0_f1', 'NC|obs0_f2-rob0_v0', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f1-rob0_v2', 'NC|obj0_f2-rob0_f2')
# ('IC|obs0_v0-obj0_f1', 'NC|obs0_f2-rob0_v0', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f1-rob0_v2', 'NC|obj0_f3-rob0_v0')
# ('IC|obs0_v0-obj0_f1', 'NC|obs0_f2-rob0_v0', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f2-rob0_v0', 'IC|obj0_f2-rob0_f2')
# ('IC|obs0_v0-obj0_f1', 'NC|obs0_f2-rob0_v0', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f2-rob0_v0', 'IC|obj0_f0-rob0_v1')
# ('IC|obs0_v0-obj0_f1', 'NC|obs0_f2-rob0_v0', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f2-rob0_v0', 'IC|obj0_f3-rob0_v0')
# ('IC|obs0_v0-obj0_f1', 'NC|obs0_f2-rob0_v0', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f2-rob0_v0', 'IC|obj0_v0-rob0_f0')
# ('IC|obs0_v0-obj0_f1', 'NC|obs0_f2-rob0_v0', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f2-rob0_v0', 'NC|obj0_f0-rob0_v1')
# ('IC|obs0_v0-obj0_f1', 'NC|obs0_f2-rob0_v0', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f2-rob0_v0', 'NC|obj0_f1-rob0_f1')
# ('IC|obs0_v0-obj0_f1', 'NC|obs0_f2-rob0_v0', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f2-rob0_v0', 'NC|obj0_f2-rob0_f2')
# ('IC|obs0_v0-obj0_f1', 'NC|obs0_f2-rob0_v0', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f2-rob0_v0', 'NC|obj0_f3-rob0_v0')
# ('IC|obs0_v0-obj0_f2', 'NC|obs0_f0-rob0_v1', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f0-rob0_v1', 'IC|obj0_f1-rob0_f1')
# ('IC|obs0_v0-obj0_f2', 'NC|obs0_f0-rob0_v1', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f0-rob0_v1', 'IC|obj0_f0-rob0_v1')
# ('IC|obs0_v0-obj0_f2', 'NC|obs0_f0-rob0_v1', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f0-rob0_v1', 'IC|obj0_v0-rob0_f0')
# ('IC|obs0_v0-obj0_f2', 'NC|obs0_f0-rob0_v1', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f0-rob0_v1', 'NC|obj0_f0-rob0_v1')
# ('IC|obs0_v0-obj0_f2', 'NC|obs0_f0-rob0_v1', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f0-rob0_v1', 'NC|obj0_f1-rob0_f1')
# ('IC|obs0_v0-obj0_f2', 'NC|obs0_f0-rob0_v1', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f0-rob0_v1', 'NC|obj0_f2-rob0_f2')
# ('IC|obs0_v0-obj0_f2', 'NC|obs0_f0-rob0_v1', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f0-rob0_v1', 'NC|obj0_f3-rob0_v0')
# ('IC|obs0_v0-obj0_f2', 'NC|obs0_f0-rob0_v1', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f1-rob0_v2', 'NC|obj0_f0-rob0_v1')
# ('IC|obs0_v0-obj0_f2', 'NC|obs0_f0-rob0_v1', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f1-rob0_v2', 'NC|obj0_f1-rob0_f1')
# ('IC|obs0_v0-obj0_f2', 'NC|obs0_f0-rob0_v1', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f1-rob0_v2', 'NC|obj0_f2-rob0_f2')
# ('IC|obs0_v0-obj0_f2', 'NC|obs0_f0-rob0_v1', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f2-rob0_v0', 'IC|obj0_f1-rob0_f1')
# ('IC|obs0_v0-obj0_f2', 'NC|obs0_f0-rob0_v1', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f2-rob0_v0', 'IC|obj0_f2-rob0_f2')
# ('IC|obs0_v0-obj0_f2', 'NC|obs0_f0-rob0_v1', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f2-rob0_v0', 'IC|obj0_f0-rob0_v1')
# ('IC|obs0_v0-obj0_f2', 'NC|obs0_f0-rob0_v1', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f2-rob0_v0', 'IC|obj0_v0-rob0_f0')
# ('IC|obs0_v0-obj0_f2', 'NC|obs0_f0-rob0_v1', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f2-rob0_v0', 'NC|obj0_f0-rob0_v1')
# ('IC|obs0_v0-obj0_f2', 'NC|obs0_f0-rob0_v1', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f2-rob0_v0', 'NC|obj0_f1-rob0_f1')
# ('IC|obs0_v0-obj0_f2', 'NC|obs0_f0-rob0_v1', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f2-rob0_v0', 'NC|obj0_f2-rob0_f2')
# ('IC|obs0_v0-obj0_f2', 'NC|obs0_f0-rob0_v1', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f2-rob0_v0', 'NC|obj0_f3-rob0_v0')
# ('IC|obs0_v0-obj0_f2', 'NC|obs0_f1-rob0_v0', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f0-rob0_v1', 'NC|obj0_f0-rob0_v1')
# ('IC|obs0_v0-obj0_f2', 'NC|obs0_f1-rob0_v0', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f0-rob0_v1', 'NC|obj0_f3-rob0_v0')
# ('IC|obs0_v0-obj0_f2', 'NC|obs0_f1-rob0_v0', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f1-rob0_v2', 'NC|obj0_f1-rob0_f1')
# ('IC|obs0_v0-obj0_f2', 'NC|obs0_f1-rob0_v0', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f1-rob0_v2', 'NC|obj0_f2-rob0_f2')
# ('IC|obs0_v0-obj0_f2', 'NC|obs0_f1-rob0_v0', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f1-rob0_v2', 'NC|obj0_f3-rob0_v0')
# ('IC|obs0_v0-obj0_f2', 'NC|obs0_f1-rob0_v0', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f2-rob0_v0', 'NC|obj0_f0-rob0_v1')
# ('IC|obs0_v0-obj0_f2', 'NC|obs0_f1-rob0_v0', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f2-rob0_v0', 'NC|obj0_f1-rob0_f1')
# ('IC|obs0_v0-obj0_f2', 'NC|obs0_f1-rob0_v0', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f2-rob0_v0', 'NC|obj0_f2-rob0_f2')
# ('IC|obs0_v0-obj0_f2', 'NC|obs0_f1-rob0_v0', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f2-rob0_v0', 'NC|obj0_f3-rob0_v0')
# ('IC|obs0_v0-obj0_f2', 'NC|obs0_f2-rob0_v0', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f0-rob0_v1', 'IC|obj0_f0-rob0_v1')
# ('IC|obs0_v0-obj0_f2', 'NC|obs0_f2-rob0_v0', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f0-rob0_v1', 'IC|obj0_v0-rob0_f0')
# ('IC|obs0_v0-obj0_f2', 'NC|obs0_f2-rob0_v0', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f0-rob0_v1', 'NC|obj0_f0-rob0_v1')
# ('IC|obs0_v0-obj0_f2', 'NC|obs0_f2-rob0_v0', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f0-rob0_v1', 'NC|obj0_f3-rob0_v0')
# ('IC|obs0_v0-obj0_f2', 'NC|obs0_f2-rob0_v0', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f1-rob0_v2', 'NC|obj0_f1-rob0_f1')
# ('IC|obs0_v0-obj0_f2', 'NC|obs0_f2-rob0_v0', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f1-rob0_v2', 'NC|obj0_f2-rob0_f2')
# ('IC|obs0_v0-obj0_f2', 'NC|obs0_f2-rob0_v0', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f1-rob0_v2', 'NC|obj0_f3-rob0_v0')
# ('IC|obs0_v0-obj0_f2', 'NC|obs0_f2-rob0_v0', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f2-rob0_v0', 'IC|obj0_f2-rob0_f2')
# ('IC|obs0_v0-obj0_f2', 'NC|obs0_f2-rob0_v0', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f2-rob0_v0', 'IC|obj0_f0-rob0_v1')
# ('IC|obs0_v0-obj0_f2', 'NC|obs0_f2-rob0_v0', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f2-rob0_v0', 'IC|obj0_f3-rob0_v0')
# ('IC|obs0_v0-obj0_f2', 'NC|obs0_f2-rob0_v0', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f2-rob0_v0', 'IC|obj0_v0-rob0_f0')
# ('IC|obs0_v0-obj0_f2', 'NC|obs0_f2-rob0_v0', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f2-rob0_v0', 'NC|obj0_f0-rob0_v1')
# ('IC|obs0_v0-obj0_f2', 'NC|obs0_f2-rob0_v0', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f2-rob0_v0', 'NC|obj0_f1-rob0_f1')
# ('IC|obs0_v0-obj0_f2', 'NC|obs0_f2-rob0_v0', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f2-rob0_v0', 'NC|obj0_f2-rob0_f2')
# ('IC|obs0_v0-obj0_f2', 'NC|obs0_f2-rob0_v0', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f2-rob0_v0', 'NC|obj0_f3-rob0_v0')
# ('IC|obs0_v1-obj0_f0', 'NC|obs0_f0-rob0_v1', 'NC|obs1_f1-obj0_v0', 'NC|obs1_f0-rob0_v1', 'NC|obj0_f0-rob0_v1')
# ('IC|obs0_v1-obj0_f0', 'NC|obs0_f0-rob0_v1', 'NC|obs1_f1-obj0_v0', 'NC|obs1_f0-rob0_v1', 'NC|obj0_f1-rob0_f1')
# ('IC|obs0_v1-obj0_f0', 'NC|obs0_f0-rob0_v1', 'NC|obs1_f1-obj0_v0', 'NC|obs1_f0-rob0_v1', 'NC|obj0_f2-rob0_f2')
# ('IC|obs0_v1-obj0_f0', 'NC|obs0_f0-rob0_v1', 'NC|obs1_f1-obj0_v0', 'NC|obs1_f0-rob0_v1', 'NC|obj0_f3-rob0_v0')
# ('IC|obs0_v1-obj0_f0', 'NC|obs0_f0-rob0_v1', 'NC|obs1_f1-obj0_v0', 'NC|obs1_f1-rob0_v2', 'IC|obj0_f1-rob0_f1')
# ('IC|obs0_v1-obj0_f0', 'NC|obs0_f0-rob0_v1', 'NC|obs1_f1-obj0_v0', 'NC|obs1_f1-rob0_v2', 'IC|obj0_f0-rob0_v1')
# ('IC|obs0_v1-obj0_f0', 'NC|obs0_f0-rob0_v1', 'NC|obs1_f1-obj0_v0', 'NC|obs1_f1-rob0_v2', 'IC|obj0_v0-rob0_f0')
# ('IC|obs0_v1-obj0_f0', 'NC|obs0_f0-rob0_v1', 'NC|obs1_f1-obj0_v0', 'NC|obs1_f1-rob0_v2', 'NC|obj0_f0-rob0_v1')
# ('IC|obs0_v1-obj0_f0', 'NC|obs0_f0-rob0_v1', 'NC|obs1_f1-obj0_v0', 'NC|obs1_f1-rob0_v2', 'NC|obj0_f1-rob0_f1')
# ('IC|obs0_v1-obj0_f0', 'NC|obs0_f0-rob0_v1', 'NC|obs1_f1-obj0_v0', 'NC|obs1_f1-rob0_v2', 'NC|obj0_f2-rob0_f2')
# ('IC|obs0_v1-obj0_f0', 'NC|obs0_f0-rob0_v1', 'NC|obs1_f1-obj0_v0', 'NC|obs1_f2-rob0_v0', 'IC|obj0_f1-rob0_f1')
# ('IC|obs0_v1-obj0_f0', 'NC|obs0_f0-rob0_v1', 'NC|obs1_f1-obj0_v0', 'NC|obs1_f2-rob0_v0', 'IC|obj0_f0-rob0_v1')
# ('IC|obs0_v1-obj0_f0', 'NC|obs0_f0-rob0_v1', 'NC|obs1_f1-obj0_v0', 'NC|obs1_f2-rob0_v0', 'IC|obj0_v0-rob0_f0')
# ('IC|obs0_v1-obj0_f0', 'NC|obs0_f0-rob0_v1', 'NC|obs1_f1-obj0_v0', 'NC|obs1_f2-rob0_v0', 'NC|obj0_f0-rob0_v1')
# ('IC|obs0_v1-obj0_f0', 'NC|obs0_f0-rob0_v1', 'NC|obs1_f1-obj0_v0', 'NC|obs1_f2-rob0_v0', 'NC|obj0_f1-rob0_f1')
# ('IC|obs0_v1-obj0_f0', 'NC|obs0_f0-rob0_v1', 'NC|obs1_f1-obj0_v0', 'NC|obs1_f2-rob0_v0', 'NC|obj0_f2-rob0_f2')
# ('IC|obs0_v1-obj0_f0', 'NC|obs0_f0-rob0_v1', 'NC|obs1_f1-obj0_v0', 'NC|obs1_f2-rob0_v0', 'NC|obj0_f3-rob0_v0')
# ('IC|obs0_v1-obj0_f0', 'NC|obs0_f0-rob0_v1', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f0-rob0_v1', 'NC|obj0_f0-rob0_v1')
# ('IC|obs0_v1-obj0_f0', 'NC|obs0_f0-rob0_v1', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f0-rob0_v1', 'NC|obj0_f1-rob0_f1')
# ('IC|obs0_v1-obj0_f0', 'NC|obs0_f0-rob0_v1', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f0-rob0_v1', 'NC|obj0_f2-rob0_f2')
# ('IC|obs0_v1-obj0_f0', 'NC|obs0_f0-rob0_v1', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f0-rob0_v1', 'NC|obj0_f3-rob0_v0')
# ('IC|obs0_v1-obj0_f0', 'NC|obs0_f0-rob0_v1', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f1-rob0_v2', 'IC|obj0_f1-rob0_f1')
# ('IC|obs0_v1-obj0_f0', 'NC|obs0_f0-rob0_v1', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f1-rob0_v2', 'IC|obj0_f0-rob0_v1')
# ('IC|obs0_v1-obj0_f0', 'NC|obs0_f0-rob0_v1', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f1-rob0_v2', 'IC|obj0_v0-rob0_f0')
# ('IC|obs0_v1-obj0_f0', 'NC|obs0_f0-rob0_v1', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f1-rob0_v2', 'NC|obj0_f0-rob0_v1')
# ('IC|obs0_v1-obj0_f0', 'NC|obs0_f0-rob0_v1', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f1-rob0_v2', 'NC|obj0_f1-rob0_f1')
# ('IC|obs0_v1-obj0_f0', 'NC|obs0_f0-rob0_v1', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f1-rob0_v2', 'NC|obj0_f2-rob0_f2')
# ('IC|obs0_v1-obj0_f0', 'NC|obs0_f0-rob0_v1', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f2-rob0_v0', 'IC|obj0_f1-rob0_f1')
# ('IC|obs0_v1-obj0_f0', 'NC|obs0_f0-rob0_v1', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f2-rob0_v0', 'IC|obj0_f0-rob0_v1')
# ('IC|obs0_v1-obj0_f0', 'NC|obs0_f0-rob0_v1', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f2-rob0_v0', 'IC|obj0_v0-rob0_f0')
# ('IC|obs0_v1-obj0_f0', 'NC|obs0_f0-rob0_v1', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f2-rob0_v0', 'NC|obj0_f0-rob0_v1')
# ('IC|obs0_v1-obj0_f0', 'NC|obs0_f0-rob0_v1', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f2-rob0_v0', 'NC|obj0_f1-rob0_f1')
# ('IC|obs0_v1-obj0_f0', 'NC|obs0_f0-rob0_v1', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f2-rob0_v0', 'NC|obj0_f2-rob0_f2')
# ('IC|obs0_v1-obj0_f0', 'NC|obs0_f0-rob0_v1', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f2-rob0_v0', 'NC|obj0_f3-rob0_v0')
# ('IC|obs0_v1-obj0_f0', 'NC|obs0_f1-rob0_v0', 'NC|obs1_f1-obj0_v0', 'NC|obs1_f0-rob0_v1', 'NC|obj0_f0-rob0_v1')
# ('IC|obs0_v1-obj0_f0', 'NC|obs0_f1-rob0_v0', 'NC|obs1_f1-obj0_v0', 'NC|obs1_f0-rob0_v1', 'NC|obj0_f3-rob0_v0')
# ('IC|obs0_v1-obj0_f0', 'NC|obs0_f1-rob0_v0', 'NC|obs1_f1-obj0_v0', 'NC|obs1_f1-rob0_v2', 'IC|obj0_f1-rob0_f1')
# ('IC|obs0_v1-obj0_f0', 'NC|obs0_f1-rob0_v0', 'NC|obs1_f1-obj0_v0', 'NC|obs1_f1-rob0_v2', 'IC|obj0_f2-rob0_f2')
# ('IC|obs0_v1-obj0_f0', 'NC|obs0_f1-rob0_v0', 'NC|obs1_f1-obj0_v0', 'NC|obs1_f1-rob0_v2', 'NC|obj0_f1-rob0_f1')
# ('IC|obs0_v1-obj0_f0', 'NC|obs0_f1-rob0_v0', 'NC|obs1_f1-obj0_v0', 'NC|obs1_f1-rob0_v2', 'NC|obj0_f2-rob0_f2')
# ('IC|obs0_v1-obj0_f0', 'NC|obs0_f1-rob0_v0', 'NC|obs1_f1-obj0_v0', 'NC|obs1_f1-rob0_v2', 'NC|obj0_f3-rob0_v0')
# ('IC|obs0_v1-obj0_f0', 'NC|obs0_f1-rob0_v0', 'NC|obs1_f1-obj0_v0', 'NC|obs1_f2-rob0_v0', 'IC|obj0_f1-rob0_f1')
# ('IC|obs0_v1-obj0_f0', 'NC|obs0_f1-rob0_v0', 'NC|obs1_f1-obj0_v0', 'NC|obs1_f2-rob0_v0', 'IC|obj0_f2-rob0_f2')
# ('IC|obs0_v1-obj0_f0', 'NC|obs0_f1-rob0_v0', 'NC|obs1_f1-obj0_v0', 'NC|obs1_f2-rob0_v0', 'IC|obj0_f3-rob0_v0')
# ('IC|obs0_v1-obj0_f0', 'NC|obs0_f1-rob0_v0', 'NC|obs1_f1-obj0_v0', 'NC|obs1_f2-rob0_v0', 'IC|obj0_v0-rob0_f0')
# ('IC|obs0_v1-obj0_f0', 'NC|obs0_f1-rob0_v0', 'NC|obs1_f1-obj0_v0', 'NC|obs1_f2-rob0_v0', 'NC|obj0_f0-rob0_v1')
# ('IC|obs0_v1-obj0_f0', 'NC|obs0_f1-rob0_v0', 'NC|obs1_f1-obj0_v0', 'NC|obs1_f2-rob0_v0', 'NC|obj0_f1-rob0_f1')
# ('IC|obs0_v1-obj0_f0', 'NC|obs0_f1-rob0_v0', 'NC|obs1_f1-obj0_v0', 'NC|obs1_f2-rob0_v0', 'NC|obj0_f2-rob0_f2')
# ('IC|obs0_v1-obj0_f0', 'NC|obs0_f1-rob0_v0', 'NC|obs1_f1-obj0_v0', 'NC|obs1_f2-rob0_v0', 'NC|obj0_f3-rob0_v0')
# ('IC|obs0_v1-obj0_f0', 'NC|obs0_f1-rob0_v0', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f0-rob0_v1', 'NC|obj0_f0-rob0_v1')
# ('IC|obs0_v1-obj0_f0', 'NC|obs0_f1-rob0_v0', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f0-rob0_v1', 'NC|obj0_f3-rob0_v0')
# ('IC|obs0_v1-obj0_f0', 'NC|obs0_f1-rob0_v0', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f1-rob0_v2', 'IC|obj0_f1-rob0_f1')
# ('IC|obs0_v1-obj0_f0', 'NC|obs0_f1-rob0_v0', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f1-rob0_v2', 'IC|obj0_f2-rob0_f2')
# ('IC|obs0_v1-obj0_f0', 'NC|obs0_f1-rob0_v0', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f1-rob0_v2', 'NC|obj0_f1-rob0_f1')
# ('IC|obs0_v1-obj0_f0', 'NC|obs0_f1-rob0_v0', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f1-rob0_v2', 'NC|obj0_f2-rob0_f2')
# ('IC|obs0_v1-obj0_f0', 'NC|obs0_f1-rob0_v0', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f1-rob0_v2', 'NC|obj0_f3-rob0_v0')
# ('IC|obs0_v1-obj0_f0', 'NC|obs0_f1-rob0_v0', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f2-rob0_v0', 'IC|obj0_f1-rob0_f1')
# ('IC|obs0_v1-obj0_f0', 'NC|obs0_f1-rob0_v0', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f2-rob0_v0', 'IC|obj0_f2-rob0_f2')
# ('IC|obs0_v1-obj0_f0', 'NC|obs0_f1-rob0_v0', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f2-rob0_v0', 'IC|obj0_f3-rob0_v0')
# ('IC|obs0_v1-obj0_f0', 'NC|obs0_f1-rob0_v0', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f2-rob0_v0', 'IC|obj0_v0-rob0_f0')
# ('IC|obs0_v1-obj0_f0', 'NC|obs0_f1-rob0_v0', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f2-rob0_v0', 'NC|obj0_f0-rob0_v1')
# ('IC|obs0_v1-obj0_f0', 'NC|obs0_f1-rob0_v0', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f2-rob0_v0', 'NC|obj0_f1-rob0_f1')
# ('IC|obs0_v1-obj0_f0', 'NC|obs0_f1-rob0_v0', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f2-rob0_v0', 'NC|obj0_f2-rob0_f2')
# ('IC|obs0_v1-obj0_f0', 'NC|obs0_f1-rob0_v0', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f2-rob0_v0', 'NC|obj0_f3-rob0_v0')
# ('IC|obs0_v1-obj0_f0', 'NC|obs0_f2-rob0_v0', 'NC|obs1_f1-obj0_v0', 'NC|obs1_f0-rob0_v1', 'NC|obj0_f0-rob0_v1')
# ('IC|obs0_v1-obj0_f0', 'NC|obs0_f2-rob0_v0', 'NC|obs1_f1-obj0_v0', 'NC|obs1_f0-rob0_v1', 'NC|obj0_f3-rob0_v0')
# ('IC|obs0_v1-obj0_f0', 'NC|obs0_f2-rob0_v0', 'NC|obs1_f1-obj0_v0', 'NC|obs1_f1-rob0_v2', 'NC|obj0_f1-rob0_f1')
# ('IC|obs0_v1-obj0_f0', 'NC|obs0_f2-rob0_v0', 'NC|obs1_f1-obj0_v0', 'NC|obs1_f1-rob0_v2', 'NC|obj0_f2-rob0_f2')
# ('IC|obs0_v1-obj0_f0', 'NC|obs0_f2-rob0_v0', 'NC|obs1_f1-obj0_v0', 'NC|obs1_f1-rob0_v2', 'NC|obj0_f3-rob0_v0')
# ('IC|obs0_v1-obj0_f0', 'NC|obs0_f2-rob0_v0', 'NC|obs1_f1-obj0_v0', 'NC|obs1_f2-rob0_v0', 'NC|obj0_f0-rob0_v1')
# ('IC|obs0_v1-obj0_f0', 'NC|obs0_f2-rob0_v0', 'NC|obs1_f1-obj0_v0', 'NC|obs1_f2-rob0_v0', 'NC|obj0_f1-rob0_f1')
# ('IC|obs0_v1-obj0_f0', 'NC|obs0_f2-rob0_v0', 'NC|obs1_f1-obj0_v0', 'NC|obs1_f2-rob0_v0', 'NC|obj0_f2-rob0_f2')
# ('IC|obs0_v1-obj0_f0', 'NC|obs0_f2-rob0_v0', 'NC|obs1_f1-obj0_v0', 'NC|obs1_f2-rob0_v0', 'NC|obj0_f3-rob0_v0')
# ('IC|obs0_v1-obj0_f0', 'NC|obs0_f2-rob0_v0', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f0-rob0_v1', 'NC|obj0_f0-rob0_v1')
# ('IC|obs0_v1-obj0_f0', 'NC|obs0_f2-rob0_v0', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f0-rob0_v1', 'NC|obj0_f3-rob0_v0')
# ('IC|obs0_v1-obj0_f0', 'NC|obs0_f2-rob0_v0', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f1-rob0_v2', 'NC|obj0_f1-rob0_f1')
# ('IC|obs0_v1-obj0_f0', 'NC|obs0_f2-rob0_v0', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f1-rob0_v2', 'NC|obj0_f2-rob0_f2')
# ('IC|obs0_v1-obj0_f0', 'NC|obs0_f2-rob0_v0', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f1-rob0_v2', 'NC|obj0_f3-rob0_v0')
# ('IC|obs0_v1-obj0_f0', 'NC|obs0_f2-rob0_v0', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f2-rob0_v0', 'NC|obj0_f0-rob0_v1')
# ('IC|obs0_v1-obj0_f0', 'NC|obs0_f2-rob0_v0', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f2-rob0_v0', 'NC|obj0_f1-rob0_f1')
# ('IC|obs0_v1-obj0_f0', 'NC|obs0_f2-rob0_v0', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f2-rob0_v0', 'NC|obj0_f2-rob0_f2')
# ('IC|obs0_v1-obj0_f0', 'NC|obs0_f2-rob0_v0', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f2-rob0_v0', 'NC|obj0_f3-rob0_v0')
# ('IC|obs0_v1-obj0_f3', 'NC|obs0_f0-rob0_v1', 'NC|obs1_f1-obj0_v0', 'NC|obs1_f0-rob0_v1', 'NC|obj0_f0-rob0_v1')
# ('IC|obs0_v1-obj0_f3', 'NC|obs0_f0-rob0_v1', 'NC|obs1_f1-obj0_v0', 'NC|obs1_f0-rob0_v1', 'NC|obj0_f1-rob0_f1')
# ('IC|obs0_v1-obj0_f3', 'NC|obs0_f0-rob0_v1', 'NC|obs1_f1-obj0_v0', 'NC|obs1_f0-rob0_v1', 'NC|obj0_f2-rob0_f2')
# ('IC|obs0_v1-obj0_f3', 'NC|obs0_f0-rob0_v1', 'NC|obs1_f1-obj0_v0', 'NC|obs1_f0-rob0_v1', 'NC|obj0_f3-rob0_v0')
# ('IC|obs0_v1-obj0_f3', 'NC|obs0_f0-rob0_v1', 'NC|obs1_f1-obj0_v0', 'NC|obs1_f1-rob0_v2', 'IC|obj0_f1-rob0_f1')
# ('IC|obs0_v1-obj0_f3', 'NC|obs0_f0-rob0_v1', 'NC|obs1_f1-obj0_v0', 'NC|obs1_f1-rob0_v2', 'IC|obj0_f2-rob0_f2')
# ('IC|obs0_v1-obj0_f3', 'NC|obs0_f0-rob0_v1', 'NC|obs1_f1-obj0_v0', 'NC|obs1_f1-rob0_v2', 'IC|obj0_f0-rob0_v1')
# ('IC|obs0_v1-obj0_f3', 'NC|obs0_f0-rob0_v1', 'NC|obs1_f1-obj0_v0', 'NC|obs1_f1-rob0_v2', 'IC|obj0_v0-rob0_f0')
# ('IC|obs0_v1-obj0_f3', 'NC|obs0_f0-rob0_v1', 'NC|obs1_f1-obj0_v0', 'NC|obs1_f1-rob0_v2', 'NC|obj0_f0-rob0_v1')
# ('IC|obs0_v1-obj0_f3', 'NC|obs0_f0-rob0_v1', 'NC|obs1_f1-obj0_v0', 'NC|obs1_f1-rob0_v2', 'NC|obj0_f1-rob0_f1')
# ('IC|obs0_v1-obj0_f3', 'NC|obs0_f0-rob0_v1', 'NC|obs1_f1-obj0_v0', 'NC|obs1_f1-rob0_v2', 'NC|obj0_f2-rob0_f2')
# ('IC|obs0_v1-obj0_f3', 'NC|obs0_f0-rob0_v1', 'NC|obs1_f1-obj0_v0', 'NC|obs1_f2-rob0_v0', 'IC|obj0_f1-rob0_f1')
# ('IC|obs0_v1-obj0_f3', 'NC|obs0_f0-rob0_v1', 'NC|obs1_f1-obj0_v0', 'NC|obs1_f2-rob0_v0', 'IC|obj0_f2-rob0_f2')
# ('IC|obs0_v1-obj0_f3', 'NC|obs0_f0-rob0_v1', 'NC|obs1_f1-obj0_v0', 'NC|obs1_f2-rob0_v0', 'IC|obj0_f0-rob0_v1')
# ('IC|obs0_v1-obj0_f3', 'NC|obs0_f0-rob0_v1', 'NC|obs1_f1-obj0_v0', 'NC|obs1_f2-rob0_v0', 'IC|obj0_v0-rob0_f0')
# ('IC|obs0_v1-obj0_f3', 'NC|obs0_f0-rob0_v1', 'NC|obs1_f1-obj0_v0', 'NC|obs1_f2-rob0_v0', 'NC|obj0_f0-rob0_v1')
# ('IC|obs0_v1-obj0_f3', 'NC|obs0_f0-rob0_v1', 'NC|obs1_f1-obj0_v0', 'NC|obs1_f2-rob0_v0', 'NC|obj0_f1-rob0_f1')
# ('IC|obs0_v1-obj0_f3', 'NC|obs0_f0-rob0_v1', 'NC|obs1_f1-obj0_v0', 'NC|obs1_f2-rob0_v0', 'NC|obj0_f2-rob0_f2')
# ('IC|obs0_v1-obj0_f3', 'NC|obs0_f0-rob0_v1', 'NC|obs1_f1-obj0_v0', 'NC|obs1_f2-rob0_v0', 'NC|obj0_f3-rob0_v0')
# ('IC|obs0_v1-obj0_f3', 'NC|obs0_f0-rob0_v1', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f0-rob0_v1', 'NC|obj0_f0-rob0_v1')
# ('IC|obs0_v1-obj0_f3', 'NC|obs0_f0-rob0_v1', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f0-rob0_v1', 'NC|obj0_f1-rob0_f1')
# ('IC|obs0_v1-obj0_f3', 'NC|obs0_f0-rob0_v1', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f0-rob0_v1', 'NC|obj0_f2-rob0_f2')
# ('IC|obs0_v1-obj0_f3', 'NC|obs0_f0-rob0_v1', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f0-rob0_v1', 'NC|obj0_f3-rob0_v0')
# ('IC|obs0_v1-obj0_f3', 'NC|obs0_f0-rob0_v1', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f1-rob0_v2', 'IC|obj0_f1-rob0_f1')
# ('IC|obs0_v1-obj0_f3', 'NC|obs0_f0-rob0_v1', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f1-rob0_v2', 'IC|obj0_f2-rob0_f2')
# ('IC|obs0_v1-obj0_f3', 'NC|obs0_f0-rob0_v1', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f1-rob0_v2', 'IC|obj0_f0-rob0_v1')
# ('IC|obs0_v1-obj0_f3', 'NC|obs0_f0-rob0_v1', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f1-rob0_v2', 'IC|obj0_v0-rob0_f0')
# ('IC|obs0_v1-obj0_f3', 'NC|obs0_f0-rob0_v1', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f1-rob0_v2', 'NC|obj0_f0-rob0_v1')
# ('IC|obs0_v1-obj0_f3', 'NC|obs0_f0-rob0_v1', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f1-rob0_v2', 'NC|obj0_f1-rob0_f1')
# ('IC|obs0_v1-obj0_f3', 'NC|obs0_f0-rob0_v1', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f1-rob0_v2', 'NC|obj0_f2-rob0_f2')
# ('IC|obs0_v1-obj0_f3', 'NC|obs0_f0-rob0_v1', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f2-rob0_v0', 'IC|obj0_f1-rob0_f1')
# ('IC|obs0_v1-obj0_f3', 'NC|obs0_f0-rob0_v1', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f2-rob0_v0', 'IC|obj0_f2-rob0_f2')
# ('IC|obs0_v1-obj0_f3', 'NC|obs0_f0-rob0_v1', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f2-rob0_v0', 'IC|obj0_f0-rob0_v1')
# ('IC|obs0_v1-obj0_f3', 'NC|obs0_f0-rob0_v1', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f2-rob0_v0', 'IC|obj0_v0-rob0_f0')
# ('IC|obs0_v1-obj0_f3', 'NC|obs0_f0-rob0_v1', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f2-rob0_v0', 'NC|obj0_f0-rob0_v1')
# ('IC|obs0_v1-obj0_f3', 'NC|obs0_f0-rob0_v1', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f2-rob0_v0', 'NC|obj0_f1-rob0_f1')
# ('IC|obs0_v1-obj0_f3', 'NC|obs0_f0-rob0_v1', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f2-rob0_v0', 'NC|obj0_f2-rob0_f2')
# ('IC|obs0_v1-obj0_f3', 'NC|obs0_f0-rob0_v1', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f2-rob0_v0', 'NC|obj0_f3-rob0_v0')
# ('IC|obs0_v1-obj0_f3', 'NC|obs0_f1-rob0_v0', 'NC|obs1_f1-obj0_v0', 'NC|obs1_f0-rob0_v1', 'NC|obj0_f0-rob0_v1')
# ('IC|obs0_v1-obj0_f3', 'NC|obs0_f1-rob0_v0', 'NC|obs1_f1-obj0_v0', 'NC|obs1_f0-rob0_v1', 'NC|obj0_f3-rob0_v0')
# ('IC|obs0_v1-obj0_f3', 'NC|obs0_f1-rob0_v0', 'NC|obs1_f1-obj0_v0', 'NC|obs1_f1-rob0_v2', 'IC|obj0_f1-rob0_f1')
# ('IC|obs0_v1-obj0_f3', 'NC|obs0_f1-rob0_v0', 'NC|obs1_f1-obj0_v0', 'NC|obs1_f1-rob0_v2', 'IC|obj0_f2-rob0_f2')
# ('IC|obs0_v1-obj0_f3', 'NC|obs0_f1-rob0_v0', 'NC|obs1_f1-obj0_v0', 'NC|obs1_f1-rob0_v2', 'NC|obj0_f1-rob0_f1')
# ('IC|obs0_v1-obj0_f3', 'NC|obs0_f1-rob0_v0', 'NC|obs1_f1-obj0_v0', 'NC|obs1_f1-rob0_v2', 'NC|obj0_f2-rob0_f2')
# ('IC|obs0_v1-obj0_f3', 'NC|obs0_f1-rob0_v0', 'NC|obs1_f1-obj0_v0', 'NC|obs1_f1-rob0_v2', 'NC|obj0_f3-rob0_v0')
# ('IC|obs0_v1-obj0_f3', 'NC|obs0_f1-rob0_v0', 'NC|obs1_f1-obj0_v0', 'NC|obs1_f2-rob0_v0', 'IC|obj0_f1-rob0_f1')
# ('IC|obs0_v1-obj0_f3', 'NC|obs0_f1-rob0_v0', 'NC|obs1_f1-obj0_v0', 'NC|obs1_f2-rob0_v0', 'IC|obj0_f2-rob0_f2')
# ('IC|obs0_v1-obj0_f3', 'NC|obs0_f1-rob0_v0', 'NC|obs1_f1-obj0_v0', 'NC|obs1_f2-rob0_v0', 'IC|obj0_f3-rob0_v0')
# ('IC|obs0_v1-obj0_f3', 'NC|obs0_f1-rob0_v0', 'NC|obs1_f1-obj0_v0', 'NC|obs1_f2-rob0_v0', 'IC|obj0_v0-rob0_f0')
# ('IC|obs0_v1-obj0_f3', 'NC|obs0_f1-rob0_v0', 'NC|obs1_f1-obj0_v0', 'NC|obs1_f2-rob0_v0', 'NC|obj0_f0-rob0_v1')
# ('IC|obs0_v1-obj0_f3', 'NC|obs0_f1-rob0_v0', 'NC|obs1_f1-obj0_v0', 'NC|obs1_f2-rob0_v0', 'NC|obj0_f1-rob0_f1')
# ('IC|obs0_v1-obj0_f3', 'NC|obs0_f1-rob0_v0', 'NC|obs1_f1-obj0_v0', 'NC|obs1_f2-rob0_v0', 'NC|obj0_f2-rob0_f2')
# ('IC|obs0_v1-obj0_f3', 'NC|obs0_f1-rob0_v0', 'NC|obs1_f1-obj0_v0', 'NC|obs1_f2-rob0_v0', 'NC|obj0_f3-rob0_v0')
# ('IC|obs0_v1-obj0_f3', 'NC|obs0_f1-rob0_v0', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f0-rob0_v1', 'NC|obj0_f0-rob0_v1')
# ('IC|obs0_v1-obj0_f3', 'NC|obs0_f1-rob0_v0', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f0-rob0_v1', 'NC|obj0_f3-rob0_v0')
# ('IC|obs0_v1-obj0_f3', 'NC|obs0_f1-rob0_v0', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f1-rob0_v2', 'IC|obj0_f1-rob0_f1')
# ('IC|obs0_v1-obj0_f3', 'NC|obs0_f1-rob0_v0', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f1-rob0_v2', 'IC|obj0_f2-rob0_f2')
# ('IC|obs0_v1-obj0_f3', 'NC|obs0_f1-rob0_v0', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f1-rob0_v2', 'NC|obj0_f1-rob0_f1')
# ('IC|obs0_v1-obj0_f3', 'NC|obs0_f1-rob0_v0', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f1-rob0_v2', 'NC|obj0_f2-rob0_f2')
# ('IC|obs0_v1-obj0_f3', 'NC|obs0_f1-rob0_v0', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f1-rob0_v2', 'NC|obj0_f3-rob0_v0')
# ('IC|obs0_v1-obj0_f3', 'NC|obs0_f1-rob0_v0', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f2-rob0_v0', 'IC|obj0_f1-rob0_f1')
# ('IC|obs0_v1-obj0_f3', 'NC|obs0_f1-rob0_v0', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f2-rob0_v0', 'IC|obj0_f2-rob0_f2')
# ('IC|obs0_v1-obj0_f3', 'NC|obs0_f1-rob0_v0', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f2-rob0_v0', 'IC|obj0_f3-rob0_v0')
# ('IC|obs0_v1-obj0_f3', 'NC|obs0_f1-rob0_v0', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f2-rob0_v0', 'IC|obj0_v0-rob0_f0')
# ('IC|obs0_v1-obj0_f3', 'NC|obs0_f1-rob0_v0', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f2-rob0_v0', 'NC|obj0_f0-rob0_v1')
# ('IC|obs0_v1-obj0_f3', 'NC|obs0_f1-rob0_v0', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f2-rob0_v0', 'NC|obj0_f1-rob0_f1')
# ('IC|obs0_v1-obj0_f3', 'NC|obs0_f1-rob0_v0', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f2-rob0_v0', 'NC|obj0_f2-rob0_f2')
# ('IC|obs0_v1-obj0_f3', 'NC|obs0_f1-rob0_v0', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f2-rob0_v0', 'NC|obj0_f3-rob0_v0')
# ('IC|obs0_v1-obj0_f3', 'NC|obs0_f2-rob0_v0', 'NC|obs1_f1-obj0_v0', 'NC|obs1_f0-rob0_v1', 'NC|obj0_f0-rob0_v1')
# ('IC|obs0_v1-obj0_f3', 'NC|obs0_f2-rob0_v0', 'NC|obs1_f1-obj0_v0', 'NC|obs1_f0-rob0_v1', 'NC|obj0_f3-rob0_v0')
# ('IC|obs0_v1-obj0_f3', 'NC|obs0_f2-rob0_v0', 'NC|obs1_f1-obj0_v0', 'NC|obs1_f1-rob0_v2', 'NC|obj0_f1-rob0_f1')
# ('IC|obs0_v1-obj0_f3', 'NC|obs0_f2-rob0_v0', 'NC|obs1_f1-obj0_v0', 'NC|obs1_f1-rob0_v2', 'NC|obj0_f2-rob0_f2')
# ('IC|obs0_v1-obj0_f3', 'NC|obs0_f2-rob0_v0', 'NC|obs1_f1-obj0_v0', 'NC|obs1_f1-rob0_v2', 'NC|obj0_f3-rob0_v0')
# ('IC|obs0_v1-obj0_f3', 'NC|obs0_f2-rob0_v0', 'NC|obs1_f1-obj0_v0', 'NC|obs1_f2-rob0_v0', 'NC|obj0_f0-rob0_v1')
# ('IC|obs0_v1-obj0_f3', 'NC|obs0_f2-rob0_v0', 'NC|obs1_f1-obj0_v0', 'NC|obs1_f2-rob0_v0', 'NC|obj0_f1-rob0_f1')
# ('IC|obs0_v1-obj0_f3', 'NC|obs0_f2-rob0_v0', 'NC|obs1_f1-obj0_v0', 'NC|obs1_f2-rob0_v0', 'NC|obj0_f2-rob0_f2')
# ('IC|obs0_v1-obj0_f3', 'NC|obs0_f2-rob0_v0', 'NC|obs1_f1-obj0_v0', 'NC|obs1_f2-rob0_v0', 'NC|obj0_f3-rob0_v0')
# ('IC|obs0_v1-obj0_f3', 'NC|obs0_f2-rob0_v0', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f0-rob0_v1', 'NC|obj0_f0-rob0_v1')
# ('IC|obs0_v1-obj0_f3', 'NC|obs0_f2-rob0_v0', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f0-rob0_v1', 'NC|obj0_f3-rob0_v0')
# ('IC|obs0_v1-obj0_f3', 'NC|obs0_f2-rob0_v0', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f1-rob0_v2', 'NC|obj0_f1-rob0_f1')
# ('IC|obs0_v1-obj0_f3', 'NC|obs0_f2-rob0_v0', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f1-rob0_v2', 'NC|obj0_f2-rob0_f2')
# ('IC|obs0_v1-obj0_f3', 'NC|obs0_f2-rob0_v0', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f1-rob0_v2', 'NC|obj0_f3-rob0_v0')
# ('IC|obs0_v1-obj0_f3', 'NC|obs0_f2-rob0_v0', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f2-rob0_v0', 'NC|obj0_f0-rob0_v1')
# ('IC|obs0_v1-obj0_f3', 'NC|obs0_f2-rob0_v0', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f2-rob0_v0', 'NC|obj0_f1-rob0_f1')
# ('IC|obs0_v1-obj0_f3', 'NC|obs0_f2-rob0_v0', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f2-rob0_v0', 'NC|obj0_f2-rob0_f2')
# ('IC|obs0_v1-obj0_f3', 'NC|obs0_f2-rob0_v0', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f2-rob0_v0', 'NC|obj0_f3-rob0_v0')
# ('NC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'IC|obs1_f0-obj0_v3', 'NC|obs1_f0-rob0_v1', 'IC|obj0_f1-rob0_f1')
# ('NC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'IC|obs1_f0-obj0_v3', 'NC|obs1_f0-rob0_v1', 'IC|obj0_f0-rob0_v1')
# ('NC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'IC|obs1_f0-obj0_v3', 'NC|obs1_f0-rob0_v1', 'IC|obj0_v0-rob0_f0')
# ('NC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'IC|obs1_f0-obj0_v3', 'NC|obs1_f0-rob0_v1', 'NC|obj0_f0-rob0_v1')
# ('NC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'IC|obs1_f0-obj0_v3', 'NC|obs1_f0-rob0_v1', 'NC|obj0_f1-rob0_f1')
# ('NC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'IC|obs1_f0-obj0_v3', 'NC|obs1_f0-rob0_v1', 'NC|obj0_f2-rob0_f2')
# ('NC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'IC|obs1_f0-obj0_v3', 'NC|obs1_f0-rob0_v1', 'NC|obj0_f3-rob0_v0')
# ('NC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'IC|obs1_f0-obj0_v3', 'NC|obs1_f1-rob0_v2', 'IC|obj0_f1-rob0_f1')
# ('NC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'IC|obs1_f0-obj0_v3', 'NC|obs1_f1-rob0_v2', 'IC|obj0_f2-rob0_f2')
# ('NC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'IC|obs1_f0-obj0_v3', 'NC|obs1_f1-rob0_v2', 'IC|obj0_f0-rob0_v1')
# ('NC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'IC|obs1_f0-obj0_v3', 'NC|obs1_f1-rob0_v2', 'NC|obj0_f0-rob0_v1')
# ('NC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'IC|obs1_f0-obj0_v3', 'NC|obs1_f1-rob0_v2', 'NC|obj0_f1-rob0_f1')
# ('NC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'IC|obs1_f0-obj0_v3', 'NC|obs1_f1-rob0_v2', 'NC|obj0_f2-rob0_f2')
# ('NC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'IC|obs1_f0-obj0_v3', 'NC|obs1_f1-rob0_v2', 'NC|obj0_f3-rob0_v0')
# ('NC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'IC|obs1_f0-obj0_v3', 'NC|obs1_f2-rob0_v0', 'IC|obj0_f2-rob0_f2')
# ('NC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'IC|obs1_f0-obj0_v3', 'NC|obs1_f2-rob0_v0', 'IC|obj0_f3-rob0_v0')
# ('NC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'IC|obs1_f0-obj0_v3', 'NC|obs1_f2-rob0_v0', 'NC|obj0_f0-rob0_v1')
# ('NC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'IC|obs1_f0-obj0_v3', 'NC|obs1_f2-rob0_v0', 'NC|obj0_f1-rob0_f1')
# ('NC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'IC|obs1_f0-obj0_v3', 'NC|obs1_f2-rob0_v0', 'NC|obj0_f2-rob0_f2')
# ('NC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'IC|obs1_f0-obj0_v3', 'NC|obs1_f2-rob0_v0', 'NC|obj0_f3-rob0_v0')
# ('NC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'IC|obs1_f1-obj0_v0', 'NC|obs1_f0-rob0_v1', 'IC|obj0_f1-rob0_f1')
# ('NC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'IC|obs1_f1-obj0_v0', 'NC|obs1_f0-rob0_v1', 'IC|obj0_f0-rob0_v1')
# ...
# ('NC|obs0_f2-obj0_v1', 'NC|obs0_f0-rob0_v1', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f2-rob0_v0', 'IC|obj0_f0-rob0_v1')
# ('NC|obs0_f2-obj0_v1', 'NC|obs0_f0-rob0_v1', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f2-rob0_v0', 'IC|obj0_v0-rob0_f0')
# ('NC|obs0_f2-obj0_v1', 'NC|obs0_f0-rob0_v1', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f2-rob0_v0', 'NC|obj0_f0-rob0_v1')
# ('NC|obs0_f2-obj0_v1', 'NC|obs0_f0-rob0_v1', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f2-rob0_v0', 'NC|obj0_f1-rob0_f1')
# ('NC|obs0_f2-obj0_v1', 'NC|obs0_f0-rob0_v1', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f2-rob0_v0', 'NC|obj0_f2-rob0_f2')
# ('NC|obs0_f2-obj0_v1', 'NC|obs0_f0-rob0_v1', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f2-rob0_v0', 'NC|obj0_f3-rob0_v0')
# ('NC|obs0_f2-obj0_v1', 'NC|obs0_f1-rob0_v0', 'NC|obs1_f0-obj0_v3', 'NC|obs1_f0-rob0_v1', 'IC|obj0_f1-rob0_f1')
# ('NC|obs0_f2-obj0_v1', 'NC|obs0_f1-rob0_v0', 'NC|obs1_f0-obj0_v3', 'NC|obs1_f0-rob0_v1', 'IC|obj0_f2-rob0_f2')
# ('NC|obs0_f2-obj0_v1', 'NC|obs0_f1-rob0_v0', 'NC|obs1_f0-obj0_v3', 'NC|obs1_f0-rob0_v1', 'IC|obj0_f0-rob0_v1')
# ('NC|obs0_f2-obj0_v1', 'NC|obs0_f1-rob0_v0', 'NC|obs1_f0-obj0_v3', 'NC|obs1_f0-rob0_v1', 'IC|obj0_f3-rob0_v0')
# ('NC|obs0_f2-obj0_v1', 'NC|obs0_f1-rob0_v0', 'NC|obs1_f0-obj0_v3', 'NC|obs1_f0-rob0_v1', 'IC|obj0_v0-rob0_f0')
# ('NC|obs0_f2-obj0_v1', 'NC|obs0_f1-rob0_v0', 'NC|obs1_f0-obj0_v3', 'NC|obs1_f0-rob0_v1', 'NC|obj0_f0-rob0_v1')
# ('NC|obs0_f2-obj0_v1', 'NC|obs0_f1-rob0_v0', 'NC|obs1_f0-obj0_v3', 'NC|obs1_f0-rob0_v1', 'NC|obj0_f1-rob0_f1')
# ('NC|obs0_f2-obj0_v1', 'NC|obs0_f1-rob0_v0', 'NC|obs1_f0-obj0_v3', 'NC|obs1_f0-rob0_v1', 'NC|obj0_f2-rob0_f2')
# ('NC|obs0_f2-obj0_v1', 'NC|obs0_f1-rob0_v0', 'NC|obs1_f0-obj0_v3', 'NC|obs1_f0-rob0_v1', 'NC|obj0_f3-rob0_v0')
# ('NC|obs0_f2-obj0_v1', 'NC|obs0_f1-rob0_v0', 'NC|obs1_f0-obj0_v3', 'NC|obs1_f1-rob0_v2', 'NC|obj0_f1-rob0_f1')
# ('NC|obs0_f2-obj0_v1', 'NC|obs0_f1-rob0_v0', 'NC|obs1_f0-obj0_v3', 'NC|obs1_f1-rob0_v2', 'NC|obj0_f2-rob0_f2')
# ('NC|obs0_f2-obj0_v1', 'NC|obs0_f1-rob0_v0', 'NC|obs1_f0-obj0_v3', 'NC|obs1_f1-rob0_v2', 'NC|obj0_f3-rob0_v0')
# ('NC|obs0_f2-obj0_v1', 'NC|obs0_f1-rob0_v0', 'NC|obs1_f0-obj0_v3', 'NC|obs1_f2-rob0_v0', 'IC|obj0_f1-rob0_f1')
# ('NC|obs0_f2-obj0_v1', 'NC|obs0_f1-rob0_v0', 'NC|obs1_f0-obj0_v3', 'NC|obs1_f2-rob0_v0', 'IC|obj0_f2-rob0_f2')
# ('NC|obs0_f2-obj0_v1', 'NC|obs0_f1-rob0_v0', 'NC|obs1_f0-obj0_v3', 'NC|obs1_f2-rob0_v0', 'IC|obj0_f0-rob0_v1')
# ('NC|obs0_f2-obj0_v1', 'NC|obs0_f1-rob0_v0', 'NC|obs1_f0-obj0_v3', 'NC|obs1_f2-rob0_v0', 'IC|obj0_f3-rob0_v0')
# ('NC|obs0_f2-obj0_v1', 'NC|obs0_f1-rob0_v0', 'NC|obs1_f0-obj0_v3', 'NC|obs1_f2-rob0_v0', 'IC|obj0_v0-rob0_f0')
# ('NC|obs0_f2-obj0_v1', 'NC|obs0_f1-rob0_v0', 'NC|obs1_f0-obj0_v3', 'NC|obs1_f2-rob0_v0', 'NC|obj0_f0-rob0_v1')
# ('NC|obs0_f2-obj0_v1', 'NC|obs0_f1-rob0_v0', 'NC|obs1_f0-obj0_v3', 'NC|obs1_f2-rob0_v0', 'NC|obj0_f1-rob0_f1')
# ('NC|obs0_f2-obj0_v1', 'NC|obs0_f1-rob0_v0', 'NC|obs1_f0-obj0_v3', 'NC|obs1_f2-rob0_v0', 'NC|obj0_f2-rob0_f2')
# ('NC|obs0_f2-obj0_v1', 'NC|obs0_f1-rob0_v0', 'NC|obs1_f0-obj0_v3', 'NC|obs1_f2-rob0_v0', 'NC|obj0_f3-rob0_v0')
# ('NC|obs0_f2-obj0_v1', 'NC|obs0_f1-rob0_v0', 'NC|obs1_f1-obj0_v0', 'NC|obs1_f0-rob0_v1', 'NC|obj0_f0-rob0_v1')
# ('NC|obs0_f2-obj0_v1', 'NC|obs0_f1-rob0_v0', 'NC|obs1_f1-obj0_v0', 'NC|obs1_f0-rob0_v1', 'NC|obj0_f1-rob0_f1')
# ('NC|obs0_f2-obj0_v1', 'NC|obs0_f1-rob0_v0', 'NC|obs1_f1-obj0_v0', 'NC|obs1_f0-rob0_v1', 'NC|obj0_f3-rob0_v0')
# ('NC|obs0_f2-obj0_v1', 'NC|obs0_f1-rob0_v0', 'NC|obs1_f1-obj0_v0', 'NC|obs1_f1-rob0_v2', 'IC|obj0_f1-rob0_f1')
# ('NC|obs0_f2-obj0_v1', 'NC|obs0_f1-rob0_v0', 'NC|obs1_f1-obj0_v0', 'NC|obs1_f1-rob0_v2', 'IC|obj0_f2-rob0_f2')
# ('NC|obs0_f2-obj0_v1', 'NC|obs0_f1-rob0_v0', 'NC|obs1_f1-obj0_v0', 'NC|obs1_f1-rob0_v2', 'IC|obj0_f0-rob0_v1')
# ('NC|obs0_f2-obj0_v1', 'NC|obs0_f1-rob0_v0', 'NC|obs1_f1-obj0_v0', 'NC|obs1_f1-rob0_v2', 'IC|obj0_f3-rob0_v0')
# ('NC|obs0_f2-obj0_v1', 'NC|obs0_f1-rob0_v0', 'NC|obs1_f1-obj0_v0', 'NC|obs1_f1-rob0_v2', 'IC|obj0_v0-rob0_f0')
# ('NC|obs0_f2-obj0_v1', 'NC|obs0_f1-rob0_v0', 'NC|obs1_f1-obj0_v0', 'NC|obs1_f1-rob0_v2', 'NC|obj0_f0-rob0_v1')
# ('NC|obs0_f2-obj0_v1', 'NC|obs0_f1-rob0_v0', 'NC|obs1_f1-obj0_v0', 'NC|obs1_f1-rob0_v2', 'NC|obj0_f1-rob0_f1')
# ('NC|obs0_f2-obj0_v1', 'NC|obs0_f1-rob0_v0', 'NC|obs1_f1-obj0_v0', 'NC|obs1_f1-rob0_v2', 'NC|obj0_f2-rob0_f2')
# ('NC|obs0_f2-obj0_v1', 'NC|obs0_f1-rob0_v0', 'NC|obs1_f1-obj0_v0', 'NC|obs1_f1-rob0_v2', 'NC|obj0_f3-rob0_v0')
# ('NC|obs0_f2-obj0_v1', 'NC|obs0_f1-rob0_v0', 'NC|obs1_f1-obj0_v0', 'NC|obs1_f2-rob0_v0', 'IC|obj0_f1-rob0_f1')
# ('NC|obs0_f2-obj0_v1', 'NC|obs0_f1-rob0_v0', 'NC|obs1_f1-obj0_v0', 'NC|obs1_f2-rob0_v0', 'IC|obj0_f2-rob0_f2')
# ('NC|obs0_f2-obj0_v1', 'NC|obs0_f1-rob0_v0', 'NC|obs1_f1-obj0_v0', 'NC|obs1_f2-rob0_v0', 'IC|obj0_f0-rob0_v1')
# ('NC|obs0_f2-obj0_v1', 'NC|obs0_f1-rob0_v0', 'NC|obs1_f1-obj0_v0', 'NC|obs1_f2-rob0_v0', 'IC|obj0_f3-rob0_v0')
# ('NC|obs0_f2-obj0_v1', 'NC|obs0_f1-rob0_v0', 'NC|obs1_f1-obj0_v0', 'NC|obs1_f2-rob0_v0', 'IC|obj0_v0-rob0_f0')
# ('NC|obs0_f2-obj0_v1', 'NC|obs0_f1-rob0_v0', 'NC|obs1_f1-obj0_v0', 'NC|obs1_f2-rob0_v0', 'NC|obj0_f0-rob0_v1')
# ('NC|obs0_f2-obj0_v1', 'NC|obs0_f1-rob0_v0', 'NC|obs1_f1-obj0_v0', 'NC|obs1_f2-rob0_v0', 'NC|obj0_f1-rob0_f1')
# ('NC|obs0_f2-obj0_v1', 'NC|obs0_f1-rob0_v0', 'NC|obs1_f1-obj0_v0', 'NC|obs1_f2-rob0_v0', 'NC|obj0_f2-rob0_f2')
# ('NC|obs0_f2-obj0_v1', 'NC|obs0_f1-rob0_v0', 'NC|obs1_f1-obj0_v0', 'NC|obs1_f2-rob0_v0', 'NC|obj0_f3-rob0_v0')
# ('NC|obs0_f2-obj0_v1', 'NC|obs0_f1-rob0_v0', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f0-rob0_v1', 'IC|obj0_f1-rob0_f1')
# ('NC|obs0_f2-obj0_v1', 'NC|obs0_f1-rob0_v0', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f0-rob0_v1', 'IC|obj0_f2-rob0_f2')
# ('NC|obs0_f2-obj0_v1', 'NC|obs0_f1-rob0_v0', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f0-rob0_v1', 'IC|obj0_f0-rob0_v1')
# ('NC|obs0_f2-obj0_v1', 'NC|obs0_f1-rob0_v0', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f0-rob0_v1', 'IC|obj0_f3-rob0_v0')
# ('NC|obs0_f2-obj0_v1', 'NC|obs0_f1-rob0_v0', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f0-rob0_v1', 'IC|obj0_v0-rob0_f0')
# ('NC|obs0_f2-obj0_v1', 'NC|obs0_f1-rob0_v0', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f0-rob0_v1', 'NC|obj0_f0-rob0_v1')
# ('NC|obs0_f2-obj0_v1', 'NC|obs0_f1-rob0_v0', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f0-rob0_v1', 'NC|obj0_f1-rob0_f1')
# ('NC|obs0_f2-obj0_v1', 'NC|obs0_f1-rob0_v0', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f0-rob0_v1', 'NC|obj0_f2-rob0_f2')
# ('NC|obs0_f2-obj0_v1', 'NC|obs0_f1-rob0_v0', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f0-rob0_v1', 'NC|obj0_f3-rob0_v0')
# ('NC|obs0_f2-obj0_v1', 'NC|obs0_f1-rob0_v0', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f1-rob0_v2', 'IC|obj0_f1-rob0_f1')
# ('NC|obs0_f2-obj0_v1', 'NC|obs0_f1-rob0_v0', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f1-rob0_v2', 'IC|obj0_f2-rob0_f2')
# ('NC|obs0_f2-obj0_v1', 'NC|obs0_f1-rob0_v0', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f1-rob0_v2', 'IC|obj0_f0-rob0_v1')
# ('NC|obs0_f2-obj0_v1', 'NC|obs0_f1-rob0_v0', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f1-rob0_v2', 'IC|obj0_f3-rob0_v0')
# ('NC|obs0_f2-obj0_v1', 'NC|obs0_f1-rob0_v0', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f1-rob0_v2', 'IC|obj0_v0-rob0_f0')
# ('NC|obs0_f2-obj0_v1', 'NC|obs0_f1-rob0_v0', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f1-rob0_v2', 'NC|obj0_f0-rob0_v1')
# ('NC|obs0_f2-obj0_v1', 'NC|obs0_f1-rob0_v0', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f1-rob0_v2', 'NC|obj0_f1-rob0_f1')
# ('NC|obs0_f2-obj0_v1', 'NC|obs0_f1-rob0_v0', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f1-rob0_v2', 'NC|obj0_f2-rob0_f2')
# ('NC|obs0_f2-obj0_v1', 'NC|obs0_f1-rob0_v0', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f1-rob0_v2', 'NC|obj0_f3-rob0_v0')
# ('NC|obs0_f2-obj0_v1', 'NC|obs0_f1-rob0_v0', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f2-rob0_v0', 'IC|obj0_f1-rob0_f1')
# ('NC|obs0_f2-obj0_v1', 'NC|obs0_f1-rob0_v0', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f2-rob0_v0', 'IC|obj0_f2-rob0_f2')
# ('NC|obs0_f2-obj0_v1', 'NC|obs0_f1-rob0_v0', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f2-rob0_v0', 'IC|obj0_f0-rob0_v1')
# ('NC|obs0_f2-obj0_v1', 'NC|obs0_f1-rob0_v0', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f2-rob0_v0', 'IC|obj0_f3-rob0_v0')
# ('NC|obs0_f2-obj0_v1', 'NC|obs0_f1-rob0_v0', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f2-rob0_v0', 'IC|obj0_v0-rob0_f0')
# ('NC|obs0_f2-obj0_v1', 'NC|obs0_f1-rob0_v0', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f2-rob0_v0', 'NC|obj0_f0-rob0_v1')
# ('NC|obs0_f2-obj0_v1', 'NC|obs0_f1-rob0_v0', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f2-rob0_v0', 'NC|obj0_f1-rob0_f1')
# ('NC|obs0_f2-obj0_v1', 'NC|obs0_f1-rob0_v0', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f2-rob0_v0', 'NC|obj0_f2-rob0_f2')
# ('NC|obs0_f2-obj0_v1', 'NC|obs0_f1-rob0_v0', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f2-rob0_v0', 'NC|obj0_f3-rob0_v0')
# ('NC|obs0_f2-obj0_v1', 'NC|obs0_f2-rob0_v0', 'NC|obs1_f0-obj0_v3', 'NC|obs1_f0-rob0_v1', 'IC|obj0_f1-rob0_f1')
# ('NC|obs0_f2-obj0_v1', 'NC|obs0_f2-rob0_v0', 'NC|obs1_f0-obj0_v3', 'NC|obs1_f0-rob0_v1', 'IC|obj0_f2-rob0_f2')
# ('NC|obs0_f2-obj0_v1', 'NC|obs0_f2-rob0_v0', 'NC|obs1_f0-obj0_v3', 'NC|obs1_f0-rob0_v1', 'IC|obj0_f0-rob0_v1')
# ('NC|obs0_f2-obj0_v1', 'NC|obs0_f2-rob0_v0', 'NC|obs1_f0-obj0_v3', 'NC|obs1_f0-rob0_v1', 'IC|obj0_f3-rob0_v0')
# ('NC|obs0_f2-obj0_v1', 'NC|obs0_f2-rob0_v0', 'NC|obs1_f0-obj0_v3', 'NC|obs1_f0-rob0_v1', 'IC|obj0_v0-rob0_f0')
# ('NC|obs0_f2-obj0_v1', 'NC|obs0_f2-rob0_v0', 'NC|obs1_f0-obj0_v3', 'NC|obs1_f0-rob0_v1', 'NC|obj0_f0-rob0_v1')
# ('NC|obs0_f2-obj0_v1', 'NC|obs0_f2-rob0_v0', 'NC|obs1_f0-obj0_v3', 'NC|obs1_f0-rob0_v1', 'NC|obj0_f1-rob0_f1')
# ('NC|obs0_f2-obj0_v1', 'NC|obs0_f2-rob0_v0', 'NC|obs1_f0-obj0_v3', 'NC|obs1_f0-rob0_v1', 'NC|obj0_f2-rob0_f2')
# ('NC|obs0_f2-obj0_v1', 'NC|obs0_f2-rob0_v0', 'NC|obs1_f0-obj0_v3', 'NC|obs1_f0-rob0_v1', 'NC|obj0_f3-rob0_v0')
# ('NC|obs0_f2-obj0_v1', 'NC|obs0_f2-rob0_v0', 'NC|obs1_f0-obj0_v3', 'NC|obs1_f1-rob0_v2', 'NC|obj0_f1-rob0_f1')
# ('NC|obs0_f2-obj0_v1', 'NC|obs0_f2-rob0_v0', 'NC|obs1_f0-obj0_v3', 'NC|obs1_f1-rob0_v2', 'NC|obj0_f2-rob0_f2')
# ('NC|obs0_f2-obj0_v1', 'NC|obs0_f2-rob0_v0', 'NC|obs1_f0-obj0_v3', 'NC|obs1_f1-rob0_v2', 'NC|obj0_f3-rob0_v0')
# ('NC|obs0_f2-obj0_v1', 'NC|obs0_f2-rob0_v0', 'NC|obs1_f0-obj0_v3', 'NC|obs1_f2-rob0_v0', 'IC|obj0_f1-rob0_f1')
# ('NC|obs0_f2-obj0_v1', 'NC|obs0_f2-rob0_v0', 'NC|obs1_f0-obj0_v3', 'NC|obs1_f2-rob0_v0', 'IC|obj0_f2-rob0_f2')
# ('NC|obs0_f2-obj0_v1', 'NC|obs0_f2-rob0_v0', 'NC|obs1_f0-obj0_v3', 'NC|obs1_f2-rob0_v0', 'IC|obj0_f0-rob0_v1')
# ('NC|obs0_f2-obj0_v1', 'NC|obs0_f2-rob0_v0', 'NC|obs1_f0-obj0_v3', 'NC|obs1_f2-rob0_v0', 'IC|obj0_f3-rob0_v0')
# ('NC|obs0_f2-obj0_v1', 'NC|obs0_f2-rob0_v0', 'NC|obs1_f0-obj0_v3', 'NC|obs1_f2-rob0_v0', 'IC|obj0_v0-rob0_f0')
# ('NC|obs0_f2-obj0_v1', 'NC|obs0_f2-rob0_v0', 'NC|obs1_f0-obj0_v3', 'NC|obs1_f2-rob0_v0', 'NC|obj0_f0-rob0_v1')
# ('NC|obs0_f2-obj0_v1', 'NC|obs0_f2-rob0_v0', 'NC|obs1_f0-obj0_v3', 'NC|obs1_f2-rob0_v0', 'NC|obj0_f1-rob0_f1')
# ('NC|obs0_f2-obj0_v1', 'NC|obs0_f2-rob0_v0', 'NC|obs1_f0-obj0_v3', 'NC|obs1_f2-rob0_v0', 'NC|obj0_f2-rob0_f2')
# ('NC|obs0_f2-obj0_v1', 'NC|obs0_f2-rob0_v0', 'NC|obs1_f0-obj0_v3', 'NC|obs1_f2-rob0_v0', 'NC|obj0_f3-rob0_v0')
# ('NC|obs0_f2-obj0_v1', 'NC|obs0_f2-rob0_v0', 'NC|obs1_f1-obj0_v0', 'NC|obs1_f0-rob0_v1', 'NC|obj0_f0-rob0_v1')
# ('NC|obs0_f2-obj0_v1', 'NC|obs0_f2-rob0_v0', 'NC|obs1_f1-obj0_v0', 'NC|obs1_f0-rob0_v1', 'NC|obj0_f1-rob0_f1')
# ('NC|obs0_f2-obj0_v1', 'NC|obs0_f2-rob0_v0', 'NC|obs1_f1-obj0_v0', 'NC|obs1_f0-rob0_v1', 'NC|obj0_f3-rob0_v0')
# ('NC|obs0_f2-obj0_v1', 'NC|obs0_f2-rob0_v0', 'NC|obs1_f1-obj0_v0', 'NC|obs1_f1-rob0_v2', 'IC|obj0_f1-rob0_f1')
# ('NC|obs0_f2-obj0_v1', 'NC|obs0_f2-rob0_v0', 'NC|obs1_f1-obj0_v0', 'NC|obs1_f1-rob0_v2', 'IC|obj0_f2-rob0_f2')
# ('NC|obs0_f2-obj0_v1', 'NC|obs0_f2-rob0_v0', 'NC|obs1_f1-obj0_v0', 'NC|obs1_f1-rob0_v2', 'IC|obj0_f0-rob0_v1')
# ('NC|obs0_f2-obj0_v1', 'NC|obs0_f2-rob0_v0', 'NC|obs1_f1-obj0_v0', 'NC|obs1_f1-rob0_v2', 'IC|obj0_f3-rob0_v0')
# ('NC|obs0_f2-obj0_v1', 'NC|obs0_f2-rob0_v0', 'NC|obs1_f1-obj0_v0', 'NC|obs1_f1-rob0_v2', 'IC|obj0_v0-rob0_f0')
# ('NC|obs0_f2-obj0_v1', 'NC|obs0_f2-rob0_v0', 'NC|obs1_f1-obj0_v0', 'NC|obs1_f1-rob0_v2', 'NC|obj0_f0-rob0_v1')
# ('NC|obs0_f2-obj0_v1', 'NC|obs0_f2-rob0_v0', 'NC|obs1_f1-obj0_v0', 'NC|obs1_f1-rob0_v2', 'NC|obj0_f1-rob0_f1')
# ('NC|obs0_f2-obj0_v1', 'NC|obs0_f2-rob0_v0', 'NC|obs1_f1-obj0_v0', 'NC|obs1_f1-rob0_v2', 'NC|obj0_f2-rob0_f2')
# ('NC|obs0_f2-obj0_v1', 'NC|obs0_f2-rob0_v0', 'NC|obs1_f1-obj0_v0', 'NC|obs1_f1-rob0_v2', 'NC|obj0_f3-rob0_v0')
# ('NC|obs0_f2-obj0_v1', 'NC|obs0_f2-rob0_v0', 'NC|obs1_f1-obj0_v0', 'NC|obs1_f2-rob0_v0', 'IC|obj0_f1-rob0_f1')
# ('NC|obs0_f2-obj0_v1', 'NC|obs0_f2-rob0_v0', 'NC|obs1_f1-obj0_v0', 'NC|obs1_f2-rob0_v0', 'IC|obj0_f2-rob0_f2')
# ('NC|obs0_f2-obj0_v1', 'NC|obs0_f2-rob0_v0', 'NC|obs1_f1-obj0_v0', 'NC|obs1_f2-rob0_v0', 'IC|obj0_f0-rob0_v1')
# ('NC|obs0_f2-obj0_v1', 'NC|obs0_f2-rob0_v0', 'NC|obs1_f1-obj0_v0', 'NC|obs1_f2-rob0_v0', 'IC|obj0_f3-rob0_v0')
# ('NC|obs0_f2-obj0_v1', 'NC|obs0_f2-rob0_v0', 'NC|obs1_f1-obj0_v0', 'NC|obs1_f2-rob0_v0', 'IC|obj0_v0-rob0_f0')
# ('NC|obs0_f2-obj0_v1', 'NC|obs0_f2-rob0_v0', 'NC|obs1_f1-obj0_v0', 'NC|obs1_f2-rob0_v0', 'NC|obj0_f0-rob0_v1')
# ('NC|obs0_f2-obj0_v1', 'NC|obs0_f2-rob0_v0', 'NC|obs1_f1-obj0_v0', 'NC|obs1_f2-rob0_v0', 'NC|obj0_f1-rob0_f1')
# ('NC|obs0_f2-obj0_v1', 'NC|obs0_f2-rob0_v0', 'NC|obs1_f1-obj0_v0', 'NC|obs1_f2-rob0_v0', 'NC|obj0_f2-rob0_f2')
# ('NC|obs0_f2-obj0_v1', 'NC|obs0_f2-rob0_v0', 'NC|obs1_f1-obj0_v0', 'NC|obs1_f2-rob0_v0', 'NC|obj0_f3-rob0_v0')
# ('NC|obs0_f2-obj0_v1', 'NC|obs0_f2-rob0_v0', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f0-rob0_v1', 'IC|obj0_f1-rob0_f1')
# ('NC|obs0_f2-obj0_v1', 'NC|obs0_f2-rob0_v0', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f0-rob0_v1', 'IC|obj0_f2-rob0_f2')
# ('NC|obs0_f2-obj0_v1', 'NC|obs0_f2-rob0_v0', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f0-rob0_v1', 'IC|obj0_f0-rob0_v1')
# ('NC|obs0_f2-obj0_v1', 'NC|obs0_f2-rob0_v0', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f0-rob0_v1', 'IC|obj0_f3-rob0_v0')
# ('NC|obs0_f2-obj0_v1', 'NC|obs0_f2-rob0_v0', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f0-rob0_v1', 'IC|obj0_v0-rob0_f0')
# ('NC|obs0_f2-obj0_v1', 'NC|obs0_f2-rob0_v0', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f0-rob0_v1', 'NC|obj0_f0-rob0_v1')
# ('NC|obs0_f2-obj0_v1', 'NC|obs0_f2-rob0_v0', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f0-rob0_v1', 'NC|obj0_f1-rob0_f1')
# ('NC|obs0_f2-obj0_v1', 'NC|obs0_f2-rob0_v0', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f0-rob0_v1', 'NC|obj0_f2-rob0_f2')
# ('NC|obs0_f2-obj0_v1', 'NC|obs0_f2-rob0_v0', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f0-rob0_v1', 'NC|obj0_f3-rob0_v0')
# ('NC|obs0_f2-obj0_v1', 'NC|obs0_f2-rob0_v0', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f1-rob0_v2', 'IC|obj0_f1-rob0_f1')
# ('NC|obs0_f2-obj0_v1', 'NC|obs0_f2-rob0_v0', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f1-rob0_v2', 'IC|obj0_f2-rob0_f2')
# ('NC|obs0_f2-obj0_v1', 'NC|obs0_f2-rob0_v0', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f1-rob0_v2', 'IC|obj0_f0-rob0_v1')
# ('NC|obs0_f2-obj0_v1', 'NC|obs0_f2-rob0_v0', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f1-rob0_v2', 'IC|obj0_f3-rob0_v0')
# ('NC|obs0_f2-obj0_v1', 'NC|obs0_f2-rob0_v0', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f1-rob0_v2', 'IC|obj0_v0-rob0_f0')
# ('NC|obs0_f2-obj0_v1', 'NC|obs0_f2-rob0_v0', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f1-rob0_v2', 'NC|obj0_f0-rob0_v1')
# ('NC|obs0_f2-obj0_v1', 'NC|obs0_f2-rob0_v0', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f1-rob0_v2', 'NC|obj0_f1-rob0_f1')
# ('NC|obs0_f2-obj0_v1', 'NC|obs0_f2-rob0_v0', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f1-rob0_v2', 'NC|obj0_f2-rob0_f2')
# ('NC|obs0_f2-obj0_v1', 'NC|obs0_f2-rob0_v0', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f1-rob0_v2', 'NC|obj0_f3-rob0_v0')
# ('NC|obs0_f2-obj0_v1', 'NC|obs0_f2-rob0_v0', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f2-rob0_v0', 'IC|obj0_f1-rob0_f1')
# ('NC|obs0_f2-obj0_v1', 'NC|obs0_f2-rob0_v0', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f2-rob0_v0', 'IC|obj0_f2-rob0_f2')
# ('NC|obs0_f2-obj0_v1', 'NC|obs0_f2-rob0_v0', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f2-rob0_v0', 'IC|obj0_f0-rob0_v1')
# ('NC|obs0_f2-obj0_v1', 'NC|obs0_f2-rob0_v0', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f2-rob0_v0', 'IC|obj0_f3-rob0_v0')
# ('NC|obs0_f2-obj0_v1', 'NC|obs0_f2-rob0_v0', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f2-rob0_v0', 'IC|obj0_v0-rob0_f0')
# ('NC|obs0_f2-obj0_v1', 'NC|obs0_f2-rob0_v0', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f2-rob0_v0', 'NC|obj0_f0-rob0_v1')
# ('NC|obs0_f2-obj0_v1', 'NC|obs0_f2-rob0_v0', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f2-rob0_v0', 'NC|obj0_f1-rob0_f1')
# ('NC|obs0_f2-obj0_v1', 'NC|obs0_f2-rob0_v0', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f2-rob0_v0', 'NC|obj0_f2-rob0_f2')
# ('NC|obs0_f2-obj0_v1', 'NC|obs0_f2-rob0_v0', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f2-rob0_v0', 'NC|obj0_f3-rob0_v0')
# source
# target

# %%
gpt_ans = ['source',
"('NC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f1-rob0_v2', 'NC|obj0_f1-rob0_f1')",
"('NC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f1-rob0_v1', 'NC|obj0_f1-rob0_f1')",
"('NC|obs0_f0-obj0_v3', 'NC|obs0_f1-rob0_v1', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f1-rob0_v1', 'NC|obj0_f1-rob0_f1')",
"('NC|obs0_f0-obj0_v3', 'NC|obs0_f1-rob0_v1', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f2-rob0_v1', 'NC|obj0_f1-rob0_f1')",
"('NC|obs0_f0-obj0_v3', 'NC|obs0_f1-rob0_v0', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f2-rob0_v1', 'NC|obj0_f1-rob0_f1')",
"('NC|obs0_f0-obj0_v3', 'NC|obs0_f1-rob0_v0', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f2-rob0_v0', 'NC|obj0_f1-rob0_f1')",
"('NC|obs0_f0-obj0_v3', 'NC|obs0_f1-rob0_v0', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f2-rob0_v0', 'NC|obj0_f2-rob0_f1')",
"('NC|obs0_f1-obj0_v3', 'NC|obs0_f1-rob0_v0', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f2-rob0_v0', 'NC|obj0_f2-rob0_f1')",
"('NC|obs0_f1-obj0_v1', 'NC|obs0_f1-rob0_v0', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f2-rob0_v0', 'NC|obj0_f2-rob0_f1')",
"('NC|obs0_f1-obj0_v1', 'NC|obs0_f1-rob0_v0', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f2-rob0_v0', 'NC|obj0_f2-rob0_f1')",
"('NC|obs0_f1-obj0_v1', 'NC|obs0_f1-rob0_v0', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f2-rob0_v0', 'NC|obj0_f2-rob0_f2')",
"('NC|obs0_f2-obj0_v1', 'NC|obs0_f1-rob0_v0', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f2-rob0_v0', 'NC|obj0_f2-rob0_f2')",
"('NC|obs0_f2-obj0_v1', 'NC|obs0_f1-rob0_v0', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f2-rob0_v0', 'NC|obj0_f2-rob0_f2')",
'target']
for name in gpt_ans:
    # print(name in cg.vertex_names)
    if name not in cg.vertex_names:
        print(name)
# Out:
# ('NC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f1-rob0_v1', 'NC|obj0_f1-rob0_f1')
# ('NC|obs0_f0-obj0_v3', 'NC|obs0_f1-rob0_v1', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f1-rob0_v1', 'NC|obj0_f1-rob0_f1')
# ('NC|obs0_f0-obj0_v3', 'NC|obs0_f1-rob0_v1', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f2-rob0_v1', 'NC|obj0_f1-rob0_f1')
# ('NC|obs0_f0-obj0_v3', 'NC|obs0_f1-rob0_v0', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f2-rob0_v1', 'NC|obj0_f1-rob0_f1')
# ('NC|obs0_f0-obj0_v3', 'NC|obs0_f1-rob0_v0', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f2-rob0_v0', 'NC|obj0_f2-rob0_f1')
# ('NC|obs0_f1-obj0_v3', 'NC|obs0_f1-rob0_v0', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f2-rob0_v0', 'NC|obj0_f2-rob0_f1')
# ('NC|obs0_f1-obj0_v1', 'NC|obs0_f1-rob0_v0', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f2-rob0_v0', 'NC|obj0_f2-rob0_f1')
# ('NC|obs0_f1-obj0_v1', 'NC|obs0_f1-rob0_v0', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f2-rob0_v0', 'NC|obj0_f2-rob0_f1')

# %%
vertex_inclusion = [
    "source",
    "('NC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f1-rob0_v2', 'NC|obj0_f1-rob0_f1')",
    "('NC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f2-rob0_v0', 'NC|obj0_f1-rob0_f1')",
    "('NC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f2-rob0_v0', 'IC|obj0_f1-rob0_f1')",
    "('IC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f2-rob0_v0', 'IC|obj0_f1-rob0_f1')",
    "('IC|obs0_v0-obj0_f2', 'NC|obs0_f0-rob0_v1', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f2-rob0_v0', 'IC|obj0_f1-rob0_f1')",
    "('IC|obs0_v0-obj0_f2', 'NC|obs0_f0-rob0_v1', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f0-rob0_v1', 'IC|obj0_f1-rob0_f1')",
    "('IC|obs0_v0-obj0_f1', 'NC|obs0_f0-rob0_v1', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f0-rob0_v1', 'NC|obj0_f0-rob0_v1')",
    "('IC|obs0_v0-obj0_f1', 'NC|obs0_f2-rob0_v0', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f0-rob0_v1', 'NC|obj0_f0-rob0_v1')",
    "('IC|obs0_v0-obj0_f1', 'NC|obs0_f2-rob0_v0', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f2-rob0_v0', 'IC|obj0_f0-rob0_v1')",
    "('NC|obs0_f2-obj0_v1', 'NC|obs0_f2-rob0_v0', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f2-rob0_v0', 'IC|obj0_f0-rob0_v1')",
    "('NC|obs0_f2-obj0_v1', 'NC|obs0_f2-rob0_v0', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f2-rob0_v0', 'IC|obj0_v0-rob0_f0')",
    "('NC|obs0_f2-obj0_v1', 'NC|obs0_f2-rob0_v0', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f2-rob0_v0', 'IC|obj0_f3-rob0_v0')",
    "('NC|obs0_f2-obj0_v1', 'NC|obs0_f1-rob0_v0', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f2-rob0_v0', 'NC|obj0_f2-rob0_f2')",
    "target",
]

# for i in range(len(vertex_inclusion) - 1):
#     has_edge_to_next_vertex = any(
#         edge.v == vertex_inclusion[i + 1]
#         for edge in cg.outgoing_edges(vertex_inclusion[i])
#     )
#     print(
#         f"{vertex_inclusion[i]} -> {vertex_inclusion[i+1]}: {has_edge_to_next_vertex}"
#     )

# %%
cg_sol_only = ContactGraph.load_from_file(
    ContactGraphGeneratorParams.graph_file_path_from_name("cg_maze_a2"),
    vertex_inclusion=vertex_inclusion,
)
cg_sol_only.set_target(vertex_inclusion[-1])
cg_sol_only.workspace = [[-4, 4], [-5, 3]]
# Out:
# INFO:large_gcs.graph.contact_graph:Loading 35 contact pair modes for 4 bodies...
# INFO:large_gcs.graph.contact_graph:Generating contact sets for 1234 sets...
# 100%|██████████| 1234/1234 [00:02<00:00, 543.40it/s]
# INFO:large_gcs.graph.contact_graph:Filtering sets for inclusion strings ['source', "('NC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f1-rob0_v2', 'NC|obj0_f1-rob0_f1')", "('NC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f2-rob0_v0', 'NC|obj0_f1-rob0_f1')", "('NC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f2-rob0_v0', 'IC|obj0_f1-rob0_f1')", "('IC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f2-rob0_v0', 'IC|obj0_f1-rob0_f1')", "('IC|obs0_v0-obj0_f2', 'NC|obs0_f0-rob0_v1', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f2-rob0_v0', 'IC|obj0_f1-rob0_f1')", "('IC|obs0_v0-obj0_f2', 'NC|obs0_f0-rob0_v1', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f0-rob0_v1', 'IC|obj0_f1-rob0_f1')", "('IC|obs0_v0-obj0_f1', 'NC|obs0_f0-rob0_v1', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f0-rob0_v1', 'NC|obj0_f0-rob0_v1')", "('IC|obs0_v0-obj0_f1', 'NC|obs0_f2-rob0_v0', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f0-rob0_v1', 'NC|obj0_f0-rob0_v1')", "('IC|obs0_v0-obj0_f1', 'NC|obs0_f2-rob0_v0', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f2-rob0_v0', 'IC|obj0_f0-rob0_v1')", "('NC|obs0_f2-obj0_v1', 'NC|obs0_f2-rob0_v0', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f2-rob0_v0', 'IC|obj0_f0-rob0_v1')", "('NC|obs0_f2-obj0_v1', 'NC|obs0_f2-rob0_v0', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f2-rob0_v0', 'IC|obj0_v0-rob0_f0')", "('NC|obs0_f2-obj0_v1', 'NC|obs0_f2-rob0_v0', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f2-rob0_v0', 'IC|obj0_f3-rob0_v0')", "('NC|obs0_f2-obj0_v1', 'NC|obs0_f1-rob0_v0', 'NC|obs1_f2-obj0_v1', 'NC|obs1_f2-rob0_v0', 'NC|obj0_f2-rob0_f2')", 'target']
# 100%|██████████| 1234/1234 [00:00<00:00, 7161.51it/s]
# INFO:large_gcs.graph.contact_graph:13 sets remain after filtering for inclusion sets
# INFO:large_gcs.graph.contact_graph:Creating vertex costs...
# 100%|██████████| 15/15 [00:00<00:00, 6181.43it/s]
# INFO:large_gcs.graph.graph:Adding 15 vertices to graph...
# 100%|██████████| 15/15 [00:00<00:00, 5563.72it/s]
# INFO:large_gcs.graph.contact_graph:Creating edge costs...
# 100%|██████████| 44/44 [00:00<00:00, 6459.78it/s]
# INFO:large_gcs.graph.contact_graph:Creating edge constraints...
# 100%|██████████| 44/44 [00:00<00:00, 3786.17it/s]
# INFO:large_gcs.graph.graph:Adding 44 edges to graph...
# 100%|██████████| 44/44 [00:00<00:00, 4910.19it/s]
# INFO:large_gcs.graph.contact_graph:Created contact graph: GraphParams(dim_bounds=(4, 18), n_vertices=15, n_edges=44, source=[array([1.600, 0.600]), array([3.250, 0.000])], target=[array([-2.300, -0.700]), array([-0.500, 2.000])], workspace=array([[-4,  4],
#        [-3,  3]]), default_costs_constraints=None)

# %%
# cg_sol_only.graphviz()

# %%
active_edges = []
for i in range(len(vertex_inclusion) - 1):
    active_edges.append(
        cg_sol_only.edges[(vertex_inclusion[i], vertex_inclusion[i + 1])]
    )
# sol = cg_sol_only.solve_convex_restriction(active_edges)
sol = cg_sol_only.solve(use_convex_relaxation=False)
print(sol.vertex_path)
print(sol.cost)
print(sol.time)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 active_edges = []
# ----> 2 for i in range(len(vertex_inclusion) - 1):
#       3     active_edges.append(
#       4         cg_sol_only.edges[(vertex_inclusion[i], vertex_inclusion[i + 1])]
#       5     )
#       6 # sol = cg_sol_only.solve_convex_restriction(active_edges)
#
# NameError: name 'vertex_inclusion' is not defined

# %%
contact_sol = cg_sol_only.contact_spp_sol

# %%
from IPython.display import HTML

anim = cg_sol_only.animate_solution()
# save as mp4
HTML(anim.to_html5_video())
# Out:
# INFO:matplotlib.animation:Animation.save using <class 'matplotlib.animation.FFMpegWriter'>
# INFO:matplotlib.animation:MovieWriter._run: running command: ffmpeg -f rawvideo -vcodec rawvideo -s 640x480 -pix_fmt rgba -r 20.0 -loglevel error -i pipe: -vcodec h264 -pix_fmt yuv420p -y /tmp/tmpokc106_z/temp.m4v
# <video width="640" height="480" controls autoplay loop>
#   <source type="video/mp4" src="...

# %%
anim.save("cg_maze_a2_manual.mp4")
# Out:
# INFO:matplotlib.animation:Animation.save using <class 'matplotlib.animation.FFMpegWriter'>
# INFO:matplotlib.animation:MovieWriter._run: running command: ffmpeg -f rawvideo -vcodec rawvideo -s 640x480 -pix_fmt rgba -r 20.0 -loglevel error -i pipe: -vcodec h264 -pix_fmt yuv420p -y cg_maze_a2_manual.mp4
