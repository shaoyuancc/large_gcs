# %% [markdown]
# # Contact Graph Generator

# %%
from large_gcs.example_graphs.utils.contact_graph_generator import (
    ContactGraphGeneratorParams,
    ContactGraphGenerator,
)
from large_gcs.graph.contact_graph import ContactGraph
from large_gcs.algorithms.gcs_astar_convex_restriction import GcsAstarConvexRestriction
from large_gcs.graph.contact_cost_constraint_factory import (
    contact_shortcut_edge_cost_factory_over_obj_weighted,
)

import numpy as np

np.set_printoptions(formatter={"float": lambda x: "{0:0.3f}".format(x)})

# %%
ws_x = 4
ws_y = 3
params = ContactGraphGeneratorParams(
    name="cg_trichal2",
    obs_vertices=[[[-1, 2], [-1, -1], [2, 2]]],
    obj_vertices=[[[1, 0.5], [1, -0.5], [2, -0.5], [2, 0.5]]],
    rob_vertices=[[[3, 1], [3, 0], [3.5, 0]]],
    source_obj_pos=[[3.25, 0]],
    source_rob_pos=[[1.5, 0.5]],
    target_obj_pos=[[-1.5, 0]],
    target_rob_pos=[[-3, 0]],
    n_pos_per_set=2,
    workspace=[[-ws_x, ws_x], [-ws_y, ws_y]],
)

generator = ContactGraphGenerator(params)
generator.plot()

# %%
# generator.generate()

# %%
cg = ContactGraph.load_from_file(params.graph_file_path)
# Out:
# Loading 20 contact pair modes for 3 bodies...
# Generating contact sets for 179 sets...
# 100%|██████████| 179/179 [00:02<00:00, 66.80it/s]
# Adding 181 vertices to graph...
# 100%|██████████| 181/181 [00:00<00:00, 5937.92it/s]
# Adding 6408 edges to graph...
# 100%|██████████| 6408/6408 [00:01<00:00, 3486.40it/s]
# Created contact graph: GraphParams(dim_bounds=(4, 18), n_vertices=181, n_edges=6408, source=[array([3.250, 0.000]), array([1.500, 0.500])], target=[array([-1.500, 0.000]), array([-3,  0])], workspace=array([[-4,  4],
#        [-3,  3]]), default_costs_constraints=None)

# %% [markdown]
# Just checking that everything works

# %%
# gcs_astar = GcsAstarConvexRestriction(
#     cg,
#     should_reexplore=True,
#     shortcut_edge_cost_factory=contact_shortcut_edge_cost_factory_over_obj_weighted,
# )
# sol = gcs_astar.run(verbose=True, animate=False)
# Out:
# Running GcsAstarConvexRestriction, should_rexplore: True, use_convex_relaxation: False, shortcut_edge_cost_factory: contact_shortcut_edge_cost_factory_over_obj_weighted
#
# n_vertices_visited: 2, n_edges_visited: 0, n_vertices_explored: 0, vertex_coverage: 0.011, edge_coverage: 0, time_wall_clock: 0, n_gcs_solves: 0, gcs_solve_time_total: 0, gcs_solve_time_iter_mean: 0, gcs_solve_time_last_10_mean: 0, gcs_solve_time_iter_std: 0, gcs_solve_time_iter_min: inf, gcs_solve_time_iter_max: 0, n_vertices_revisited: 0, n_vertices_reexplored: 0
# now exploring node source's 1 neighbors (0)
# edge source -> ('NC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'NC|obj0_f3-rob0_v0') is feasible, new dist: 241.0487381277758, added to pq True
#
# n_vertices_visited: 3, n_edges_visited: 1, n_vertices_explored: 1, vertex_coverage: 0.0166, edge_coverage: 0.0002, time_wall_clock: 0.00543, n_gcs_solves: 1, gcs_solve_time_total: 0.00257, gcs_solve_time_iter_mean: 0.00257, gcs_solve_time_last_10_mean: 0, gcs_solve_time_iter_std: 0, gcs_solve_time_iter_min: 0.00257, gcs_solve_time_iter_max: 0.00257, n_vertices_revisited: 0, n_vertices_reexplored: 0
# now exploring node ('NC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'NC|obj0_f3-rob0_v0')'s 56 neighbors (241.0487381277758)
# edge ('NC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'NC|obj0_f3-rob0_v0') -> ('IC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'NC|obj0_f0-rob0_v1') not actually feasible
# edge ('NC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'NC|obj0_f3-rob0_v0') -> ('IC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'NC|obj0_f3-rob0_v0') not actually feasible
# edge ('NC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'NC|obj0_f3-rob0_v0') -> ('IC|obs0_f0-obj0_v3', 'NC|obs0_f2-rob0_v0', 'NC|obj0_f0-rob0_v1') not actually feasible
# edge ('NC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'NC|obj0_f3-rob0_v0') -> ('IC|obs0_f0-obj0_v3', 'NC|obs0_f2-rob0_v0', 'NC|obj0_f3-rob0_v0') not actually feasible
# edge ('NC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'NC|obj0_f3-rob0_v0') -> ('IC|obs0_v0-obj0_f2', 'NC|obs0_f0-rob0_v1', 'NC|obj0_f0-rob0_v1') not actually feasible
# edge ('NC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'NC|obj0_f3-rob0_v0') -> ('IC|obs0_v0-obj0_f2', 'NC|obs0_f0-rob0_v1', 'NC|obj0_f3-rob0_v0') not actually feasible
# edge ('NC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'NC|obj0_f3-rob0_v0') -> ('IC|obs0_v0-obj0_f2', 'NC|obs0_f2-rob0_v0', 'NC|obj0_f0-rob0_v1') not actually feasible
# edge ('NC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'NC|obj0_f3-rob0_v0') -> ('IC|obs0_v0-obj0_f2', 'NC|obs0_f2-rob0_v0', 'NC|obj0_f3-rob0_v0') not actually feasible
# edge ('NC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'NC|obj0_f3-rob0_v0') -> ('IC|obs0_v1-obj0_f3', 'NC|obs0_f0-rob0_v1', 'NC|obj0_f0-rob0_v1') not actually feasible
# edge ('NC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'NC|obj0_f3-rob0_v0') -> ('IC|obs0_v1-obj0_f3', 'NC|obs0_f0-rob0_v1', 'NC|obj0_f3-rob0_v0') not actually feasible
# edge ('NC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'NC|obj0_f3-rob0_v0') -> ('IC|obs0_v1-obj0_f3', 'NC|obs0_f2-rob0_v0', 'NC|obj0_f0-rob0_v1') not actually feasible
# edge ('NC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'NC|obj0_f3-rob0_v0') -> ('IC|obs0_v1-obj0_f3', 'NC|obs0_f2-rob0_v0', 'NC|obj0_f3-rob0_v0') not actually feasible
# edge ('NC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'NC|obj0_f3-rob0_v0') -> ('NC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'IC|obj0_f2-rob0_f2') is feasible, new dist: 260.61046241386447, added to pq True
# edge ('NC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'NC|obj0_f3-rob0_v0') -> ('NC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'IC|obj0_f3-rob0_v0') not actually feasible
# edge ('NC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'NC|obj0_f3-rob0_v0') -> ('NC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'IC|obj0_v0-rob0_f0') not actually feasible
# edge ('NC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'NC|obj0_f3-rob0_v0') -> ('NC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'NC|obj0_f0-rob0_v1') is feasible, new dist: 242.04873812777512, added to pq True
# edge ('NC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'NC|obj0_f3-rob0_v0') -> ('NC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'NC|obj0_f2-rob0_f2') is feasible, new dist: 251.8425479557186, added to pq True
# edge ('NC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'NC|obj0_f3-rob0_v0') -> ('NC|obs0_f0-obj0_v3', 'NC|obs0_f1-rob0_f2', 'IC|obj0_f2-rob0_f2') not actually feasible
# edge ('NC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'NC|obj0_f3-rob0_v0') -> ('NC|obs0_f0-obj0_v3', 'NC|obs0_f1-rob0_f2', 'IC|obj0_f3-rob0_v0') not actually feasible
# edge ('NC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'NC|obj0_f3-rob0_v0') -> ('NC|obs0_f0-obj0_v3', 'NC|obs0_f1-rob0_f2', 'IC|obj0_v0-rob0_f0') not actually feasible
# edge ('NC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'NC|obj0_f3-rob0_v0') -> ('NC|obs0_f0-obj0_v3', 'NC|obs0_f1-rob0_f2', 'NC|obj0_f0-rob0_v1') not actually feasible
# edge ('NC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'NC|obj0_f3-rob0_v0') -> ('NC|obs0_f0-obj0_v3', 'NC|obs0_f1-rob0_f2', 'NC|obj0_f2-rob0_f2') not actually feasible
# edge ('NC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'NC|obj0_f3-rob0_v0') -> ('NC|obs0_f0-obj0_v3', 'NC|obs0_f1-rob0_f2', 'NC|obj0_f3-rob0_v0') not actually feasible
# edge ('NC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'NC|obj0_f3-rob0_v0') -> ('NC|obs0_f0-obj0_v3', 'NC|obs0_f2-rob0_v0', 'IC|obj0_f2-rob0_f2') not actually feasible
# edge ('NC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'NC|obj0_f3-rob0_v0') -> ('NC|obs0_f0-obj0_v3', 'NC|obs0_f2-rob0_v0', 'IC|obj0_f3-rob0_v0') not actually feasible
# edge ('NC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'NC|obj0_f3-rob0_v0') -> ('NC|obs0_f0-obj0_v3', 'NC|obs0_f2-rob0_v0', 'IC|obj0_v0-rob0_f0') not actually feasible
# edge ('NC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'NC|obj0_f3-rob0_v0') -> ('NC|obs0_f0-obj0_v3', 'NC|obs0_f2-rob0_v0', 'NC|obj0_f0-rob0_v1') is feasible, new dist: 241.03951390622953, added to pq True
# edge ('NC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'NC|obj0_f3-rob0_v0') -> ('NC|obs0_f0-obj0_v3', 'NC|obs0_f2-rob0_v0', 'NC|obj0_f2-rob0_f2') not actually feasible
# edge ('NC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'NC|obj0_f3-rob0_v0') -> ('NC|obs0_f0-obj0_v3', 'NC|obs0_f2-rob0_v0', 'NC|obj0_f3-rob0_v0') is feasible, new dist: 240.8738106927364, added to pq True
# edge ('NC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'NC|obj0_f3-rob0_v0') -> ('NC|obs0_f1-obj0_f0', 'NC|obs0_f0-rob0_v1', 'IC|obj0_f2-rob0_f2') not actually feasible
# edge ('NC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'NC|obj0_f3-rob0_v0') -> ('NC|obs0_f1-obj0_f0', 'NC|obs0_f0-rob0_v1', 'IC|obj0_f3-rob0_v0') not actually feasible
# edge ('NC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'NC|obj0_f3-rob0_v0') -> ('NC|obs0_f1-obj0_f0', 'NC|obs0_f0-rob0_v1', 'IC|obj0_v0-rob0_f0') not actually feasible
# edge ('NC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'NC|obj0_f3-rob0_v0') -> ('NC|obs0_f1-obj0_f0', 'NC|obs0_f0-rob0_v1', 'NC|obj0_f0-rob0_v1') not actually feasible
# edge ('NC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'NC|obj0_f3-rob0_v0') -> ('NC|obs0_f1-obj0_f0', 'NC|obs0_f0-rob0_v1', 'NC|obj0_f2-rob0_f2') not actually feasible
# edge ('NC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'NC|obj0_f3-rob0_v0') -> ('NC|obs0_f1-obj0_f0', 'NC|obs0_f0-rob0_v1', 'NC|obj0_f3-rob0_v0') not actually feasible
# edge ('NC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'NC|obj0_f3-rob0_v0') -> ('NC|obs0_f1-obj0_f0', 'NC|obs0_f1-rob0_f2', 'IC|obj0_f2-rob0_f2') not actually feasible
# edge ('NC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'NC|obj0_f3-rob0_v0') -> ('NC|obs0_f1-obj0_f0', 'NC|obs0_f1-rob0_f2', 'IC|obj0_f3-rob0_v0') not actually feasible
# edge ('NC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'NC|obj0_f3-rob0_v0') -> ('NC|obs0_f1-obj0_f0', 'NC|obs0_f1-rob0_f2', 'IC|obj0_v0-rob0_f0') not actually feasible
# edge ('NC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'NC|obj0_f3-rob0_v0') -> ('NC|obs0_f1-obj0_f0', 'NC|obs0_f1-rob0_f2', 'NC|obj0_f0-rob0_v1') not actually feasible
# edge ('NC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'NC|obj0_f3-rob0_v0') -> ('NC|obs0_f1-obj0_f0', 'NC|obs0_f1-rob0_f2', 'NC|obj0_f2-rob0_f2') not actually feasible
# edge ('NC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'NC|obj0_f3-rob0_v0') -> ('NC|obs0_f1-obj0_f0', 'NC|obs0_f1-rob0_f2', 'NC|obj0_f3-rob0_v0') not actually feasible
# edge ('NC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'NC|obj0_f3-rob0_v0') -> ('NC|obs0_f1-obj0_f0', 'NC|obs0_f2-rob0_v0', 'NC|obj0_f0-rob0_v1') not actually feasible
# edge ('NC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'NC|obj0_f3-rob0_v0') -> ('NC|obs0_f1-obj0_f0', 'NC|obs0_f2-rob0_v0', 'NC|obj0_f3-rob0_v0') not actually feasible
# edge ('NC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'NC|obj0_f3-rob0_v0') -> ('NC|obs0_f2-obj0_f1', 'NC|obs0_f0-rob0_v1', 'IC|obj0_f2-rob0_f2') not actually feasible
# edge ('NC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'NC|obj0_f3-rob0_v0') -> ('NC|obs0_f2-obj0_f1', 'NC|obs0_f0-rob0_v1', 'IC|obj0_f3-rob0_v0') not actually feasible
# edge ('NC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'NC|obj0_f3-rob0_v0') -> ('NC|obs0_f2-obj0_f1', 'NC|obs0_f0-rob0_v1', 'IC|obj0_v0-rob0_f0') not actually feasible
# edge ('NC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'NC|obj0_f3-rob0_v0') -> ('NC|obs0_f2-obj0_f1', 'NC|obs0_f0-rob0_v1', 'NC|obj0_f0-rob0_v1') not actually feasible
# edge ('NC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'NC|obj0_f3-rob0_v0') -> ('NC|obs0_f2-obj0_f1', 'NC|obs0_f0-rob0_v1', 'NC|obj0_f2-rob0_f2') not actually feasible
# edge ('NC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'NC|obj0_f3-rob0_v0') -> ('NC|obs0_f2-obj0_f1', 'NC|obs0_f0-rob0_v1', 'NC|obj0_f3-rob0_v0') not actually feasible
# edge ('NC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'NC|obj0_f3-rob0_v0') -> ('NC|obs0_f2-obj0_f1', 'NC|obs0_f2-rob0_v0', 'IC|obj0_f2-rob0_f2') not actually feasible
# edge ('NC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'NC|obj0_f3-rob0_v0') -> ('NC|obs0_f2-obj0_f1', 'NC|obs0_f2-rob0_v0', 'IC|obj0_f3-rob0_v0') not actually feasible
# edge ('NC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'NC|obj0_f3-rob0_v0') -> ('NC|obs0_f2-obj0_f1', 'NC|obs0_f2-rob0_v0', 'IC|obj0_v0-rob0_f0') not actually feasible
# edge ('NC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'NC|obj0_f3-rob0_v0') -> ('NC|obs0_f2-obj0_f1', 'NC|obs0_f2-rob0_v0', 'NC|obj0_f0-rob0_v1') not actually feasible
# edge ('NC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'NC|obj0_f3-rob0_v0') -> ('NC|obs0_f2-obj0_f1', 'NC|obs0_f2-rob0_v0', 'NC|obj0_f2-rob0_f2') not actually feasible
# edge ('NC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'NC|obj0_f3-rob0_v0') -> ('NC|obs0_f2-obj0_f1', 'NC|obs0_f2-rob0_v0', 'NC|obj0_f3-rob0_v0') not actually feasible
#
# n_vertices_visited: 4, n_edges_visited: 2, n_vertices_explored: 56, vertex_coverage: 0.0221, edge_coverage: 0.0003, time_wall_clock: 0.345, n_gcs_solves: 56, gcs_solve_time_total: 0.272, gcs_solve_time_iter_mean: 0.00485, gcs_solve_time_last_10_mean: 0.00116, gcs_solve_time_iter_std: 0.0251, gcs_solve_time_iter_min: 0.00106, gcs_solve_time_iter_max: 0.191, n_vertices_revisited: 0, n_vertices_reexplored: 0
# now exploring node ('NC|obs0_f0-obj0_v3', 'NC|obs0_f2-rob0_v0', 'NC|obj0_f3-rob0_v0')'s 63 neighbors (240.8738106927364)
# edge ('NC|obs0_f0-obj0_v3', 'NC|obs0_f2-rob0_v0', 'NC|obj0_f3-rob0_v0') -> ('IC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'NC|obj0_f0-rob0_v1') not actually feasible
# edge ('NC|obs0_f0-obj0_v3', 'NC|obs0_f2-rob0_v0', 'NC|obj0_f3-rob0_v0') -> ('IC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'NC|obj0_f3-rob0_v0') not actually feasible
# edge ('NC|obs0_f0-obj0_v3', 'NC|obs0_f2-rob0_v0', 'NC|obj0_f3-rob0_v0') -> ('IC|obs0_f0-obj0_v3', 'NC|obs0_f1-rob0_f2', 'NC|obj0_f2-rob0_f2') not actually feasible
# edge ('NC|obs0_f0-obj0_v3', 'NC|obs0_f2-rob0_v0', 'NC|obj0_f3-rob0_v0') -> ('IC|obs0_f0-obj0_v3', 'NC|obs0_f1-rob0_f2', 'NC|obj0_f3-rob0_v0') not actually feasible
# edge ('NC|obs0_f0-obj0_v3', 'NC|obs0_f2-rob0_v0', 'NC|obj0_f3-rob0_v0') -> ('IC|obs0_f0-obj0_v3', 'NC|obs0_f2-rob0_v0', 'IC|obj0_f2-rob0_f2') not actually feasible
# edge ('NC|obs0_f0-obj0_v3', 'NC|obs0_f2-rob0_v0', 'NC|obj0_f3-rob0_v0') -> ('IC|obs0_f0-obj0_v3', 'NC|obs0_f2-rob0_v0', 'IC|obj0_f3-rob0_v0') not actually feasible
# edge ('NC|obs0_f0-obj0_v3', 'NC|obs0_f2-rob0_v0', 'NC|obj0_f3-rob0_v0') -> ('IC|obs0_f0-obj0_v3', 'NC|obs0_f2-rob0_v0', 'IC|obj0_v0-rob0_f0') not actually feasible
# edge ('NC|obs0_f0-obj0_v3', 'NC|obs0_f2-rob0_v0', 'NC|obj0_f3-rob0_v0') -> ('IC|obs0_f0-obj0_v3', 'NC|obs0_f2-rob0_v0', 'NC|obj0_f0-rob0_v1') not actually feasible
# edge ('NC|obs0_f0-obj0_v3', 'NC|obs0_f2-rob0_v0', 'NC|obj0_f3-rob0_v0') -> ('IC|obs0_f0-obj0_v3', 'NC|obs0_f2-rob0_v0', 'NC|obj0_f2-rob0_f2') not actually feasible
# edge ('NC|obs0_f0-obj0_v3', 'NC|obs0_f2-rob0_v0', 'NC|obj0_f3-rob0_v0') -> ('IC|obs0_f0-obj0_v3', 'NC|obs0_f2-rob0_v0', 'NC|obj0_f3-rob0_v0') not actually feasible
# edge ('NC|obs0_f0-obj0_v3', 'NC|obs0_f2-rob0_v0', 'NC|obj0_f3-rob0_v0') -> ('IC|obs0_v0-obj0_f2', 'NC|obs0_f0-rob0_v1', 'NC|obj0_f0-rob0_v1') not actually feasible
# edge ('NC|obs0_f0-obj0_v3', 'NC|obs0_f2-rob0_v0', 'NC|obj0_f3-rob0_v0') -> ('IC|obs0_v0-obj0_f2', 'NC|obs0_f0-rob0_v1', 'NC|obj0_f3-rob0_v0') not actually feasible
# edge ('NC|obs0_f0-obj0_v3', 'NC|obs0_f2-rob0_v0', 'NC|obj0_f3-rob0_v0') -> ('IC|obs0_v0-obj0_f2', 'NC|obs0_f1-rob0_f2', 'NC|obj0_f2-rob0_f2') not actually feasible
# edge ('NC|obs0_f0-obj0_v3', 'NC|obs0_f2-rob0_v0', 'NC|obj0_f3-rob0_v0') -> ('IC|obs0_v0-obj0_f2', 'NC|obs0_f1-rob0_f2', 'NC|obj0_f3-rob0_v0') not actually feasible
# edge ('NC|obs0_f0-obj0_v3', 'NC|obs0_f2-rob0_v0', 'NC|obj0_f3-rob0_v0') -> ('IC|obs0_v0-obj0_f2', 'NC|obs0_f2-rob0_v0', 'IC|obj0_f2-rob0_f2') not actually feasible
# edge ('NC|obs0_f0-obj0_v3', 'NC|obs0_f2-rob0_v0', 'NC|obj0_f3-rob0_v0') -> ('IC|obs0_v0-obj0_f2', 'NC|obs0_f2-rob0_v0', 'IC|obj0_f3-rob0_v0') not actually feasible
# edge ('NC|obs0_f0-obj0_v3', 'NC|obs0_f2-rob0_v0', 'NC|obj0_f3-rob0_v0') -> ('IC|obs0_v0-obj0_f2', 'NC|obs0_f2-rob0_v0', 'IC|obj0_v0-rob0_f0') not actually feasible
# edge ('NC|obs0_f0-obj0_v3', 'NC|obs0_f2-rob0_v0', 'NC|obj0_f3-rob0_v0') -> ('IC|obs0_v0-obj0_f2', 'NC|obs0_f2-rob0_v0', 'NC|obj0_f0-rob0_v1') not actually feasible
# edge ('NC|obs0_f0-obj0_v3', 'NC|obs0_f2-rob0_v0', 'NC|obj0_f3-rob0_v0') -> ('IC|obs0_v0-obj0_f2', 'NC|obs0_f2-rob0_v0', 'NC|obj0_f2-rob0_f2') not actually feasible
# edge ('NC|obs0_f0-obj0_v3', 'NC|obs0_f2-rob0_v0', 'NC|obj0_f3-rob0_v0') -> ('IC|obs0_v0-obj0_f2', 'NC|obs0_f2-rob0_v0', 'NC|obj0_f3-rob0_v0') not actually feasible
# edge ('NC|obs0_f0-obj0_v3', 'NC|obs0_f2-rob0_v0', 'NC|obj0_f3-rob0_v0') -> ('IC|obs0_v1-obj0_f3', 'NC|obs0_f0-rob0_v1', 'NC|obj0_f0-rob0_v1') not actually feasible
# edge ('NC|obs0_f0-obj0_v3', 'NC|obs0_f2-rob0_v0', 'NC|obj0_f3-rob0_v0') -> ('IC|obs0_v1-obj0_f3', 'NC|obs0_f0-rob0_v1', 'NC|obj0_f3-rob0_v0') not actually feasible
# edge ('NC|obs0_f0-obj0_v3', 'NC|obs0_f2-rob0_v0', 'NC|obj0_f3-rob0_v0') -> ('IC|obs0_v1-obj0_f3', 'NC|obs0_f1-rob0_f2', 'NC|obj0_f2-rob0_f2') not actually feasible
# edge ('NC|obs0_f0-obj0_v3', 'NC|obs0_f2-rob0_v0', 'NC|obj0_f3-rob0_v0') -> ('IC|obs0_v1-obj0_f3', 'NC|obs0_f1-rob0_f2', 'NC|obj0_f3-rob0_v0') not actually feasible
# edge ('NC|obs0_f0-obj0_v3', 'NC|obs0_f2-rob0_v0', 'NC|obj0_f3-rob0_v0') -> ('IC|obs0_v1-obj0_f3', 'NC|obs0_f2-rob0_v0', 'NC|obj0_f0-rob0_v1') not actually feasible
# edge ('NC|obs0_f0-obj0_v3', 'NC|obs0_f2-rob0_v0', 'NC|obj0_f3-rob0_v0') -> ('IC|obs0_v1-obj0_f3', 'NC|obs0_f2-rob0_v0', 'NC|obj0_f2-rob0_f2') not actually feasible
# edge ('NC|obs0_f0-obj0_v3', 'NC|obs0_f2-rob0_v0', 'NC|obj0_f3-rob0_v0') -> ('IC|obs0_v1-obj0_f3', 'NC|obs0_f2-rob0_v0', 'NC|obj0_f3-rob0_v0') not actually feasible
# edge ('NC|obs0_f0-obj0_v3', 'NC|obs0_f2-rob0_v0', 'NC|obj0_f3-rob0_v0') -> ('NC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'IC|obj0_f2-rob0_f2') not actually feasible
# edge ('NC|obs0_f0-obj0_v3', 'NC|obs0_f2-rob0_v0', 'NC|obj0_f3-rob0_v0') -> ('NC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'IC|obj0_f3-rob0_v0') not actually feasible
# edge ('NC|obs0_f0-obj0_v3', 'NC|obs0_f2-rob0_v0', 'NC|obj0_f3-rob0_v0') -> ('NC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'IC|obj0_v0-rob0_f0') not actually feasible
# edge ('NC|obs0_f0-obj0_v3', 'NC|obs0_f2-rob0_v0', 'NC|obj0_f3-rob0_v0') -> ('NC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'NC|obj0_f0-rob0_v1') not actually feasible
# edge ('NC|obs0_f0-obj0_v3', 'NC|obs0_f2-rob0_v0', 'NC|obj0_f3-rob0_v0') -> ('NC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'NC|obj0_f2-rob0_f2') not actually feasible
# edge ('NC|obs0_f0-obj0_v3', 'NC|obs0_f2-rob0_v0', 'NC|obj0_f3-rob0_v0') -> ('NC|obs0_f0-obj0_v3', 'NC|obs0_f1-rob0_f2', 'NC|obj0_f0-rob0_v1') not actually feasible
# edge ('NC|obs0_f0-obj0_v3', 'NC|obs0_f2-rob0_v0', 'NC|obj0_f3-rob0_v0') -> ('NC|obs0_f0-obj0_v3', 'NC|obs0_f1-rob0_f2', 'NC|obj0_f2-rob0_f2') not actually feasible
# edge ('NC|obs0_f0-obj0_v3', 'NC|obs0_f2-rob0_v0', 'NC|obj0_f3-rob0_v0') -> ('NC|obs0_f0-obj0_v3', 'NC|obs0_f1-rob0_f2', 'NC|obj0_f3-rob0_v0') not actually feasible
# edge ('NC|obs0_f0-obj0_v3', 'NC|obs0_f2-rob0_v0', 'NC|obj0_f3-rob0_v0') -> ('NC|obs0_f0-obj0_v3', 'NC|obs0_f2-rob0_v0', 'IC|obj0_f2-rob0_f2') not actually feasible
# edge ('NC|obs0_f0-obj0_v3', 'NC|obs0_f2-rob0_v0', 'NC|obj0_f3-rob0_v0') -> ('NC|obs0_f0-obj0_v3', 'NC|obs0_f2-rob0_v0', 'IC|obj0_f3-rob0_v0') not actually feasible
# edge ('NC|obs0_f0-obj0_v3', 'NC|obs0_f2-rob0_v0', 'NC|obj0_f3-rob0_v0') -> ('NC|obs0_f0-obj0_v3', 'NC|obs0_f2-rob0_v0', 'IC|obj0_v0-rob0_f0') not actually feasible
# edge ('NC|obs0_f0-obj0_v3', 'NC|obs0_f2-rob0_v0', 'NC|obj0_f3-rob0_v0') -> ('NC|obs0_f0-obj0_v3', 'NC|obs0_f2-rob0_v0', 'NC|obj0_f0-rob0_v1') is feasible, new dist: 242.0395139062373, added to pq False
# edge ('NC|obs0_f0-obj0_v3', 'NC|obs0_f2-rob0_v0', 'NC|obj0_f3-rob0_v0') -> ('NC|obs0_f0-obj0_v3', 'NC|obs0_f2-rob0_v0', 'NC|obj0_f2-rob0_f2') not actually feasible
# edge ('NC|obs0_f0-obj0_v3', 'NC|obs0_f2-rob0_v0', 'NC|obj0_f3-rob0_v0') -> ('NC|obs0_f1-obj0_f0', 'NC|obs0_f0-rob0_v1', 'NC|obj0_f0-rob0_v1') not actually feasible
# edge ('NC|obs0_f0-obj0_v3', 'NC|obs0_f2-rob0_v0', 'NC|obj0_f3-rob0_v0') -> ('NC|obs0_f1-obj0_f0', 'NC|obs0_f0-rob0_v1', 'NC|obj0_f3-rob0_v0') not actually feasible
# edge ('NC|obs0_f0-obj0_v3', 'NC|obs0_f2-rob0_v0', 'NC|obj0_f3-rob0_v0') -> ('NC|obs0_f1-obj0_f0', 'NC|obs0_f1-rob0_f2', 'NC|obj0_f0-rob0_v1') not actually feasible
# edge ('NC|obs0_f0-obj0_v3', 'NC|obs0_f2-rob0_v0', 'NC|obj0_f3-rob0_v0') -> ('NC|obs0_f1-obj0_f0', 'NC|obs0_f1-rob0_f2', 'NC|obj0_f2-rob0_f2') not actually feasible
# edge ('NC|obs0_f0-obj0_v3', 'NC|obs0_f2-rob0_v0', 'NC|obj0_f3-rob0_v0') -> ('NC|obs0_f1-obj0_f0', 'NC|obs0_f1-rob0_f2', 'NC|obj0_f3-rob0_v0') not actually feasible
# edge ('NC|obs0_f0-obj0_v3', 'NC|obs0_f2-rob0_v0', 'NC|obj0_f3-rob0_v0') -> ('NC|obs0_f1-obj0_f0', 'NC|obs0_f2-rob0_v0', 'NC|obj0_f0-rob0_v1') not actually feasible
# edge ('NC|obs0_f0-obj0_v3', 'NC|obs0_f2-rob0_v0', 'NC|obj0_f3-rob0_v0') -> ('NC|obs0_f1-obj0_f0', 'NC|obs0_f2-rob0_v0', 'NC|obj0_f2-rob0_f2') not actually feasible
# edge ('NC|obs0_f0-obj0_v3', 'NC|obs0_f2-rob0_v0', 'NC|obj0_f3-rob0_v0') -> ('NC|obs0_f1-obj0_f0', 'NC|obs0_f2-rob0_v0', 'NC|obj0_f3-rob0_v0') not actually feasible
# edge ('NC|obs0_f0-obj0_v3', 'NC|obs0_f2-rob0_v0', 'NC|obj0_f3-rob0_v0') -> ('NC|obs0_f2-obj0_f1', 'NC|obs0_f0-rob0_v1', 'IC|obj0_f2-rob0_f2') not actually feasible
# edge ('NC|obs0_f0-obj0_v3', 'NC|obs0_f2-rob0_v0', 'NC|obj0_f3-rob0_v0') -> ('NC|obs0_f2-obj0_f1', 'NC|obs0_f0-rob0_v1', 'IC|obj0_f3-rob0_v0') not actually feasible
# edge ('NC|obs0_f0-obj0_v3', 'NC|obs0_f2-rob0_v0', 'NC|obj0_f3-rob0_v0') -> ('NC|obs0_f2-obj0_f1', 'NC|obs0_f0-rob0_v1', 'IC|obj0_v0-rob0_f0') not actually feasible
# edge ('NC|obs0_f0-obj0_v3', 'NC|obs0_f2-rob0_v0', 'NC|obj0_f3-rob0_v0') -> ('NC|obs0_f2-obj0_f1', 'NC|obs0_f0-rob0_v1', 'NC|obj0_f0-rob0_v1') not actually feasible
# edge ('NC|obs0_f0-obj0_v3', 'NC|obs0_f2-rob0_v0', 'NC|obj0_f3-rob0_v0') -> ('NC|obs0_f2-obj0_f1', 'NC|obs0_f0-rob0_v1', 'NC|obj0_f2-rob0_f2') not actually feasible
# edge ('NC|obs0_f0-obj0_v3', 'NC|obs0_f2-rob0_v0', 'NC|obj0_f3-rob0_v0') -> ('NC|obs0_f2-obj0_f1', 'NC|obs0_f0-rob0_v1', 'NC|obj0_f3-rob0_v0') not actually feasible
# edge ('NC|obs0_f0-obj0_v3', 'NC|obs0_f2-rob0_v0', 'NC|obj0_f3-rob0_v0') -> ('NC|obs0_f2-obj0_f1', 'NC|obs0_f1-rob0_f2', 'NC|obj0_f2-rob0_f2') not actually feasible
# edge ('NC|obs0_f0-obj0_v3', 'NC|obs0_f2-rob0_v0', 'NC|obj0_f3-rob0_v0') -> ('NC|obs0_f2-obj0_f1', 'NC|obs0_f1-rob0_f2', 'NC|obj0_f3-rob0_v0') not actually feasible
# edge ('NC|obs0_f0-obj0_v3', 'NC|obs0_f2-rob0_v0', 'NC|obj0_f3-rob0_v0') -> ('NC|obs0_f2-obj0_f1', 'NC|obs0_f2-rob0_v0', 'IC|obj0_f2-rob0_f2') not actually feasible
# edge ('NC|obs0_f0-obj0_v3', 'NC|obs0_f2-rob0_v0', 'NC|obj0_f3-rob0_v0') -> ('NC|obs0_f2-obj0_f1', 'NC|obs0_f2-rob0_v0', 'IC|obj0_f3-rob0_v0') not actually feasible
# edge ('NC|obs0_f0-obj0_v3', 'NC|obs0_f2-rob0_v0', 'NC|obj0_f3-rob0_v0') -> ('NC|obs0_f2-obj0_f1', 'NC|obs0_f2-rob0_v0', 'IC|obj0_v0-rob0_f0') not actually feasible
# edge ('NC|obs0_f0-obj0_v3', 'NC|obs0_f2-rob0_v0', 'NC|obj0_f3-rob0_v0') -> ('NC|obs0_f2-obj0_f1', 'NC|obs0_f2-rob0_v0', 'NC|obj0_f0-rob0_v1') not actually feasible
# edge ('NC|obs0_f0-obj0_v3', 'NC|obs0_f2-rob0_v0', 'NC|obj0_f3-rob0_v0') -> ('NC|obs0_f2-obj0_f1', 'NC|obs0_f2-rob0_v0', 'NC|obj0_f2-rob0_f2') not actually feasible
# edge ('NC|obs0_f0-obj0_v3', 'NC|obs0_f2-rob0_v0', 'NC|obj0_f3-rob0_v0') -> ('NC|obs0_f2-obj0_f1', 'NC|obs0_f2-rob0_v0', 'NC|obj0_f3-rob0_v0') not actually feasible
#
# n_vertices_visited: 5, n_edges_visited: 2, n_vertices_explored: 118, vertex_coverage: 0.0276, edge_coverage: 0.0003, time_wall_clock: 0.6, n_gcs_solves: 118, gcs_solve_time_total: 0.45, gcs_solve_time_iter_mean: 0.00381, gcs_solve_time_last_10_mean: 0.00157, gcs_solve_time_iter_std: 0.0177, gcs_solve_time_iter_min: 0.00106, gcs_solve_time_iter_max: 0.191, n_vertices_revisited: 0, n_vertices_reexplored: 0
# now exploring node ('NC|obs0_f0-obj0_v3', 'NC|obs0_f2-rob0_v0', 'NC|obj0_f0-rob0_v1')'s 43 neighbors (241.03951390622953)
# edge ('NC|obs0_f0-obj0_v3', 'NC|obs0_f2-rob0_v0', 'NC|obj0_f0-rob0_v1') -> ('IC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'NC|obj0_f0-rob0_v1') not actually feasible
# edge ('NC|obs0_f0-obj0_v3', 'NC|obs0_f2-rob0_v0', 'NC|obj0_f0-rob0_v1') -> ('IC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'NC|obj0_f3-rob0_v0') not actually feasible
# edge ('NC|obs0_f0-obj0_v3', 'NC|obs0_f2-rob0_v0', 'NC|obj0_f0-rob0_v1') -> ('IC|obs0_f0-obj0_v3', 'NC|obs0_f2-rob0_v0', 'NC|obj0_f0-rob0_v1') not actually feasible
# edge ('NC|obs0_f0-obj0_v3', 'NC|obs0_f2-rob0_v0', 'NC|obj0_f0-rob0_v1') -> ('IC|obs0_f0-obj0_v3', 'NC|obs0_f2-rob0_v0', 'NC|obj0_f3-rob0_v0') not actually feasible
# edge ('NC|obs0_f0-obj0_v3', 'NC|obs0_f2-rob0_v0', 'NC|obj0_f0-rob0_v1') -> ('IC|obs0_v0-obj0_f2', 'NC|obs0_f0-rob0_v1', 'NC|obj0_f0-rob0_v1') not actually feasible
# edge ('NC|obs0_f0-obj0_v3', 'NC|obs0_f2-rob0_v0', 'NC|obj0_f0-rob0_v1') -> ('IC|obs0_v0-obj0_f2', 'NC|obs0_f0-rob0_v1', 'NC|obj0_f3-rob0_v0') not actually feasible
# edge ('NC|obs0_f0-obj0_v3', 'NC|obs0_f2-rob0_v0', 'NC|obj0_f0-rob0_v1') -> ('IC|obs0_v0-obj0_f2', 'NC|obs0_f2-rob0_v0', 'NC|obj0_f0-rob0_v1') not actually feasible
# edge ('NC|obs0_f0-obj0_v3', 'NC|obs0_f2-rob0_v0', 'NC|obj0_f0-rob0_v1') -> ('IC|obs0_v0-obj0_f2', 'NC|obs0_f2-rob0_v0', 'NC|obj0_f3-rob0_v0') not actually feasible
# edge ('NC|obs0_f0-obj0_v3', 'NC|obs0_f2-rob0_v0', 'NC|obj0_f0-rob0_v1') -> ('IC|obs0_v1-obj0_f3', 'NC|obs0_f0-rob0_v1', 'NC|obj0_f0-rob0_v1') not actually feasible
# edge ('NC|obs0_f0-obj0_v3', 'NC|obs0_f2-rob0_v0', 'NC|obj0_f0-rob0_v1') -> ('IC|obs0_v1-obj0_f3', 'NC|obs0_f0-rob0_v1', 'NC|obj0_f3-rob0_v0') not actually feasible
# edge ('NC|obs0_f0-obj0_v3', 'NC|obs0_f2-rob0_v0', 'NC|obj0_f0-rob0_v1') -> ('IC|obs0_v1-obj0_f3', 'NC|obs0_f2-rob0_v0', 'NC|obj0_f0-rob0_v1') not actually feasible
# edge ('NC|obs0_f0-obj0_v3', 'NC|obs0_f2-rob0_v0', 'NC|obj0_f0-rob0_v1') -> ('IC|obs0_v1-obj0_f3', 'NC|obs0_f2-rob0_v0', 'NC|obj0_f3-rob0_v0') not actually feasible
# edge ('NC|obs0_f0-obj0_v3', 'NC|obs0_f2-rob0_v0', 'NC|obj0_f0-rob0_v1') -> ('NC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'IC|obj0_f1-rob0_f1') not actually feasible
# edge ('NC|obs0_f0-obj0_v3', 'NC|obs0_f2-rob0_v0', 'NC|obj0_f0-rob0_v1') -> ('NC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'IC|obj0_f0-rob0_v1') not actually feasible
# edge ('NC|obs0_f0-obj0_v3', 'NC|obs0_f2-rob0_v0', 'NC|obj0_f0-rob0_v1') -> ('NC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'IC|obj0_v0-rob0_f0') not actually feasible
# edge ('NC|obs0_f0-obj0_v3', 'NC|obs0_f2-rob0_v0', 'NC|obj0_f0-rob0_v1') -> ('NC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'NC|obj0_f0-rob0_v1') not actually feasible
# edge ('NC|obs0_f0-obj0_v3', 'NC|obs0_f2-rob0_v0', 'NC|obj0_f0-rob0_v1') -> ('NC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'NC|obj0_f1-rob0_f1') not actually feasible
# edge ('NC|obs0_f0-obj0_v3', 'NC|obs0_f2-rob0_v0', 'NC|obj0_f0-rob0_v1') -> ('NC|obs0_f0-obj0_v3', 'NC|obs0_f1-rob0_f2', 'NC|obj0_f0-rob0_v1') not actually feasible
# edge ('NC|obs0_f0-obj0_v3', 'NC|obs0_f2-rob0_v0', 'NC|obj0_f0-rob0_v1') -> ('NC|obs0_f0-obj0_v3', 'NC|obs0_f1-rob0_f2', 'NC|obj0_f3-rob0_v0') not actually feasible
# edge ('NC|obs0_f0-obj0_v3', 'NC|obs0_f2-rob0_v0', 'NC|obj0_f0-rob0_v1') -> ('NC|obs0_f0-obj0_v3', 'NC|obs0_f2-rob0_v0', 'IC|obj0_f1-rob0_f1') not actually feasible
# edge ('NC|obs0_f0-obj0_v3', 'NC|obs0_f2-rob0_v0', 'NC|obj0_f0-rob0_v1') -> ('NC|obs0_f0-obj0_v3', 'NC|obs0_f2-rob0_v0', 'IC|obj0_f0-rob0_v1') not actually feasible
# edge ('NC|obs0_f0-obj0_v3', 'NC|obs0_f2-rob0_v0', 'NC|obj0_f0-rob0_v1') -> ('NC|obs0_f0-obj0_v3', 'NC|obs0_f2-rob0_v0', 'IC|obj0_v0-rob0_f0') not actually feasible
# edge ('NC|obs0_f0-obj0_v3', 'NC|obs0_f2-rob0_v0', 'NC|obj0_f0-rob0_v1') -> ('NC|obs0_f0-obj0_v3', 'NC|obs0_f2-rob0_v0', 'NC|obj0_f1-rob0_f1') not actually feasible
# edge ('NC|obs0_f0-obj0_v3', 'NC|obs0_f2-rob0_v0', 'NC|obj0_f0-rob0_v1') -> ('NC|obs0_f0-obj0_v3', 'NC|obs0_f2-rob0_v0', 'NC|obj0_f3-rob0_v0') is feasible, new dist: 241.87381070707815, added to pq False
# edge ('NC|obs0_f0-obj0_v3', 'NC|obs0_f2-rob0_v0', 'NC|obj0_f0-rob0_v1') -> ('NC|obs0_f1-obj0_f0', 'NC|obs0_f0-rob0_v1', 'NC|obj0_f0-rob0_v1') not actually feasible
# edge ('NC|obs0_f0-obj0_v3', 'NC|obs0_f2-rob0_v0', 'NC|obj0_f0-rob0_v1') -> ('NC|obs0_f1-obj0_f0', 'NC|obs0_f0-rob0_v1', 'NC|obj0_f3-rob0_v0') not actually feasible
# edge ('NC|obs0_f0-obj0_v3', 'NC|obs0_f2-rob0_v0', 'NC|obj0_f0-rob0_v1') -> ('NC|obs0_f1-obj0_f0', 'NC|obs0_f1-rob0_f2', 'NC|obj0_f0-rob0_v1') not actually feasible
# edge ('NC|obs0_f0-obj0_v3', 'NC|obs0_f2-rob0_v0', 'NC|obj0_f0-rob0_v1') -> ('NC|obs0_f1-obj0_f0', 'NC|obs0_f1-rob0_f2', 'NC|obj0_f3-rob0_v0') not actually feasible
# edge ('NC|obs0_f0-obj0_v3', 'NC|obs0_f2-rob0_v0', 'NC|obj0_f0-rob0_v1') -> ('NC|obs0_f1-obj0_f0', 'NC|obs0_f2-rob0_v0', 'NC|obj0_f0-rob0_v1') not actually feasible
# edge ('NC|obs0_f0-obj0_v3', 'NC|obs0_f2-rob0_v0', 'NC|obj0_f0-rob0_v1') -> ('NC|obs0_f1-obj0_f0', 'NC|obs0_f2-rob0_v0', 'NC|obj0_f3-rob0_v0') not actually feasible
# edge ('NC|obs0_f0-obj0_v3', 'NC|obs0_f2-rob0_v0', 'NC|obj0_f0-rob0_v1') -> ('NC|obs0_f2-obj0_f1', 'NC|obs0_f0-rob0_v1', 'IC|obj0_f1-rob0_f1') not actually feasible
# edge ('NC|obs0_f0-obj0_v3', 'NC|obs0_f2-rob0_v0', 'NC|obj0_f0-rob0_v1') -> ('NC|obs0_f2-obj0_f1', 'NC|obs0_f0-rob0_v1', 'IC|obj0_f0-rob0_v1') not actually feasible
# edge ('NC|obs0_f0-obj0_v3', 'NC|obs0_f2-rob0_v0', 'NC|obj0_f0-rob0_v1') -> ('NC|obs0_f2-obj0_f1', 'NC|obs0_f0-rob0_v1', 'IC|obj0_v0-rob0_f0') not actually feasible
# edge ('NC|obs0_f0-obj0_v3', 'NC|obs0_f2-rob0_v0', 'NC|obj0_f0-rob0_v1') -> ('NC|obs0_f2-obj0_f1', 'NC|obs0_f0-rob0_v1', 'NC|obj0_f0-rob0_v1') not actually feasible
# edge ('NC|obs0_f0-obj0_v3', 'NC|obs0_f2-rob0_v0', 'NC|obj0_f0-rob0_v1') -> ('NC|obs0_f2-obj0_f1', 'NC|obs0_f0-rob0_v1', 'NC|obj0_f1-rob0_f1') not actually feasible
# edge ('NC|obs0_f0-obj0_v3', 'NC|obs0_f2-rob0_v0', 'NC|obj0_f0-rob0_v1') -> ('NC|obs0_f2-obj0_f1', 'NC|obs0_f0-rob0_v1', 'NC|obj0_f3-rob0_v0') not actually feasible
# edge ('NC|obs0_f0-obj0_v3', 'NC|obs0_f2-rob0_v0', 'NC|obj0_f0-rob0_v1') -> ('NC|obs0_f2-obj0_f1', 'NC|obs0_f2-rob0_v0', 'IC|obj0_f1-rob0_f1') not actually feasible
# edge ('NC|obs0_f0-obj0_v3', 'NC|obs0_f2-rob0_v0', 'NC|obj0_f0-rob0_v1') -> ('NC|obs0_f2-obj0_f1', 'NC|obs0_f2-rob0_v0', 'IC|obj0_f0-rob0_v1') not actually feasible
# edge ('NC|obs0_f0-obj0_v3', 'NC|obs0_f2-rob0_v0', 'NC|obj0_f0-rob0_v1') -> ('NC|obs0_f2-obj0_f1', 'NC|obs0_f2-rob0_v0', 'IC|obj0_v0-rob0_f0') not actually feasible
# edge ('NC|obs0_f0-obj0_v3', 'NC|obs0_f2-rob0_v0', 'NC|obj0_f0-rob0_v1') -> ('NC|obs0_f2-obj0_f1', 'NC|obs0_f2-rob0_v0', 'NC|obj0_f0-rob0_v1') not actually feasible
# edge ('NC|obs0_f0-obj0_v3', 'NC|obs0_f2-rob0_v0', 'NC|obj0_f0-rob0_v1') -> ('NC|obs0_f2-obj0_f1', 'NC|obs0_f2-rob0_v0', 'NC|obj0_f1-rob0_f1') not actually feasible
# edge ('NC|obs0_f0-obj0_v3', 'NC|obs0_f2-rob0_v0', 'NC|obj0_f0-rob0_v1') -> ('NC|obs0_f2-obj0_f1', 'NC|obs0_f2-rob0_v0', 'NC|obj0_f3-rob0_v0') not actually feasible
#
# n_vertices_visited: 6, n_edges_visited: 2, n_vertices_explored: 159, vertex_coverage: 0.0331, edge_coverage: 0.0003, time_wall_clock: 0.728, n_gcs_solves: 160, gcs_solve_time_total: 0.527, gcs_solve_time_iter_mean: 0.00329, gcs_solve_time_last_10_mean: 0.00155, gcs_solve_time_iter_std: 0.0153, gcs_solve_time_iter_min: 0.00106, gcs_solve_time_iter_max: 0.191, n_vertices_revisited: 0, n_vertices_reexplored: 1
# now exploring node ('NC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'NC|obj0_f0-rob0_v1')'s 67 neighbors (242.04873812777512)
# edge ('NC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'NC|obj0_f0-rob0_v1') -> ('IC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'IC|obj0_f1-rob0_f1') not actually feasible
# edge ('NC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'NC|obj0_f0-rob0_v1') -> ('IC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'IC|obj0_f0-rob0_v1') not actually feasible
# edge ('NC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'NC|obj0_f0-rob0_v1') -> ('IC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'IC|obj0_v0-rob0_f0') not actually feasible
# edge ('NC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'NC|obj0_f0-rob0_v1') -> ('IC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'NC|obj0_f0-rob0_v1') not actually feasible
# edge ('NC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'NC|obj0_f0-rob0_v1') -> ('IC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'NC|obj0_f1-rob0_f1') not actually feasible
# edge ('NC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'NC|obj0_f0-rob0_v1') -> ('IC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'NC|obj0_f3-rob0_v0') not actually feasible
# edge ('NC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'NC|obj0_f0-rob0_v1') -> ('IC|obs0_f0-obj0_v3', 'NC|obs0_f2-rob0_v0', 'NC|obj0_f0-rob0_v1') not actually feasible
# edge ('NC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'NC|obj0_f0-rob0_v1') -> ('IC|obs0_f0-obj0_v3', 'NC|obs0_f2-rob0_v0', 'NC|obj0_f3-rob0_v0') not actually feasible
# edge ('NC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'NC|obj0_f0-rob0_v1') -> ('IC|obs0_v0-obj0_f2', 'NC|obs0_f0-rob0_v1', 'IC|obj0_f1-rob0_f1') not actually feasible
# edge ('NC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'NC|obj0_f0-rob0_v1') -> ('IC|obs0_v0-obj0_f2', 'NC|obs0_f0-rob0_v1', 'IC|obj0_f0-rob0_v1') not actually feasible
# edge ('NC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'NC|obj0_f0-rob0_v1') -> ('IC|obs0_v0-obj0_f2', 'NC|obs0_f0-rob0_v1', 'IC|obj0_v0-rob0_f0') not actually feasible
# edge ('NC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'NC|obj0_f0-rob0_v1') -> ('IC|obs0_v0-obj0_f2', 'NC|obs0_f0-rob0_v1', 'NC|obj0_f0-rob0_v1') not actually feasible
# edge ('NC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'NC|obj0_f0-rob0_v1') -> ('IC|obs0_v0-obj0_f2', 'NC|obs0_f0-rob0_v1', 'NC|obj0_f1-rob0_f1') not actually feasible
# edge ('NC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'NC|obj0_f0-rob0_v1') -> ('IC|obs0_v0-obj0_f2', 'NC|obs0_f0-rob0_v1', 'NC|obj0_f3-rob0_v0') not actually feasible
# edge ('NC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'NC|obj0_f0-rob0_v1') -> ('IC|obs0_v0-obj0_f2', 'NC|obs0_f2-rob0_v0', 'NC|obj0_f0-rob0_v1') not actually feasible
# edge ('NC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'NC|obj0_f0-rob0_v1') -> ('IC|obs0_v0-obj0_f2', 'NC|obs0_f2-rob0_v0', 'NC|obj0_f3-rob0_v0') not actually feasible
# edge ('NC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'NC|obj0_f0-rob0_v1') -> ('IC|obs0_v1-obj0_f3', 'NC|obs0_f0-rob0_v1', 'IC|obj0_f1-rob0_f1') not actually feasible
# edge ('NC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'NC|obj0_f0-rob0_v1') -> ('IC|obs0_v1-obj0_f3', 'NC|obs0_f0-rob0_v1', 'IC|obj0_f0-rob0_v1') not actually feasible
# edge ('NC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'NC|obj0_f0-rob0_v1') -> ('IC|obs0_v1-obj0_f3', 'NC|obs0_f0-rob0_v1', 'IC|obj0_v0-rob0_f0') not actually feasible
# edge ('NC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'NC|obj0_f0-rob0_v1') -> ('IC|obs0_v1-obj0_f3', 'NC|obs0_f0-rob0_v1', 'NC|obj0_f0-rob0_v1') not actually feasible
# edge ('NC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'NC|obj0_f0-rob0_v1') -> ('IC|obs0_v1-obj0_f3', 'NC|obs0_f0-rob0_v1', 'NC|obj0_f1-rob0_f1') not actually feasible
# edge ('NC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'NC|obj0_f0-rob0_v1') -> ('IC|obs0_v1-obj0_f3', 'NC|obs0_f0-rob0_v1', 'NC|obj0_f3-rob0_v0') not actually feasible
# edge ('NC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'NC|obj0_f0-rob0_v1') -> ('IC|obs0_v1-obj0_f3', 'NC|obs0_f2-rob0_v0', 'NC|obj0_f0-rob0_v1') not actually feasible
# edge ('NC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'NC|obj0_f0-rob0_v1') -> ('IC|obs0_v1-obj0_f3', 'NC|obs0_f2-rob0_v0', 'NC|obj0_f3-rob0_v0') not actually feasible
# edge ('NC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'NC|obj0_f0-rob0_v1') -> ('NC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'IC|obj0_f1-rob0_f1') is feasible, new dist: 100.8809125772046, added to pq True
# edge ('NC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'NC|obj0_f0-rob0_v1') -> ('NC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'IC|obj0_f0-rob0_v1') is feasible, new dist: 270.79723119255056, added to pq True
# edge ('NC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'NC|obj0_f0-rob0_v1') -> ('NC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'IC|obj0_v0-rob0_f0') is feasible, new dist: 266.0333087781393, added to pq True
# edge ('NC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'NC|obj0_f0-rob0_v1') -> ('NC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'NC|obj0_f1-rob0_f1') is feasible, new dist: 285.6027798599762, added to pq True
# edge ('NC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'NC|obj0_f0-rob0_v1') -> ('NC|obs0_f0-obj0_v3', 'NC|obs0_f1-rob0_f2', 'IC|obj0_f1-rob0_f1') not actually feasible
# edge ('NC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'NC|obj0_f0-rob0_v1') -> ('NC|obs0_f0-obj0_v3', 'NC|obs0_f1-rob0_f2', 'IC|obj0_f0-rob0_v1') not actually feasible
# edge ('NC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'NC|obj0_f0-rob0_v1') -> ('NC|obs0_f0-obj0_v3', 'NC|obs0_f1-rob0_f2', 'IC|obj0_v0-rob0_f0') not actually feasible
# edge ('NC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'NC|obj0_f0-rob0_v1') -> ('NC|obs0_f0-obj0_v3', 'NC|obs0_f1-rob0_f2', 'NC|obj0_f0-rob0_v1') not actually feasible
# edge ('NC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'NC|obj0_f0-rob0_v1') -> ('NC|obs0_f0-obj0_v3', 'NC|obs0_f1-rob0_f2', 'NC|obj0_f1-rob0_f1') not actually feasible
# edge ('NC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'NC|obj0_f0-rob0_v1') -> ('NC|obs0_f0-obj0_v3', 'NC|obs0_f1-rob0_f2', 'NC|obj0_f3-rob0_v0') not actually feasible
# edge ('NC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'NC|obj0_f0-rob0_v1') -> ('NC|obs0_f0-obj0_v3', 'NC|obs0_f2-rob0_v0', 'IC|obj0_f1-rob0_f1') not actually feasible
# edge ('NC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'NC|obj0_f0-rob0_v1') -> ('NC|obs0_f0-obj0_v3', 'NC|obs0_f2-rob0_v0', 'IC|obj0_f0-rob0_v1') not actually feasible
# edge ('NC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'NC|obj0_f0-rob0_v1') -> ('NC|obs0_f0-obj0_v3', 'NC|obs0_f2-rob0_v0', 'IC|obj0_v0-rob0_f0') not actually feasible
# edge ('NC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'NC|obj0_f0-rob0_v1') -> ('NC|obs0_f0-obj0_v3', 'NC|obs0_f2-rob0_v0', 'NC|obj0_f0-rob0_v1') is feasible, new dist: 242.03951391436317, added to pq False
# edge ('NC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'NC|obj0_f0-rob0_v1') -> ('NC|obs0_f0-obj0_v3', 'NC|obs0_f2-rob0_v0', 'NC|obj0_f1-rob0_f1') not actually feasible
# edge ('NC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'NC|obj0_f0-rob0_v1') -> ('NC|obs0_f0-obj0_v3', 'NC|obs0_f2-rob0_v0', 'NC|obj0_f3-rob0_v0') is feasible, new dist: 241.87381070205393, added to pq False
# edge ('NC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'NC|obj0_f0-rob0_v1') -> ('NC|obs0_f1-obj0_f0', 'NC|obs0_f0-rob0_v1', 'IC|obj0_f1-rob0_f1') not actually feasible
# edge ('NC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'NC|obj0_f0-rob0_v1') -> ('NC|obs0_f1-obj0_f0', 'NC|obs0_f0-rob0_v1', 'IC|obj0_f0-rob0_v1') not actually feasible
# edge ('NC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'NC|obj0_f0-rob0_v1') -> ('NC|obs0_f1-obj0_f0', 'NC|obs0_f0-rob0_v1', 'IC|obj0_v0-rob0_f0') not actually feasible
# edge ('NC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'NC|obj0_f0-rob0_v1') -> ('NC|obs0_f1-obj0_f0', 'NC|obs0_f0-rob0_v1', 'NC|obj0_f0-rob0_v1') not actually feasible
# edge ('NC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'NC|obj0_f0-rob0_v1') -> ('NC|obs0_f1-obj0_f0', 'NC|obs0_f0-rob0_v1', 'NC|obj0_f1-rob0_f1') not actually feasible
# edge ('NC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'NC|obj0_f0-rob0_v1') -> ('NC|obs0_f1-obj0_f0', 'NC|obs0_f0-rob0_v1', 'NC|obj0_f3-rob0_v0') not actually feasible
# edge ('NC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'NC|obj0_f0-rob0_v1') -> ('NC|obs0_f1-obj0_f0', 'NC|obs0_f1-rob0_f2', 'IC|obj0_f1-rob0_f1') not actually feasible
# edge ('NC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'NC|obj0_f0-rob0_v1') -> ('NC|obs0_f1-obj0_f0', 'NC|obs0_f1-rob0_f2', 'IC|obj0_f0-rob0_v1') not actually feasible
# edge ('NC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'NC|obj0_f0-rob0_v1') -> ('NC|obs0_f1-obj0_f0', 'NC|obs0_f1-rob0_f2', 'IC|obj0_v0-rob0_f0') not actually feasible
# edge ('NC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'NC|obj0_f0-rob0_v1') -> ('NC|obs0_f1-obj0_f0', 'NC|obs0_f1-rob0_f2', 'NC|obj0_f0-rob0_v1') not actually feasible
# edge ('NC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'NC|obj0_f0-rob0_v1') -> ('NC|obs0_f1-obj0_f0', 'NC|obs0_f1-rob0_f2', 'NC|obj0_f1-rob0_f1') not actually feasible
# edge ('NC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'NC|obj0_f0-rob0_v1') -> ('NC|obs0_f1-obj0_f0', 'NC|obs0_f1-rob0_f2', 'NC|obj0_f3-rob0_v0') not actually feasible
# edge ('NC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'NC|obj0_f0-rob0_v1') -> ('NC|obs0_f1-obj0_f0', 'NC|obs0_f2-rob0_v0', 'NC|obj0_f0-rob0_v1') not actually feasible
# edge ('NC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'NC|obj0_f0-rob0_v1') -> ('NC|obs0_f1-obj0_f0', 'NC|obs0_f2-rob0_v0', 'NC|obj0_f3-rob0_v0') not actually feasible
# edge ('NC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'NC|obj0_f0-rob0_v1') -> ('NC|obs0_f2-obj0_f1', 'NC|obs0_f0-rob0_v1', 'IC|obj0_f1-rob0_f1') not actually feasible
# edge ('NC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'NC|obj0_f0-rob0_v1') -> ('NC|obs0_f2-obj0_f1', 'NC|obs0_f0-rob0_v1', 'IC|obj0_f0-rob0_v1') not actually feasible
# edge ('NC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'NC|obj0_f0-rob0_v1') -> ('NC|obs0_f2-obj0_f1', 'NC|obs0_f0-rob0_v1', 'IC|obj0_v0-rob0_f0') not actually feasible
# edge ('NC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'NC|obj0_f0-rob0_v1') -> ('NC|obs0_f2-obj0_f1', 'NC|obs0_f0-rob0_v1', 'NC|obj0_f0-rob0_v1') not actually feasible
# edge ('NC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'NC|obj0_f0-rob0_v1') -> ('NC|obs0_f2-obj0_f1', 'NC|obs0_f0-rob0_v1', 'NC|obj0_f1-rob0_f1') not actually feasible
# edge ('NC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'NC|obj0_f0-rob0_v1') -> ('NC|obs0_f2-obj0_f1', 'NC|obs0_f0-rob0_v1', 'NC|obj0_f3-rob0_v0') not actually feasible
# edge ('NC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'NC|obj0_f0-rob0_v1') -> ('NC|obs0_f2-obj0_f1', 'NC|obs0_f2-rob0_v0', 'IC|obj0_f1-rob0_f1') not actually feasible
# edge ('NC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'NC|obj0_f0-rob0_v1') -> ('NC|obs0_f2-obj0_f1', 'NC|obs0_f2-rob0_v0', 'IC|obj0_f0-rob0_v1') not actually feasible
# edge ('NC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'NC|obj0_f0-rob0_v1') -> ('NC|obs0_f2-obj0_f1', 'NC|obs0_f2-rob0_v0', 'IC|obj0_v0-rob0_f0') not actually feasible
# edge ('NC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'NC|obj0_f0-rob0_v1') -> ('NC|obs0_f2-obj0_f1', 'NC|obs0_f2-rob0_v0', 'NC|obj0_f0-rob0_v1') not actually feasible
# edge ('NC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'NC|obj0_f0-rob0_v1') -> ('NC|obs0_f2-obj0_f1', 'NC|obs0_f2-rob0_v0', 'NC|obj0_f1-rob0_f1') not actually feasible
# edge ('NC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'NC|obj0_f0-rob0_v1') -> ('NC|obs0_f2-obj0_f1', 'NC|obs0_f2-rob0_v0', 'NC|obj0_f3-rob0_v0') not actually feasible
#
# n_vertices_visited: 7, n_edges_visited: 3, n_vertices_explored: 223, vertex_coverage: 0.0387, edge_coverage: 0.0005, time_wall_clock: 0.934, n_gcs_solves: 226, gcs_solve_time_total: 0.65, gcs_solve_time_iter_mean: 0.00288, gcs_solve_time_last_10_mean: 0.00155, gcs_solve_time_iter_std: 0.0129, gcs_solve_time_iter_min: 0.00106, gcs_solve_time_iter_max: 0.191, n_vertices_revisited: 0, n_vertices_reexplored: 3
# now exploring node ('NC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'IC|obj0_f1-rob0_f1')'s 67 neighbors (100.8809125772046)
# edge ('NC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'IC|obj0_f1-rob0_f1') -> ('IC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'IC|obj0_f1-rob0_f1') is feasible, new dist: 63.73090646991367, added to pq True
# edge ('NC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'IC|obj0_f1-rob0_f1') -> ('IC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'IC|obj0_f2-rob0_f2') is feasible, new dist: 103.54514169271756, added to pq True
# edge ('NC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'IC|obj0_f1-rob0_f1') -> ('IC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'IC|obj0_f0-rob0_v1') is feasible, new dist: 96.54172926251303, added to pq True
# edge ('NC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'IC|obj0_f1-rob0_f1') -> ('IC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'NC|obj0_f0-rob0_v1') is feasible, new dist: 92.10647090765592, added to pq True
# edge ('NC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'IC|obj0_f1-rob0_f1') -> ('IC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'NC|obj0_f1-rob0_f1') not actually feasible
# edge ('NC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'IC|obj0_f1-rob0_f1') -> ('IC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'NC|obj0_f2-rob0_f2') is feasible, new dist: 103.54514169271798, added to pq True
# edge ('NC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'IC|obj0_f1-rob0_f1') -> ('IC|obs0_f0-obj0_v3', 'NC|obs0_f1-rob0_f2', 'IC|obj0_f1-rob0_f1') not actually feasible
# edge ('NC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'IC|obj0_f1-rob0_f1') -> ('IC|obs0_f0-obj0_v3', 'NC|obs0_f1-rob0_f2', 'IC|obj0_f2-rob0_f2') not actually feasible
# edge ('NC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'IC|obj0_f1-rob0_f1') -> ('IC|obs0_f0-obj0_v3', 'NC|obs0_f1-rob0_f2', 'NC|obj0_f1-rob0_f1') not actually feasible
# edge ('NC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'IC|obj0_f1-rob0_f1') -> ('IC|obs0_f0-obj0_v3', 'NC|obs0_f1-rob0_f2', 'NC|obj0_f2-rob0_f2') not actually feasible
# edge ('NC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'IC|obj0_f1-rob0_f1') -> ('IC|obs0_v0-obj0_f2', 'NC|obs0_f0-rob0_v1', 'IC|obj0_f1-rob0_f1') not actually feasible
# edge ('NC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'IC|obj0_f1-rob0_f1') -> ('IC|obs0_v0-obj0_f2', 'NC|obs0_f0-rob0_v1', 'IC|obj0_f2-rob0_f2') not actually feasible
# edge ('NC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'IC|obj0_f1-rob0_f1') -> ('IC|obs0_v0-obj0_f2', 'NC|obs0_f0-rob0_v1', 'IC|obj0_f0-rob0_v1') not actually feasible
# edge ('NC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'IC|obj0_f1-rob0_f1') -> ('IC|obs0_v0-obj0_f2', 'NC|obs0_f0-rob0_v1', 'NC|obj0_f0-rob0_v1') not actually feasible
# edge ('NC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'IC|obj0_f1-rob0_f1') -> ('IC|obs0_v0-obj0_f2', 'NC|obs0_f0-rob0_v1', 'NC|obj0_f1-rob0_f1') not actually feasible
# edge ('NC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'IC|obj0_f1-rob0_f1') -> ('IC|obs0_v0-obj0_f2', 'NC|obs0_f0-rob0_v1', 'NC|obj0_f2-rob0_f2') not actually feasible
# edge ('NC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'IC|obj0_f1-rob0_f1') -> ('IC|obs0_v1-obj0_f3', 'NC|obs0_f0-rob0_v1', 'IC|obj0_f1-rob0_f1') not actually feasible
# edge ('NC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'IC|obj0_f1-rob0_f1') -> ('IC|obs0_v1-obj0_f3', 'NC|obs0_f0-rob0_v1', 'IC|obj0_f2-rob0_f2') not actually feasible
# edge ('NC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'IC|obj0_f1-rob0_f1') -> ('IC|obs0_v1-obj0_f3', 'NC|obs0_f0-rob0_v1', 'IC|obj0_f0-rob0_v1') not actually feasible
# edge ('NC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'IC|obj0_f1-rob0_f1') -> ('IC|obs0_v1-obj0_f3', 'NC|obs0_f0-rob0_v1', 'NC|obj0_f0-rob0_v1') not actually feasible
# edge ('NC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'IC|obj0_f1-rob0_f1') -> ('IC|obs0_v1-obj0_f3', 'NC|obs0_f0-rob0_v1', 'NC|obj0_f1-rob0_f1') not actually feasible
# edge ('NC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'IC|obj0_f1-rob0_f1') -> ('IC|obs0_v1-obj0_f3', 'NC|obs0_f0-rob0_v1', 'NC|obj0_f2-rob0_f2') not actually feasible
# edge ('NC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'IC|obj0_f1-rob0_f1') -> ('IC|obs0_v1-obj0_f3', 'NC|obs0_f1-rob0_f2', 'IC|obj0_f1-rob0_f1') not actually feasible
# edge ('NC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'IC|obj0_f1-rob0_f1') -> ('IC|obs0_v1-obj0_f3', 'NC|obs0_f1-rob0_f2', 'IC|obj0_f2-rob0_f2') not actually feasible
# edge ('NC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'IC|obj0_f1-rob0_f1') -> ('IC|obs0_v1-obj0_f3', 'NC|obs0_f1-rob0_f2', 'NC|obj0_f1-rob0_f1') not actually feasible
# edge ('NC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'IC|obj0_f1-rob0_f1') -> ('IC|obs0_v1-obj0_f3', 'NC|obs0_f1-rob0_f2', 'NC|obj0_f2-rob0_f2') not actually feasible
# edge ('NC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'IC|obj0_f1-rob0_f1') -> ('NC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'IC|obj0_f2-rob0_f2') is feasible, new dist: 102.26011815972569, added to pq True
# edge ('NC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'IC|obj0_f1-rob0_f1') -> ('NC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'IC|obj0_f0-rob0_v1') is feasible, new dist: 96.54172926251303, added to pq True
# edge ('NC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'IC|obj0_f1-rob0_f1') -> ('NC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'NC|obj0_f1-rob0_f1') not actually feasible
# edge ('NC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'IC|obj0_f1-rob0_f1') -> ('NC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'NC|obj0_f2-rob0_f2') is feasible, new dist: 103.54514169258536, added to pq True
# edge ('NC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'IC|obj0_f1-rob0_f1') -> ('NC|obs0_f0-obj0_v3', 'NC|obs0_f1-rob0_f2', 'IC|obj0_f1-rob0_f1') not actually feasible
# edge ('NC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'IC|obj0_f1-rob0_f1') -> ('NC|obs0_f0-obj0_v3', 'NC|obs0_f1-rob0_f2', 'IC|obj0_f2-rob0_f2') not actually feasible
# edge ('NC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'IC|obj0_f1-rob0_f1') -> ('NC|obs0_f0-obj0_v3', 'NC|obs0_f1-rob0_f2', 'IC|obj0_f0-rob0_v1') not actually feasible
# edge ('NC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'IC|obj0_f1-rob0_f1') -> ('NC|obs0_f0-obj0_v3', 'NC|obs0_f1-rob0_f2', 'NC|obj0_f0-rob0_v1') not actually feasible
# edge ('NC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'IC|obj0_f1-rob0_f1') -> ('NC|obs0_f0-obj0_v3', 'NC|obs0_f1-rob0_f2', 'NC|obj0_f1-rob0_f1') not actually feasible
# edge ('NC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'IC|obj0_f1-rob0_f1') -> ('NC|obs0_f0-obj0_v3', 'NC|obs0_f1-rob0_f2', 'NC|obj0_f2-rob0_f2') not actually feasible
# edge ('NC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'IC|obj0_f1-rob0_f1') -> ('NC|obs0_f0-obj0_v3', 'NC|obs0_f2-rob0_v0', 'IC|obj0_f1-rob0_f1') not actually feasible
# edge ('NC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'IC|obj0_f1-rob0_f1') -> ('NC|obs0_f0-obj0_v3', 'NC|obs0_f2-rob0_v0', 'IC|obj0_f2-rob0_f2') not actually feasible
# edge ('NC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'IC|obj0_f1-rob0_f1') -> ('NC|obs0_f0-obj0_v3', 'NC|obs0_f2-rob0_v0', 'IC|obj0_f0-rob0_v1') not actually feasible
# edge ('NC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'IC|obj0_f1-rob0_f1') -> ('NC|obs0_f0-obj0_v3', 'NC|obs0_f2-rob0_v0', 'NC|obj0_f0-rob0_v1') not actually feasible
# edge ('NC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'IC|obj0_f1-rob0_f1') -> ('NC|obs0_f0-obj0_v3', 'NC|obs0_f2-rob0_v0', 'NC|obj0_f1-rob0_f1') not actually feasible
# edge ('NC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'IC|obj0_f1-rob0_f1') -> ('NC|obs0_f0-obj0_v3', 'NC|obs0_f2-rob0_v0', 'NC|obj0_f2-rob0_f2') not actually feasible
# ...
# edge ('NC|obs0_f2-obj0_f1', 'NC|obs0_f2-rob0_v0', 'IC|obj0_f0-rob0_v1') -> ('NC|obs0_f2-obj0_f1', 'NC|obs0_f1-rob0_f2', 'IC|obj0_v0-rob0_f0') not actually feasible
# edge ('NC|obs0_f2-obj0_f1', 'NC|obs0_f2-rob0_v0', 'IC|obj0_f0-rob0_v1') -> ('NC|obs0_f2-obj0_f1', 'NC|obs0_f1-rob0_f2', 'NC|obj0_f0-rob0_v1') is feasible, new dist: 170.19860728879374, added to pq True
# edge ('NC|obs0_f2-obj0_f1', 'NC|obs0_f2-rob0_v0', 'IC|obj0_f0-rob0_v1') -> ('NC|obs0_f2-obj0_f1', 'NC|obs0_f1-rob0_f2', 'NC|obj0_f1-rob0_f1') not actually feasible
# edge ('NC|obs0_f2-obj0_f1', 'NC|obs0_f2-rob0_v0', 'IC|obj0_f0-rob0_v1') -> ('NC|obs0_f2-obj0_f1', 'NC|obs0_f2-rob0_v0', 'IC|obj0_f1-rob0_f1') not actually feasible
# edge ('NC|obs0_f2-obj0_f1', 'NC|obs0_f2-rob0_v0', 'IC|obj0_f0-rob0_v1') -> ('NC|obs0_f2-obj0_f1', 'NC|obs0_f2-rob0_v0', 'IC|obj0_v0-rob0_f0') is feasible, new dist: 35.01052874850791, added to pq True
# edge ('NC|obs0_f2-obj0_f1', 'NC|obs0_f2-rob0_v0', 'IC|obj0_f0-rob0_v1') -> ('NC|obs0_f2-obj0_f1', 'NC|obs0_f2-rob0_v0', 'NC|obj0_f0-rob0_v1') is feasible, new dist: 35.32177314662382, added to pq True
# edge ('NC|obs0_f2-obj0_f1', 'NC|obs0_f2-rob0_v0', 'IC|obj0_f0-rob0_v1') -> ('NC|obs0_f2-obj0_f1', 'NC|obs0_f2-rob0_v0', 'NC|obj0_f1-rob0_f1') not actually feasible
#
# n_vertices_visited: 12, n_edges_visited: 7, n_vertices_explored: 410, vertex_coverage: 0.0663, edge_coverage: 0.0011, time_wall_clock: 4.04, n_gcs_solves: 415, gcs_solve_time_total: 3.46, gcs_solve_time_iter_mean: 0.00833, gcs_solve_time_last_10_mean: 0.0134, gcs_solve_time_iter_std: 0.0238, gcs_solve_time_iter_min: 0.00106, gcs_solve_time_iter_max: 0.381, n_vertices_revisited: 0, n_vertices_reexplored: 5
# now exploring node ('IC|obs0_f2-obj0_f1', 'NC|obs0_f2-rob0_v0', 'IC|obj0_f0-rob0_v1')'s 23 neighbors (34.349549618409775)
# edge ('IC|obs0_f2-obj0_f1', 'NC|obs0_f2-rob0_v0', 'IC|obj0_f0-rob0_v1') -> ('IC|obs0_f1-obj0_f0', 'NC|obs0_f2-rob0_v0', 'IC|obj0_f0-rob0_v1') not actually feasible
# edge ('IC|obs0_f2-obj0_f1', 'NC|obs0_f2-rob0_v0', 'IC|obj0_f0-rob0_v1') -> ('IC|obs0_f1-obj0_f0', 'NC|obs0_f2-rob0_v0', 'IC|obj0_v0-rob0_f0') not actually feasible
# edge ('IC|obs0_f2-obj0_f1', 'NC|obs0_f2-rob0_v0', 'IC|obj0_f0-rob0_v1') -> ('IC|obs0_f1-obj0_f0', 'NC|obs0_f2-rob0_v0', 'NC|obj0_f0-rob0_v1') is feasible, new dist: 103.56341096493395, added to pq False
# edge ('IC|obs0_f2-obj0_f1', 'NC|obs0_f2-rob0_v0', 'IC|obj0_f0-rob0_v1') -> ('IC|obs0_f2-obj0_f1', 'NC|obs0_f0-rob0_v1', 'IC|obj0_v0-rob0_f0') is feasible, new dist: 61.40862447855697, added to pq False
# edge ('IC|obs0_f2-obj0_f1', 'NC|obs0_f2-rob0_v0', 'IC|obj0_f0-rob0_v1') -> ('IC|obs0_f2-obj0_f1', 'NC|obs0_f0-rob0_v1', 'NC|obj0_f0-rob0_v1') is feasible, new dist: 47.4817555916663, added to pq False
# edge ('IC|obs0_f2-obj0_f1', 'NC|obs0_f2-rob0_v0', 'IC|obj0_f0-rob0_v1') -> ('IC|obs0_f2-obj0_f1', 'NC|obs0_f2-rob0_v0', 'IC|obj0_v0-rob0_f0') is feasible, new dist: 34.96898027155149, added to pq False
# edge ('IC|obs0_f2-obj0_f1', 'NC|obs0_f2-rob0_v0', 'IC|obj0_f0-rob0_v1') -> ('IC|obs0_f2-obj0_f1', 'NC|obs0_f2-rob0_v0', 'NC|obj0_f0-rob0_v1') is feasible, new dist: 35.321773146623755, added to pq True
# edge ('IC|obs0_f2-obj0_f1', 'NC|obs0_f2-rob0_v0', 'IC|obj0_f0-rob0_v1') -> ('IC|obs0_v0-obj0_f2', 'NC|obs0_f0-rob0_v1', 'IC|obj0_f0-rob0_v1') is feasible, new dist: 61.4086244769271, added to pq False
# edge ('IC|obs0_f2-obj0_f1', 'NC|obs0_f2-rob0_v0', 'IC|obj0_f0-rob0_v1') -> ('IC|obs0_v0-obj0_f2', 'NC|obs0_f0-rob0_v1', 'IC|obj0_v0-rob0_f0') not actually feasible
# edge ('IC|obs0_f2-obj0_f1', 'NC|obs0_f2-rob0_v0', 'IC|obj0_f0-rob0_v1') -> ('IC|obs0_v0-obj0_f2', 'NC|obs0_f0-rob0_v1', 'NC|obj0_f0-rob0_v1') is feasible, new dist: 61.40862447677743, added to pq False
# edge ('IC|obs0_f2-obj0_f1', 'NC|obs0_f2-rob0_v0', 'IC|obj0_f0-rob0_v1') -> ('IC|obs0_v0-obj0_f2', 'NC|obs0_f2-rob0_v0', 'IC|obj0_f0-rob0_v1') is feasible, new dist: 61.40862447685531, added to pq False
# edge ('IC|obs0_f2-obj0_f1', 'NC|obs0_f2-rob0_v0', 'IC|obj0_f0-rob0_v1') -> ('IC|obs0_v0-obj0_f2', 'NC|obs0_f2-rob0_v0', 'IC|obj0_v0-rob0_f0') is feasible, new dist: 58.39470206197142, added to pq False
# edge ('IC|obs0_f2-obj0_f1', 'NC|obs0_f2-rob0_v0', 'IC|obj0_f0-rob0_v1') -> ('IC|obs0_v0-obj0_f2', 'NC|obs0_f2-rob0_v0', 'NC|obj0_f0-rob0_v1') is feasible, new dist: 61.380848001550916, added to pq False
# edge ('IC|obs0_f2-obj0_f1', 'NC|obs0_f2-rob0_v0', 'IC|obj0_f0-rob0_v1') -> ('NC|obs0_f1-obj0_f0', 'NC|obs0_f2-rob0_v0', 'IC|obj0_f0-rob0_v1') not actually feasible
# edge ('IC|obs0_f2-obj0_f1', 'NC|obs0_f2-rob0_v0', 'IC|obj0_f0-rob0_v1') -> ('NC|obs0_f1-obj0_f0', 'NC|obs0_f2-rob0_v0', 'IC|obj0_v0-rob0_f0') is feasible, new dist: 104.15891723748886, added to pq True
# edge ('IC|obs0_f2-obj0_f1', 'NC|obs0_f2-rob0_v0', 'IC|obj0_f0-rob0_v1') -> ('NC|obs0_f1-obj0_f0', 'NC|obs0_f2-rob0_v0', 'NC|obj0_f0-rob0_v1') is feasible, new dist: 103.5634109646387, added to pq False
# edge ('IC|obs0_f2-obj0_f1', 'NC|obs0_f2-rob0_v0', 'IC|obj0_f0-rob0_v1') -> ('NC|obs0_f2-obj0_f1', 'NC|obs0_f0-rob0_v1', 'IC|obj0_f0-rob0_v1') not actually feasible
# edge ('IC|obs0_f2-obj0_f1', 'NC|obs0_f2-rob0_v0', 'IC|obj0_f0-rob0_v1') -> ('NC|obs0_f2-obj0_f1', 'NC|obs0_f0-rob0_v1', 'IC|obj0_v0-rob0_f0') is feasible, new dist: 61.40862447301438, added to pq False
# edge ('IC|obs0_f2-obj0_f1', 'NC|obs0_f2-rob0_v0', 'IC|obj0_f0-rob0_v1') -> ('NC|obs0_f2-obj0_f1', 'NC|obs0_f0-rob0_v1', 'NC|obj0_f0-rob0_v1') is feasible, new dist: 47.48175559166629, added to pq True
# edge ('IC|obs0_f2-obj0_f1', 'NC|obs0_f2-rob0_v0', 'IC|obj0_f0-rob0_v1') -> ('NC|obs0_f2-obj0_f1', 'NC|obs0_f2-rob0_v0', 'IC|obj0_f0-rob0_v1') is feasible, new dist: 35.3495496180868, added to pq False
# edge ('IC|obs0_f2-obj0_f1', 'NC|obs0_f2-rob0_v0', 'IC|obj0_f0-rob0_v1') -> ('NC|obs0_f2-obj0_f1', 'NC|obs0_f2-rob0_v0', 'IC|obj0_v0-rob0_f0') is feasible, new dist: 35.01052874850775, added to pq True
# edge ('IC|obs0_f2-obj0_f1', 'NC|obs0_f2-rob0_v0', 'IC|obj0_f0-rob0_v1') -> ('NC|obs0_f2-obj0_f1', 'NC|obs0_f2-rob0_v0', 'NC|obj0_f0-rob0_v1') is feasible, new dist: 35.32177314662377, added to pq True
#
# n_vertices_visited: 13, n_edges_visited: 8, n_vertices_explored: 431, vertex_coverage: 0.0718, edge_coverage: 0.0012, time_wall_clock: 4.66, n_gcs_solves: 437, gcs_solve_time_total: 4.03, gcs_solve_time_iter_mean: 0.00923, gcs_solve_time_last_10_mean: 0.0265, gcs_solve_time_iter_std: 0.0238, gcs_solve_time_iter_min: 0.00106, gcs_solve_time_iter_max: 0.381, n_vertices_revisited: 0, n_vertices_reexplored: 6
# now exploring node ('IC|obs0_f2-obj0_f1', 'NC|obs0_f2-rob0_v0', 'IC|obj0_v0-rob0_f0')'s 45 neighbors (34.968980271548816)
# edge ('IC|obs0_f2-obj0_f1', 'NC|obs0_f2-rob0_v0', 'IC|obj0_v0-rob0_f0') -> ('IC|obs0_f1-obj0_f0', 'NC|obs0_f1-rob0_f2', 'IC|obj0_f3-rob0_v0') is feasible, new dist: 109.83616888630063, added to pq True
# edge ('IC|obs0_f2-obj0_f1', 'NC|obs0_f2-rob0_v0', 'IC|obj0_v0-rob0_f0') -> ('IC|obs0_f1-obj0_f0', 'NC|obs0_f1-rob0_f2', 'IC|obj0_v0-rob0_f0') is feasible, new dist: 109.83616904925303, added to pq True
# edge ('IC|obs0_f2-obj0_f1', 'NC|obs0_f2-rob0_v0', 'IC|obj0_v0-rob0_f0') -> ('IC|obs0_f1-obj0_f0', 'NC|obs0_f1-rob0_f2', 'NC|obj0_f3-rob0_v0') is feasible, new dist: 109.83616877429915, added to pq True
# edge ('IC|obs0_f2-obj0_f1', 'NC|obs0_f2-rob0_v0', 'IC|obj0_v0-rob0_f0') -> ('IC|obs0_f1-obj0_f0', 'NC|obs0_f2-rob0_v0', 'IC|obj0_f0-rob0_v1') is feasible, new dist: 105.158917237488, added to pq True
# edge ('IC|obs0_f2-obj0_f1', 'NC|obs0_f2-rob0_v0', 'IC|obj0_v0-rob0_f0') -> ('IC|obs0_f1-obj0_f0', 'NC|obs0_f2-rob0_v0', 'IC|obj0_f3-rob0_v0') is feasible, new dist: 109.83616888630029, added to pq True
# edge ('IC|obs0_f2-obj0_f1', 'NC|obs0_f2-rob0_v0', 'IC|obj0_v0-rob0_f0') -> ('IC|obs0_f1-obj0_f0', 'NC|obs0_f2-rob0_v0', 'IC|obj0_v0-rob0_f0') not actually feasible
# edge ('IC|obs0_f2-obj0_f1', 'NC|obs0_f2-rob0_v0', 'IC|obj0_v0-rob0_f0') -> ('IC|obs0_f1-obj0_f0', 'NC|obs0_f2-rob0_v0', 'NC|obj0_f0-rob0_v1') is feasible, new dist: 104.56341096414705, added to pq False
# edge ('IC|obs0_f2-obj0_f1', 'NC|obs0_f2-rob0_v0', 'IC|obj0_v0-rob0_f0') -> ('IC|obs0_f1-obj0_f0', 'NC|obs0_f2-rob0_v0', 'NC|obj0_f3-rob0_v0') is feasible, new dist: 107.80068192174427, added to pq True
# edge ('IC|obs0_f2-obj0_f1', 'NC|obs0_f2-rob0_v0', 'IC|obj0_v0-rob0_f0') -> ('IC|obs0_f2-obj0_f1', 'NC|obs0_f0-rob0_v1', 'IC|obj0_v0-rob0_f0') is feasible, new dist: 62.408624473013845, added to pq False
# edge ('IC|obs0_f2-obj0_f1', 'NC|obs0_f2-rob0_v0', 'IC|obj0_v0-rob0_f0') -> ('IC|obs0_f2-obj0_f1', 'NC|obs0_f0-rob0_v1', 'NC|obj0_f0-rob0_v1') not actually feasible
# edge ('IC|obs0_f2-obj0_f1', 'NC|obs0_f2-rob0_v0', 'IC|obj0_v0-rob0_f0') -> ('IC|obs0_f2-obj0_f1', 'NC|obs0_f1-rob0_f2', 'IC|obj0_f3-rob0_v0') is feasible, new dist: 109.83616888630061, added to pq True
# edge ('IC|obs0_f2-obj0_f1', 'NC|obs0_f2-rob0_v0', 'IC|obj0_v0-rob0_f0') -> ('IC|obs0_f2-obj0_f1', 'NC|obs0_f1-rob0_f2', 'IC|obj0_v0-rob0_f0') is feasible, new dist: 109.83616890411815, added to pq True
# edge ('IC|obs0_f2-obj0_f1', 'NC|obs0_f2-rob0_v0', 'IC|obj0_v0-rob0_f0') -> ('IC|obs0_f2-obj0_f1', 'NC|obs0_f1-rob0_f2', 'NC|obj0_f3-rob0_v0') is feasible, new dist: 109.83616888615951, added to pq True
# edge ('IC|obs0_f2-obj0_f1', 'NC|obs0_f2-rob0_v0', 'IC|obj0_v0-rob0_f0') -> ('IC|obs0_f2-obj0_f1', 'NC|obs0_f2-rob0_v0', 'IC|obj0_f0-rob0_v1') not actually feasible
# edge ('IC|obs0_f2-obj0_f1', 'NC|obs0_f2-rob0_v0', 'IC|obj0_v0-rob0_f0') -> ('IC|obs0_f2-obj0_f1', 'NC|obs0_f2-rob0_v0', 'IC|obj0_f3-rob0_v0') not actually feasible
# edge ('IC|obs0_f2-obj0_f1', 'NC|obs0_f2-rob0_v0', 'IC|obj0_v0-rob0_f0') -> ('IC|obs0_f2-obj0_f1', 'NC|obs0_f2-rob0_v0', 'NC|obj0_f0-rob0_v1') is feasible, new dist: 36.321773129306386, added to pq False
# edge ('IC|obs0_f2-obj0_f1', 'NC|obs0_f2-rob0_v0', 'IC|obj0_v0-rob0_f0') -> ('IC|obs0_f2-obj0_f1', 'NC|obs0_f2-rob0_v0', 'NC|obj0_f3-rob0_v0') is feasible, new dist: 37.170682266520686, added to pq True
# edge ('IC|obs0_f2-obj0_f1', 'NC|obs0_f2-rob0_v0', 'IC|obj0_v0-rob0_f0') -> ('IC|obs0_v0-obj0_f2', 'NC|obs0_f0-rob0_v1', 'IC|obj0_f0-rob0_v1') is feasible, new dist: 62.408624473014015, added to pq False
# edge ('IC|obs0_f2-obj0_f1', 'NC|obs0_f2-rob0_v0', 'IC|obj0_v0-rob0_f0') -> ('IC|obs0_v0-obj0_f2', 'NC|obs0_f0-rob0_v1', 'IC|obj0_v0-rob0_f0') is feasible, new dist: 62.408624473013944, added to pq False
# edge ('IC|obs0_f2-obj0_f1', 'NC|obs0_f2-rob0_v0', 'IC|obj0_v0-rob0_f0') -> ('IC|obs0_v0-obj0_f2', 'NC|obs0_f0-rob0_v1', 'NC|obj0_f0-rob0_v1') is feasible, new dist: 62.40862447301385, added to pq False
# edge ('IC|obs0_f2-obj0_f1', 'NC|obs0_f2-rob0_v0', 'IC|obj0_v0-rob0_f0') -> ('IC|obs0_v0-obj0_f2', 'NC|obs0_f2-rob0_v0', 'IC|obj0_f0-rob0_v1') not actually feasible
# edge ('IC|obs0_f2-obj0_f1', 'NC|obs0_f2-rob0_v0', 'IC|obj0_v0-rob0_f0') -> ('IC|obs0_v0-obj0_f2', 'NC|obs0_f2-rob0_v0', 'IC|obj0_f3-rob0_v0') is feasible, new dist: 58.950261410416665, added to pq True
# edge ('IC|obs0_f2-obj0_f1', 'NC|obs0_f2-rob0_v0', 'IC|obj0_v0-rob0_f0') -> ('IC|obs0_v0-obj0_f2', 'NC|obs0_f2-rob0_v0', 'IC|obj0_v0-rob0_f0') is feasible, new dist: 59.39470206075515, added to pq False
# edge ('IC|obs0_f2-obj0_f1', 'NC|obs0_f2-rob0_v0', 'IC|obj0_v0-rob0_f0') -> ('IC|obs0_v0-obj0_f2', 'NC|obs0_f2-rob0_v0', 'NC|obj0_f0-rob0_v1') is feasible, new dist: 62.38084800181529, added to pq False
# edge ('IC|obs0_f2-obj0_f1', 'NC|obs0_f2-rob0_v0', 'IC|obj0_v0-rob0_f0') -> ('IC|obs0_v0-obj0_f2', 'NC|obs0_f2-rob0_v0', 'NC|obj0_f3-rob0_v0') is feasible, new dist: 58.762596226282675, added to pq True
# edge ('IC|obs0_f2-obj0_f1', 'NC|obs0_f2-rob0_v0', 'IC|obj0_v0-rob0_f0') -> ('NC|obs0_f1-obj0_f0', 'NC|obs0_f1-rob0_f2', 'IC|obj0_f3-rob0_v0') is feasible, new dist: 109.83616888631562, added to pq True
# edge ('IC|obs0_f2-obj0_f1', 'NC|obs0_f2-rob0_v0', 'IC|obj0_v0-rob0_f0') -> ('NC|obs0_f1-obj0_f0', 'NC|obs0_f1-rob0_f2', 'IC|obj0_v0-rob0_f0') is feasible, new dist: 109.83616888628991, added to pq True
# edge ('IC|obs0_f2-obj0_f1', 'NC|obs0_f2-rob0_v0', 'IC|obj0_v0-rob0_f0') -> ('NC|obs0_f1-obj0_f0', 'NC|obs0_f1-rob0_f2', 'NC|obj0_f3-rob0_v0') is feasible, new dist: 109.83616851993433, added to pq True
# edge ('IC|obs0_f2-obj0_f1', 'NC|obs0_f2-rob0_v0', 'IC|obj0_v0-rob0_f0') -> ('NC|obs0_f1-obj0_f0', 'NC|obs0_f2-rob0_v0', 'IC|obj0_f0-rob0_v1') is feasible, new dist: 105.15891723748801, added to pq True
# edge ('IC|obs0_f2-obj0_f1', 'NC|obs0_f2-rob0_v0', 'IC|obj0_v0-rob0_f0') -> ('NC|obs0_f1-obj0_f0', 'NC|obs0_f2-rob0_v0', 'IC|obj0_f3-rob0_v0') is feasible, new dist: 109.83616888631524, added to pq True
# edge ('IC|obs0_f2-obj0_f1', 'NC|obs0_f2-rob0_v0', 'IC|obj0_v0-rob0_f0') -> ('NC|obs0_f1-obj0_f0', 'NC|obs0_f2-rob0_v0', 'IC|obj0_v0-rob0_f0') is feasible, new dist: 105.15891723748801, added to pq False
# edge ('IC|obs0_f2-obj0_f1', 'NC|obs0_f2-rob0_v0', 'IC|obj0_v0-rob0_f0') -> ('NC|obs0_f1-obj0_f0', 'NC|obs0_f2-rob0_v0', 'NC|obj0_f0-rob0_v1') is feasible, new dist: 104.56341096411727, added to pq False
# edge ('IC|obs0_f2-obj0_f1', 'NC|obs0_f2-rob0_v0', 'IC|obj0_v0-rob0_f0') -> ('NC|obs0_f1-obj0_f0', 'NC|obs0_f2-rob0_v0', 'NC|obj0_f3-rob0_v0') is feasible, new dist: 107.80068191008266, added to pq True
# edge ('IC|obs0_f2-obj0_f1', 'NC|obs0_f2-rob0_v0', 'IC|obj0_v0-rob0_f0') -> ('NC|obs0_f2-obj0_f1', 'NC|obs0_f0-rob0_v1', 'IC|obj0_f0-rob0_v1') is feasible, new dist: 44.55488671182089, added to pq False
# edge ('IC|obs0_f2-obj0_f1', 'NC|obs0_f2-rob0_v0', 'IC|obj0_v0-rob0_f0') -> ('NC|obs0_f2-obj0_f1', 'NC|obs0_f0-rob0_v1', 'IC|obj0_v0-rob0_f0') not actually feasible
# edge ('IC|obs0_f2-obj0_f1', 'NC|obs0_f2-rob0_v0', 'IC|obj0_v0-rob0_f0') -> ('NC|obs0_f2-obj0_f1', 'NC|obs0_f0-rob0_v1', 'NC|obj0_f0-rob0_v1') not actually feasible
# edge ('IC|obs0_f2-obj0_f1', 'NC|obs0_f2-rob0_v0', 'IC|obj0_v0-rob0_f0') -> ('NC|obs0_f2-obj0_f1', 'NC|obs0_f1-rob0_f2', 'IC|obj0_f3-rob0_v0') is feasible, new dist: 109.8361688863156, added to pq True
# edge ('IC|obs0_f2-obj0_f1', 'NC|obs0_f2-rob0_v0', 'IC|obj0_v0-rob0_f0') -> ('NC|obs0_f2-obj0_f1', 'NC|obs0_f1-rob0_f2', 'IC|obj0_v0-rob0_f0') not actually feasible
# edge ('IC|obs0_f2-obj0_f1', 'NC|obs0_f2-rob0_v0', 'IC|obj0_v0-rob0_f0') -> ('NC|obs0_f2-obj0_f1', 'NC|obs0_f1-rob0_f2', 'NC|obj0_f3-rob0_v0') not actually feasible
# edge ('IC|obs0_f2-obj0_f1', 'NC|obs0_f2-rob0_v0', 'IC|obj0_v0-rob0_f0') -> ('NC|obs0_f2-obj0_f1', 'NC|obs0_f2-rob0_v0', 'IC|obj0_f3-rob0_v0') not actually feasible
# edge ('IC|obs0_f2-obj0_f1', 'NC|obs0_f2-rob0_v0', 'IC|obj0_v0-rob0_f0') -> ('NC|obs0_f2-obj0_f1', 'NC|obs0_f2-rob0_v0', 'IC|obj0_v0-rob0_f0') not actually feasible
# edge ('IC|obs0_f2-obj0_f1', 'NC|obs0_f2-rob0_v0', 'IC|obj0_v0-rob0_f0') -> ('NC|obs0_f2-obj0_f1', 'NC|obs0_f2-rob0_v0', 'NC|obj0_f0-rob0_v1') not actually feasible
# edge ('IC|obs0_f2-obj0_f1', 'NC|obs0_f2-rob0_v0', 'IC|obj0_v0-rob0_f0') -> ('NC|obs0_f2-obj0_f1', 'NC|obs0_f2-rob0_v0', 'NC|obj0_f3-rob0_v0') is feasible, new dist: 37.170682266521496, added to pq True
# Convex Restriction Gcs A* complete!
# cost: 37.170682266521496, time: 0.018878936767578125
# vertex path: ['source'
#  "('NC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'NC|obj0_f3-rob0_v0')"
#  "('NC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'NC|obj0_f0-rob0_v1')"
#  "('NC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'IC|obj0_f1-rob0_f1')"
#  "('IC|obs0_f0-obj0_v3', 'NC|obs0_f0-rob0_v1', 'IC|obj0_f1-rob0_f1')"
#  "('IC|obs0_v0-obj0_f2', 'NC|obs0_f0-rob0_v1', 'IC|obj0_f1-rob0_f1')"
#  "('IC|obs0_f2-obj0_f1', 'NC|obs0_f0-rob0_v1', 'IC|obj0_f0-rob0_v1')"
#  "('NC|obs0_f2-obj0_f1', 'NC|obs0_f2-rob0_v0', 'IC|obj0_f0-rob0_v1')"
#  "('IC|obs0_f2-obj0_f1', 'NC|obs0_f2-rob0_v0', 'IC|obj0_v0-rob0_f0')"
#  "('NC|obs0_f2-obj0_f1', 'NC|obs0_f2-rob0_v0', 'NC|obj0_f3-rob0_v0')"
#  'target']
# n_vertices_visited: 13, n_edges_visited: 8, n_vertices_explored: 473, vertex_coverage: 0.0718, edge_coverage: 0.0012, time_wall_clock: 9.79, n_gcs_solves: 480, gcs_solve_time_total: 9.08, gcs_solve_time_iter_mean: 0.0189, gcs_solve_time_last_10_mean: 0.207, gcs_solve_time_iter_std: 0.0967, gcs_solve_time_iter_min: 0.00106, gcs_solve_time_iter_max: 1.54, n_vertices_revisited: 0, n_vertices_reexplored: 7

# %%
ws_x = 4
ws_y = 3
params = ContactGraphGeneratorParams(
    name="cg_trichal3",
    obs_vertices=[[[-1, 2], [-1, -1], [2, 2]]],
    obj_vertices=[[[1, 0.5], [1, -0.5], [2, -0.5], [2, 0.5]]],
    rob_vertices=[[[3, 1], [3, 0], [3.5, 0]]],
    source_obj_pos=[[3.25, 0]],
    source_rob_pos=[[-3, 0]],
    target_obj_pos=[[-1.5, 0]],
    target_rob_pos=[[1.5, 0.5]],
    n_pos_per_set=2,
    workspace=[[-ws_x, ws_x], [-ws_y, ws_y]],
)

generator = ContactGraphGenerator(params)
generator.plot()

# %%
generator.generate()

# %%
cg = ContactGraph.load_from_file(params.graph_file_path)

# %%
ws_x = 4
ws_y = 3
params = ContactGraphGeneratorParams(
    name="cg_maze_a1",
    obs_vertices=[
        [[-2, -2.7], [2.2, 2.6], [-1.3, 0.5]],
        [[0.5, -2], [2.7, -1.2], [2.4, 0.3]],
    ],
    obj_vertices=[[[1, 0.5], [1, -0.5], [2, -0.5], [2, 0.5]]],
    rob_vertices=[[[3, 1], [3, 0], [3.5, 0]]],
    source_obj_pos=[[3.25, 0]],
    source_rob_pos=[[1.5, 0.6]],
    target_obj_pos=[[-2.3, -0.7]],
    target_rob_pos=[[-0.5, 2]],
    n_pos_per_set=2,
    workspace=[[-ws_x, ws_x], [-ws_y, ws_y]],
)

generator = ContactGraphGenerator(params)
generator.plot()

# %%
generator.generate()

# %%
cg = ContactGraph.load_from_file(params.graph_file_path)

# %%
ws_x = 4
ws_y = 3
params = ContactGraphGeneratorParams(
    name="cg_maze_a2",
    obs_vertices=[
        [[-2, -2.7], [2.2, 2.6], [-1.3, 0.5]],
        [[0.5, -2], [2.7, -1.2], [2.4, 0.3]],
    ],
    obj_vertices=[[[1, 0.5], [1, -0.5], [2, -0.5], [2, 0.5]]],
    rob_vertices=[[[3, 1], [3, 0], [3.5, 0]]],
    source_obj_pos=[[1.6, 0.6]],
    source_rob_pos=[[3.25, 0]],
    target_obj_pos=[[-2.3, -0.7]],
    target_rob_pos=[[-0.5, 2]],
    n_pos_per_set=2,
    workspace=[[-ws_x, ws_x], [-ws_y, ws_y]],
)

generator = ContactGraphGenerator(params)
generator.plot()

# %%
generator.generate()

# %%
cg = ContactGraph.load_from_file(params.graph_file_path)
