# %%
from IPython.display import HTML
from large_gcs.example_graphs.spp_gcs import create_spp_2d_graph
from large_gcs.graph.cost_factory import create_l2norm_edge_cost, create_l2norm_squared_edge_cost
from large_gcs.algorithms.gcs_astar import GcsAstar
from large_gcs.algorithms.search_algorithm import AlgVisParams
import matplotlib.pyplot as plt
import numpy as np
import os
from IPython.display import Video

# %%
G = create_spp_2d_graph(create_l2norm_edge_cost)
file = os.path.join(os.environ['PROJECT_ROOT'], "output", "gcs_astar", "gcs_astar_spp_2d_l2norm.mp4")
G_astar = GcsAstar(G, vis_params=AlgVisParams(output_path=file)).run(animate=True)
# Out:
# Gcs A* complete!
# ShortestPathSolution(cost=9.28580898690435, time=0.009067926090210676, path=[('s', array([0., 0.])), ('p0', array([2.1812743 , 0.34299636])), ('e1', array([6.53338475, 1.02759693])), ('t', array([8.99999998, 0.        ]))], flows=[0.9999998448857302, 8.0961729942459e-08, 7.415253981954327e-08, 6.149346583578197e-09, 6.919027317121332e-09, 1.0353444635462076e-08, 5.0694117279012446e-08, 0.9999998448857302, 7.002179975138182e-08, 1.0915145676365899e-08, 0.9999999201564017, 2.8926051705266984e-09, 3.121303354217335e-08, 7.502518946260987e-09, 8.590698292623713e-09, 3.5004968087709433e-09, 3.3134411333317284e-08, 4.4642213091413214e-08, 7.023477800142639e-08, 4.297732094596958e-09, 2.3906404134394194e-08, 6.043012519117036e-09], result=<pydrake.solvers.MathematicalProgramResult object at 0x7f400d0855f0>)
# AlgMetrics(n_vertices_visited=9, n_edges_visited=22, vertex_coverage=1.0, edge_coverage=1.0, n_gcs_solves=17, gcs_solve_time_total=0.0723854061216116, gcs_solve_time_iter_mean=0.004257965065977152, gcs_solve_time_iter_std=0.002572814040194505, gcs_solve_time_iter_min=0.001844089012593031, gcs_solve_time_iter_max=0.009379315190017223)

# %%
Video(file)
# Out:
# <video src="/home/shaoyuan/Documents/Software/large_gcs/output/gcs_astar/gcs_astar_spp_2d.mp4" controls  >
#       Your browser does not support the <code>video</code> element.
#     </video>
