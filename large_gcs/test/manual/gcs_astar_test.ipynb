# %%
from IPython.display import HTML
from large_gcs.example_graphs.spp_gcs import create_spp_2d_graph
from large_gcs.graph.cost_factory import create_l2norm_edge_cost, create_l2norm_squared_edge_cost
from large_gcs.algorithms.gcs_astar import GcsAstar
from large_gcs.algorithms.search_algorithm import AlgVisParams
import matplotlib.pyplot as plt
import numpy as np
import os
from IPython.display import Video

# %%
G = create_spp_2d_graph(create_l2norm_edge_cost)
base_file = os.path.join(os.environ['PROJECT_ROOT'], "output", "gcs_astar", "gcs_astar_spp_2d_l2norm")
vid_file = base_file + ".mp4"
plot_file = base_file + ".png"
G_astar = GcsAstar(G, vis_params=AlgVisParams(vid_output_path=vid_file, plot_output_path=plot_file)).run(animate=True, final_plot=True)
# Out:
# Gcs A* complete!
# ShortestPathSolution(cost=9.285808554590634, time=0.0034336810931563377, path=[('s', array([0., 0.])), ('p0', array([2.25006451, 0.35392008])), ('e1', array([6.5333202, 1.0276048])), ('t', array([9., 0.]))], flows=[1.0, 1.0, 1.0], result=<pydrake.solvers.MathematicalProgramResult object at 0x7f1990568bb0>)
# AlgMetrics(n_vertices_visited=3, n_edges_visited=1, vertex_coverage=0.33, edge_coverage=0.05, n_gcs_solves=4, gcs_solve_time_total=0.009115188848227262, gcs_solve_time_iter_mean=0.0022787972120568156, gcs_solve_time_iter_std=0.0006803528402316677, gcs_solve_time_iter_min=0.001673353835940361, gcs_solve_time_iter_max=0.0034336810931563377)

# %%
Video(vid_file)
# Out:
# <video src="/home/shaoyuan/Documents/Software/large_gcs/output/gcs_astar/gcs_astar_spp_2d_l2norm.mp4" controls  >
#       Your browser does not support the <code>video</code> element.
#     </video>
