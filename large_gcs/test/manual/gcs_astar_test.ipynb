# %%
from IPython.display import HTML
from large_gcs.example_graphs.spp_gcs import create_spp_2d_graph
from large_gcs.graph.cost_factory import create_l2norm_edge_cost, create_l2norm_squared_edge_cost
from large_gcs.algorithms.gcs_astar import GcsAstar
from large_gcs.algorithms.search_algorithm import AlgVisParams
import matplotlib.pyplot as plt
import numpy as np
import os
from IPython.display import Video

# %%
G = create_spp_2d_graph(create_l2norm_edge_cost)
file = os.path.join(os.environ['PROJECT_ROOT'], "output", "gcs_astar", "gcs_astar_spp_2d_l2norm.mp4")
G_astar = GcsAstar(G, vis_params=AlgVisParams(vid_output_path=file)).run(animate=True)
# Out:
# Gcs A* complete!
# ShortestPathSolution(cost=9.285808545166546, time=0.002125148195773363, path=[('s', array([0., 0.])), ('p0', array([2.16701787, 0.34084842])), ('e1', array([6.53333073, 1.02760355])), ('t', array([9., 0.]))], flows=[1.0, 1.0, 1.0], result=<pydrake.solvers.MathematicalProgramResult object at 0x7f6d2c19c730>)
# AlgMetrics(n_vertices_visited=4, n_edges_visited=2, vertex_coverage=0.44, edge_coverage=0.09, n_gcs_solves=7, gcs_solve_time_total=0.030007853638380766, gcs_solve_time_iter_mean=0.004286836234054395, gcs_solve_time_iter_std=0.0035291676261238977, gcs_solve_time_iter_min=0.001786699052900076, gcs_solve_time_iter_max=0.012525523081421852)

# %%
Video(file)
# Out:
# <video src="/home/shaoyuan/Documents/Software/large_gcs/output/gcs_astar/gcs_astar_spp_2d_l2norm.mp4" controls  >
#       Your browser does not support the <code>video</code> element.
#     </video>
