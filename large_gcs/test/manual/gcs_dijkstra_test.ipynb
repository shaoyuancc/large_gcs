# %%
from IPython.display import HTML
from large_gcs.example_graphs.spp_gcs import create_spp_2d_graph
from large_gcs.graph.cost_factory import create_l2norm_edge_cost, create_l2norm_squared_edge_cost
from large_gcs.algorithms.gcs_dijkstra import GcsDijkstra
from large_gcs.algorithms.search_algorithm import AlgVisParams
import matplotlib.pyplot as plt
import numpy as np
import os
from IPython.display import Video

# %%
G = create_spp_2d_graph(create_l2norm_edge_cost)
file = os.path.join(os.environ['PROJECT_ROOT'], "output", "gcs_dijkstra", "gcs_dijkstra_spp_2d.mp4")
# r = 30
# G.workspace = np.array([[-r, r], [-r, r]])
# vis_params = AlgVisParams(output_path=file,
#                           fps=6,
#                           figsize=(20,20),
#                         )
G_dijk = GcsDijkstra(G, vis_params=AlgVisParams(vid_output_path=file)).run(animate=True)
# Out:
# Gcs Dijkstra complete!
# ShortestPathSolution(cost=9.28580898740115, time=0.009940310847014189, path=[('s', array([0., 0.])), ('p0', array([2.18127439, 0.34299637])), ('e1', array([6.53338475, 1.02759693])), ('t', array([8.99999998, 0.        ]))], flows=[0.9999998448851648, 8.096200618197353e-08, 7.415282901661518e-08, 6.149383118857938e-09, 6.919066510620983e-09, 1.0353496699600442e-08, 5.069431928684827e-08, 0.9999998448851648, 7.002204038238931e-08, 1.0915195479627655e-08, 2.892620932639614e-09, 3.121316341277191e-08, 8.590740773570774e-09, 3.5005198265426904e-09, 3.313456041583976e-08, 4.464238936849258e-08, 4.297756557265139e-09, 2.3906502428278258e-08, 6.043046875490084e-09, 7.502557105761823e-09, 7.023506206721815e-08, 0.9999999201561024], result=<pydrake.solvers.MathematicalProgramResult object at 0x7f6ce18a5c70>)
# AlgMetrics(n_vertices_visited=9, n_edges_visited=22, vertex_coverage=1.0, edge_coverage=1.0, n_gcs_solves=18, gcs_solve_time_total=0.10898487363010645, gcs_solve_time_iter_mean=0.00605471520167258, gcs_solve_time_iter_std=0.003933553944712673, gcs_solve_time_iter_min=0.001496282871812582, gcs_solve_time_iter_max=0.016118959989398718)

# %%
Video(file)
# Out:
# <video src="/home/shaoyuan/Documents/Software/large_gcs/output/gcs_dijkstra/gcs_dijkstra_spp_2d.mp4" controls  >
#       Your browser does not support the <code>video</code> element.
#     </video>
