# %%
from IPython.display import HTML
from large_gcs.example_graphs.spp_gcs import create_spp_2d_graph
from large_gcs.graph.cost_factory import (
    create_l2norm_edge_cost,
    create_l2norm_squared_edge_cost,
)
from large_gcs.algorithms.gcs_astar import GcsAstar
from large_gcs.algorithms.search_algorithm import AlgVisParams
import matplotlib.pyplot as plt
import numpy as np
import os
from IPython.display import Video

# %%
G = create_spp_2d_graph(create_l2norm_edge_cost)
base_file = os.path.join(
    os.environ["PROJECT_ROOT"], "output", "gcs_astar", "gcs_astar_spp_2d_l2norm"
)
vid_file = base_file + ".mp4"
plot_file = base_file + ".png"
G_astar = GcsAstar(
    G,
    use_convex_relaxation=True,
    vis_params=AlgVisParams(vid_output_path=vid_file, plot_output_path=plot_file),
).run(animate=True, final_plot=True)
# Out:
# Adding 9 vertices to graph...
# 100%|██████████| 9/9 [00:00<00:00, 31801.80it/s]
# pq is not empty True
# next node in pq has edge to target True
# candidate sol is None False
# Gcs A* complete!
# cost: 9.285808539715735, time: 0.0006255360785871744
# vertex path: ['s' 'p0' 'e1' 't']
# AlgMetrics(n_vertices_visited=3, n_edges_visited=1, vertex_coverage=0.33, edge_coverage=0.05, n_gcs_solves=4, gcs_solve_time_total=0.0026954161003232002, gcs_solve_time_iter_mean=0.0006738540250808001, gcs_solve_time_iter_std=4.2385581151461164e-05, gcs_solve_time_iter_min=0.0006255360785871744, gcs_solve_time_iter_max=0.0007245971355587244)

# %%
Video(vid_file)
# Out:
# <video src="/home/shaoyuan/Documents/Software/large_gcs/output/gcs_astar/gcs_astar_spp_2d_l2norm.mp4" controls  >
#       Your browser does not support the <code>video</code> element.
#     </video>
